# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
# from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Activation, LeakyReLU, Dropout, BatchNormalization, MaxPooling2D, Lambda
from keras.models import Model
from sklearn.metrics import mean_squared_error as mse
from progressbar import ProgressBar
from image_process import ImageProcess
import const, cv2
from drive_data import DriveData
from config import Config

import matplotlib.pyplot as plt
import sys
sys.setrecursionlimit(10**7)
tf.compat.v1.disable_eager_execution()
# Out:
# =======================================================
#                Configuration Settings
# =======================================================
# Neural Net:     	fusion_kdh_jaerock3
# Data Collection:	fusion_kdh_jaerock3
# Run Neural:     	fusion_kdh_jaerock3

# %%
"""
## Dataset
"""
image_process = ImageProcess()
config = Config.neural_net
# data_path = "/mnt/exData/internal_simulation/test/2022-03-08-17-18-14/"
data_path = "/home2/kdh/av/latent/dataset/2022-12-08-14-25-28/"
if data_path[-1] == '/':
    data_path = data_path[:-1]

    loc_slash = data_path.rfind('/')
    if loc_slash != -1: # there is '/' in the data path
        model_name = data_path[loc_slash + 1:] # get folder name
        #model_name = model_name.strip('/')
    else:
        model_name = data_path
csv_path = data_path + '/' + model_name + const.DATA_EXT 
# data = DriveData(csv_path)
print(csv_path)
# data_path = data_path
# data.read()

csv_header = ['image_fname', 
                  'steering_angle', 'throttle', 'brake', 'linux_time', 
                  'vel', 'vel_x', 'vel_y', 'vel_z', 
                  'pos_x', 'pos_y', 'pos_z', 
                  'tar_image_fname', 'tar_steering_angle', 'tar_vel', 'tar_time']

df = pd.read_csv(csv_path, names=csv_header, index_col=False)
num_data = len(df)

bar = ProgressBar()
df_image_names = []
df_measurements = []
df_time_stamps= []
df_velocities= []
df_velocities_xyz= []
df_positions_xyz= []
df_tar_image_names= []
df_tar_steering_angle= []
df_tar_vel= []
df_tar_time= []
for i in bar(range(num_data)): # we don't have a title
    df_image_names.append(df.loc[i]['image_fname'])
    # if Config.data_collection['brake'] is True:
    df_measurements.append((float(df.loc[i]['steering_angle']),
                            float(df.loc[i]['throttle']), 
                            float(df.loc[i]['brake'])))
    df_time_stamps.append(float(df.loc[i]['linux_time']))
    df_velocities.append(float(df.loc[i]['vel']))
    df_velocities_xyz.append((float(df.loc[i]['vel_x']), 
                                float(df.loc[i]['vel_y']), 
                                float(df.loc[i]['vel_z'])))
    df_positions_xyz.append((float(df.loc[i]['pos_x']), 
                                float(df.loc[i]['pos_y']), 
                                float(df.loc[i]['pos_z'])))
    df_tar_image_names.append(df.loc[i]['tar_image_fname'])
    df_tar_steering_angle.append(float(df.loc[i]['tar_steering_angle']))
    df_tar_vel.append(float(df.loc[i]['tar_vel']))
    df_tar_time.append(float(df.loc[i]['tar_time']))
# Out:
# /home2/kdh/av/latent/dataset/2022-12-08-14-25-28/2022-12-08-14-25-28.csv
# 100% |########################################################################|

# %%
samples = list(zip( df_image_names, df_velocities, df_measurements, 
                    df_tar_image_names, df_tar_steering_angle, df_tar_vel, df_tar_time))

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]=str(config['gpus'])
gpu_config = tf.compat.v1.ConfigProto()
gpu_config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=gpu_config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
def prepare_vae_batch_samples(batch_samples):
    images = []
    steering_angles = []
    vels = []
    tar_images = []
    tar_steering_angles = []
    tar_vels = []
    tar_times = []
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in batch_samples:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        if Config.data_collection['crop'] is not True:
            image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
            tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        image = image_process.process(image)
        tar_image = image_process.process(tar_image)

        vels.append(velocity)
        tar_vels.append(tar_vel)
        tar_times.append(tar_time)
        tar_steering_angles.append(tar_steering_angle)
        # if no brake data in collected data, brake values are dummy
        steering_angle, throttle, brake = measurement
        steering_angles.append(steering_angle)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/image/'+image_name, image)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/tar_image/'+tar_image_name, tar_image)
        # if data == 'train':
        #     cv2.imwrite('/mnt/Data/oscar/train_data/'+image_name, image)
        # print(image.shape)
        images.append(image)
        tar_images.append(tar_image)
        # segimgs.append(segimg)


    return images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times

# %%
"""
## Encoder
"""

"""
## Create a sampling layer
"""
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon


encoder_inputs_img = tf.keras.Input(shape=(160, 160, 3))
encoder_inputs_str = tf.keras.Input(shape=(1))
encoder_inputs_vel = tf.keras.Input(shape=(1))
encoder_inputs_time = tf.keras.Input(shape=(1))
x = layers.Conv2D(24, (5, 5), padding='same', name='conv2d_1')(encoder_inputs_img)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1')(x)

x = layers.Conv2D(36, (5, 5), padding='same', name='conv2d_2')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_2')(x)

x = layers.Conv2D(48, (5, 5), padding='same', name='conv2d_3')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2d_4')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2d_5')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

latent = layers.Flatten()(x)
fc_s1  = layers.Dense(100)(encoder_inputs_str)
fc_s1  = layers.Activation('elu')(fc_s1)
fc_s2  = layers.Dense(50)(fc_s1)
fc_s2  = layers.Activation('elu')(fc_s2)
fc_v1  = layers.Dense(100)(encoder_inputs_vel)
fc_v1  = layers.Activation('elu')(fc_v1)
fc_v2  = layers.Dense(50)(fc_v1)
fc_v2  = layers.Activation('elu')(fc_v2)
fc_t1  = layers.Dense(100)(encoder_inputs_time)
fc_t1  = layers.Activation('elu')(fc_t1)
fc_t2  = layers.Dense(50)(fc_t1)
fc_t2  = layers.Activation('elu')(fc_t2)
conc_1 = layers.concatenate([latent, fc_s2, fc_v2, fc_t2])
fc_1   = layers.Dense(100)(conc_1)
x   = layers.Activation('elu')(fc_1)

z_mean = layers.Dense(50, name="z_mean")(x)
z_log_var = layers.Dense(50, name="z_log_var")(x)
encoder_output = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model([ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time], 
                        [z_mean, z_log_var, encoder_output], 
                        name="encoder")
encoder.summary()
# Out:
# WARNING:tensorflow:From /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 24) 1824        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160, 160, 24) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 160, 160, 24) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# pool2d_1 (MaxPooling2D)         (None, 80, 80, 24)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 80, 80, 36)   21636       pool2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 80, 36)   144         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 80, 80, 36)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# pool2d_2 (MaxPooling2D)         (None, 40, 40, 36)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 40, 40, 48)   43248       pool2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40, 40, 48)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 40, 40, 48)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 64)   27712       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 40, 40, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 40, 40, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          200         input_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          200         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 40, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           5050        activation_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 50)           5050        activation_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           5050        activation_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 102400)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 102550)       0           flatten[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          10255100    concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 50)           5050        activation_11[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 50)           5050        activation_11[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 50)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 10,413,242
# Trainable params: 10,412,770
# Non-trainable params: 472
# __________________________________________________________________________________________________

# %%
"""
## Decoder
"""

latent_inputs = tf.keras.Input(shape=(50,))
# x = layers.Dense(100, activation="elu")(latent_inputs)
x = layers.Dense(40 * 40 * 64, activation="elu")(latent_inputs)
x = layers.Reshape((40, 40, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="elu",  padding="same")(x)
# x = layers.Conv2DTranspose(48, 3, activation="elu",  padding="same")(x)
x = layers.Conv2DTranspose(36, 3, activation="elu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(24, 3, activation="elu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = tf.keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 102400)            5222400
# _________________________________________________________________
# reshape (Reshape)            (None, 40, 40, 64)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 40, 40, 64)        36928
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 80, 80, 36)        20772
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 160, 160, 24)      7800
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 160, 160, 3)       651
# =================================================================
# Total params: 5,288,551
# Trainable params: 5,288,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
## VAE
"""
model_input = [ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time]
model_output = decoder(encoder_output)

VarAE=Model(model_input, model_output)
# VarAE.run_eagerly = True

# %%
"""
Data generator
"""
from sklearn.model_selection import train_test_split

def _generator(samples, batch_size=config['batch_size']):
    num_samples = len(samples)
    while True: # Loop forever so the generator never terminates
        for offset in range(0, (num_samples//batch_size)*batch_size, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times = prepare_vae_batch_samples(batch_samples)

            X_img = np.array(images).astype("float32")/255.0
            X_tvel = np.array(tar_vels).astype("float32")
            X_tstr = np.array(tar_steering_angles).astype("float32")
            X_ttime = np.array(tar_times).astype("float32")

            y_train = np.array(tar_images).astype("float32")/255.0
            # if config['num_outputs'] == 1:
            # y_train = np.array(segimg)
            # print(y_train.max())
            # y_train = np.repeat(y_train[..., np.newaxis], 1, -1)/y_train.max()
            X_train = [X_img, X_tstr, X_tvel, X_ttime]
            # print(X_tstr, X_tvel, X_ttime)
            # print(y_train)
            # print(y_train.shape)
            yield X_train, y_train

train_data, valid_data = train_test_split(samples, test_size=config['validation_rate'])

train_generator = _generator(train_data, config['batch_size'])
valid_generator = _generator(valid_data, config['batch_size'])

# %%
"""
VAE loss
"""
optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.0000001)
# optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.00000001)
#                                  learning_rate=0.000005,decay=0.0000000001
r_loss_factor=160*160*100   # This is a Hyperparameter

def vae_r_loss(y_true, y_pred):    ## MSE
    r_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_pred), axis=[1,2,3])
    return r_loss_factor * r_loss

def vae_kl_loss(y_true, y_pred):   ## KL-Divergence
    kl_loss=( -0.5 * tf.keras.backend.sum(1+z_log_var 
                - tf.keras.backend.square(z_mean) 
                - tf.keras.backend.exp(z_log_var), axis=1)
    )
    return kl_loss

def vae_loss(y_true, y_pred): 
    r_loss=vae_r_loss(y_true, y_pred) #Loss of Decoder
    kl_loss = vae_kl_loss(y_true, y_pred) #Loss of Encoder
    return r_loss + kl_loss #Sum of these two


VarAE.compile(optimizer=optimizer,
                loss= vae_loss, 
                metrics=[vae_r_loss, vae_kl_loss])
# VarAE.summary()
#  vae_r_loss: 12.6586 - vae_kl_loss: 2251744.5000 
#  val_loss: 50649853.6174 
#  val_vae_r_loss: 28.6742 - val_vae_kl_loss: 50649896.0000

# %%
"""
## Train the VAE
"""
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.python.framework.ops import disable_eager_execution

        # checkpoint
callbacks = []
#weight_filename = self.data_path + '_' + Config.config_yaml_name \
#    + '_N' + str(config['network_type']) + '_ckpt'
model_ckpt_name = "vae_kdh"
checkpoint = ModelCheckpoint(model_ckpt_name +'_ckpt.{epoch:02d}-{val_loss:.3f}.h5',
                                monitor='val_loss', 
                                verbose=1, save_best_only=True, mode='min')
callbacks.append(checkpoint)

# early stopping
patience = 1000
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, 
                            verbose=1, mode='min')
# callbacks.append(earlystop)

# validation_steps = len(valid_data)//config['batch_size']
# print(validation_steps)
train_hist = VarAE.fit( train_generator,  
                        steps_per_epoch=len(train_data)//config['batch_size'], 
                        epochs=100000, 
                        validation_data=valid_generator,
                        validation_steps=len(valid_data)//config['batch_size'],
                        # shuffle=True,
                        verbose=1, 
                        callbacks=callbacks, 
                        use_multiprocessing=True,
                        workers=48
                        )
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 37308.7677 - vae_r_loss: 33428.4883 - vae_kl_loss: 3880.2664WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 19930.85920, saving model to vae_kdh_ckpt.01-19930.859.h5
# 3127/3127 [==============================] - 276s 88ms/step - batch: 1563.0000 - size: 32.0000 - loss: 37308.7677 - vae_r_loss: 33428.4883 - vae_kl_loss: 3880.2664 - val_loss: 19930.8592 - val_vae_r_loss: 19474.1621 - val_vae_kl_loss: 456.7093
# Epoch 2/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 12641.7642 - vae_r_loss: 12263.9062 - vae_kl_loss: 377.8722WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00002: val_loss improved from 19930.85920 to 19463.73691, saving model to vae_kdh_ckpt.02-19463.737.h5
# 3127/3127 [==============================] - 270s 86ms/step - batch: 1563.0000 - size: 32.0000 - loss: 12641.7642 - vae_r_loss: 12263.9062 - vae_kl_loss: 377.8722 - val_loss: 19463.7369 - val_vae_r_loss: 19085.0254 - val_vae_kl_loss: 378.6999
# Epoch 3/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 9844.9609 - vae_r_loss: 9449.8672 - vae_kl_loss: 395.0906WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00003: val_loss improved from 19463.73691 to 19074.75685, saving model to vae_kdh_ckpt.03-19074.757.h5
# 3127/3127 [==============================] - 271s 87ms/step - batch: 1563.0000 - size: 32.0000 - loss: 9843.9473 - vae_r_loss: 9448.8574 - vae_kl_loss: 395.0869 - val_loss: 19074.7568 - val_vae_r_loss: 18700.2734 - val_vae_kl_loss: 374.4911
# Epoch 4/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7268.4491 - vae_r_loss: 6869.9004 - vae_kl_loss: 398.5483WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00004: val_loss improved from 19074.75685 to 18679.10113, saving model to vae_kdh_ckpt.04-18679.101.h5
# 3127/3127 [==============================] - 271s 87ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7268.4491 - vae_r_loss: 6869.9004 - vae_kl_loss: 398.5483 - val_loss: 18679.1011 - val_vae_r_loss: 18315.6172 - val_vae_kl_loss: 363.4770
# Epoch 5/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 285135.3611 - vae_r_loss: 8028.4014 - vae_kl_loss: 277106.9062WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00005: val_loss did not improve from 18679.10113
# 3127/3127 [==============================] - 267s 85ms/step - batch: 1563.0000 - size: 32.0000 - loss: 285048.1663 - vae_r_loss: 8029.4819 - vae_kl_loss: 277018.6250 - val_loss: 23729.3971 - val_vae_r_loss: 19532.0977 - val_vae_kl_loss: 4197.3013
# Epoch 6/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 13937.5780 - vae_r_loss: 12707.4316 - vae_kl_loss: 1230.1261WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00006: val_loss did not improve from 18679.10113
# 3127/3127 [==============================] - 269s 86ms/step - batch: 1563.0000 - size: 32.0000 - loss: 13938.1536 - vae_r_loss: 12708.2236 - vae_kl_loss: 1229.9099 - val_loss: 19166.7632 - val_vae_r_loss: 18606.7754 - val_vae_kl_loss: 559.9818
# Epoch 7/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 11989.6943 - vae_r_loss: 11508.0498 - vae_kl_loss: 481.6653WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00007: val_loss did not improve from 18679.10113
# 3127/3127 [==============================] - 272s 87ms/step - batch: 1563.0000 - size: 32.0000 - loss: 11989.1063 - vae_r_loss: 11507.4932 - vae_kl_loss: 481.6335 - val_loss: 19603.9241 - val_vae_r_loss: 19138.7715 - val_vae_kl_loss: 465.1553
# Epoch 8/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 11195.0650 - vae_r_loss: 10779.4707 - vae_kl_loss: 415.6027WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00008: val_loss improved from 18679.10113 to 18414.93996, saving model to vae_kdh_ckpt.08-18414.940.h5
# 3127/3127 [==============================] - 296s 95ms/step - batch: 1563.0000 - size: 32.0000 - loss: 11194.3410 - vae_r_loss: 10778.7549 - vae_kl_loss: 415.5935 - val_loss: 18414.9400 - val_vae_r_loss: 18009.3438 - val_vae_kl_loss: 405.5898
# Epoch 9/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 10330.7362 - vae_r_loss: 9953.2227 - vae_kl_loss: 377.4908WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00009: val_loss improved from 18414.93996 to 18386.18512, saving model to vae_kdh_ckpt.09-18386.185.h5
# 3127/3127 [==============================] - 292s 93ms/step - batch: 1563.0000 - size: 32.0000 - loss: 10330.7362 - vae_r_loss: 9953.2227 - vae_kl_loss: 377.4908 - val_loss: 18386.1851 - val_vae_r_loss: 18030.7500 - val_vae_kl_loss: 355.4263
# Epoch 10/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 9014.7126 - vae_r_loss: 8671.0312 - vae_kl_loss: 343.6830WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00010: val_loss did not improve from 18386.18512
# 3127/3127 [==============================] - 352s 113ms/step - batch: 1563.0000 - size: 32.0000 - loss: 9014.7126 - vae_r_loss: 8671.0312 - vae_kl_loss: 343.6830 - val_loss: 18670.8316 - val_vae_r_loss: 18324.8379 - val_vae_kl_loss: 346.0061
# Epoch 11/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 7268.5257 - vae_r_loss: 6947.9175 - vae_kl_loss: 320.6055WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00011: val_loss improved from 18386.18512 to 18070.70783, saving model to vae_kdh_ckpt.11-18070.708.h5
# 3127/3127 [==============================] - 353s 113ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7267.5709 - vae_r_loss: 6946.9556 - vae_kl_loss: 320.6123 - val_loss: 18070.7078 - val_vae_r_loss: 17747.7168 - val_vae_kl_loss: 323.0039
# Epoch 12/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 6472.5885 - vae_r_loss: 6118.3091 - vae_kl_loss: 354.2809WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00012: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6474.4105 - vae_r_loss: 6120.0498 - vae_kl_loss: 354.3621 - val_loss: 20788.6007 - val_vae_r_loss: 19941.4199 - val_vae_kl_loss: 847.1812
# Epoch 13/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 288399762.6907 - vae_r_loss: 13245.3389 - vae_kl_loss: 288382144.0000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00013: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 288307538.8842 - vae_r_loss: 13244.8711 - vae_kl_loss: 288289920.0000 - val_loss: 29820.8809 - val_vae_r_loss: 18265.1973 - val_vae_kl_loss: 11555.7305
# Epoch 14/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 18214.0476 - vae_r_loss: 11811.4043 - vae_kl_loss: 6402.6372WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00014: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 18214.0476 - vae_r_loss: 11811.4043 - vae_kl_loss: 6402.6372 - val_loss: 22364.0333 - val_vae_r_loss: 18216.2793 - val_vae_kl_loss: 4147.7676
# Epoch 15/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 13260.6354 - vae_r_loss: 11297.8496 - vae_kl_loss: 1962.7843WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00015: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 13260.6354 - vae_r_loss: 11297.8496 - vae_kl_loss: 1962.7843 - val_loss: 19416.8567 - val_vae_r_loss: 18164.4609 - val_vae_kl_loss: 1252.4109
# Epoch 16/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 50323078671612.7031 - vae_r_loss: 12702.6514 - vae_kl_loss: 50323079036928.0000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00016: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 50323078671612.7031 - vae_r_loss: 12702.6514 - vae_kl_loss: 50323079036928.0000 - val_loss: 20655.0891 - val_vae_r_loss: 19023.9590 - val_vae_kl_loss: 1631.1307
# Epoch 17/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 14186.5990 - vae_r_loss: 12658.8311 - vae_kl_loss: 1527.7603 ETA: 3s - batch: 1540.0000 - siWARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00017: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 14186.5990 - vae_r_loss: 12658.8311 - vae_kl_loss: 1527.7603 - val_loss: 18303.2510 - val_vae_r_loss: 17657.2754 - val_vae_kl_loss: 645.9769
# Epoch 18/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 12385.5746 - vae_r_loss: 11701.2754 - vae_kl_loss: 684.3008WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00018: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 12385.5746 - vae_r_loss: 11701.2754 - vae_kl_loss: 684.3008 - val_loss: 18297.9100 - val_vae_r_loss: 17732.7266 - val_vae_kl_loss: 565.1755
# Epoch 19/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 11232.2231 - vae_r_loss: 10683.1309 - vae_kl_loss: 549.0947WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00019: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 11232.2231 - vae_r_loss: 10683.1309 - vae_kl_loss: 549.0947 - val_loss: 18455.2673 - val_vae_r_loss: 17932.7227 - val_vae_kl_loss: 522.5613
# Epoch 20/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 10336.3254 - vae_r_loss: 9844.7354 - vae_kl_loss: 491.5897WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00020: val_loss did not improve from 18070.70783
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 10336.3254 - vae_r_loss: 9844.7354 - vae_kl_loss: 491.5897 - val_loss: 18394.9799 - val_vae_r_loss: 17895.8359 - val_vae_kl_loss: 499.1443
# Epoch 21/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 9113.0512 - vae_r_loss: 8655.7344 - vae_kl_loss: 457.3121WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00021: val_loss improved from 18070.70783 to 17905.97804, saving model to vae_kdh_ckpt.21-17905.978.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 9113.0512 - vae_r_loss: 8655.7344 - vae_kl_loss: 457.3121 - val_loss: 17905.9780 - val_vae_r_loss: 17453.2793 - val_vae_kl_loss: 452.6903
# Epoch 22/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 8655.4100 - vae_r_loss: 8208.1201 - vae_kl_loss: 447.2819WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00022: val_loss did not improve from 17905.97804
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 8655.4100 - vae_r_loss: 8208.1201 - vae_kl_loss: 447.2819 - val_loss: 18077.0928 - val_vae_r_loss: 17639.2949 - val_vae_kl_loss: 437.7944
# Epoch 23/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 8257.0194 - vae_r_loss: 7815.0317 - vae_kl_loss: 441.9930WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00023: val_loss did not improve from 17905.97804
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 8257.0194 - vae_r_loss: 7815.0317 - vae_kl_loss: 441.9930 - val_loss: 18010.2289 - val_vae_r_loss: 17553.3262 - val_vae_kl_loss: 456.8985
# Epoch 24/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7635.8615 - vae_r_loss: 7207.1831 - vae_kl_loss: 428.6885WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00024: val_loss did not improve from 17905.97804
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7635.8615 - vae_r_loss: 7207.1831 - vae_kl_loss: 428.6885 - val_loss: 18284.4022 - val_vae_r_loss: 17876.5859 - val_vae_kl_loss: 407.7985
# Epoch 25/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7758.5359 - vae_r_loss: 7320.5898 - vae_kl_loss: 437.9416WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00025: val_loss improved from 17905.97804 to 17780.24802, saving model to vae_kdh_ckpt.25-17780.248.h5
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7758.5359 - vae_r_loss: 7320.5898 - vae_kl_loss: 437.9416 - val_loss: 17780.2480 - val_vae_r_loss: 17340.4082 - val_vae_kl_loss: 439.8510
# Epoch 26/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 7480.9804 - vae_r_loss: 7052.1357 - vae_kl_loss: 428.8478WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00026: val_loss did not improve from 17780.24802
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7480.3888 - vae_r_loss: 7051.5410 - vae_kl_loss: 428.8510 - val_loss: 18029.7615 - val_vae_r_loss: 17601.8301 - val_vae_kl_loss: 427.9198
# Epoch 27/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7003.8485 - vae_r_loss: 6570.3413 - vae_kl_loss: 433.5030WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00027: val_loss did not improve from 17780.24802
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7003.8485 - vae_r_loss: 6570.3413 - vae_kl_loss: 433.5030 - val_loss: 18331.9394 - val_vae_r_loss: 17901.2500 - val_vae_kl_loss: 430.6779
# Epoch 28/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7145.1435 - vae_r_loss: 6717.0625 - vae_kl_loss: 428.0772WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00028: val_loss improved from 17780.24802 to 17705.15297, saving model to vae_kdh_ckpt.28-17705.153.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7145.1435 - vae_r_loss: 6717.0625 - vae_kl_loss: 428.0772 - val_loss: 17705.1530 - val_vae_r_loss: 17277.1250 - val_vae_kl_loss: 428.0287
# Epoch 29/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6979.4692 - vae_r_loss: 6547.3506 - vae_kl_loss: 432.1195WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00029: val_loss improved from 17705.15297 to 17410.07726, saving model to vae_kdh_ckpt.29-17410.077.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6979.4692 - vae_r_loss: 6547.3506 - vae_kl_loss: 432.1195 - val_loss: 17410.0773 - val_vae_r_loss: 16965.0215 - val_vae_kl_loss: 445.0671
# Epoch 30/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 7015.8964 - vae_r_loss: 6591.6489 - vae_kl_loss: 424.2499WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00030: val_loss did not improve from 17410.07726
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7015.9060 - vae_r_loss: 6591.6567 - vae_kl_loss: 424.2515 - val_loss: 17467.5227 - val_vae_r_loss: 17047.6289 - val_vae_kl_loss: 419.8799
# Epoch 31/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6811.2366 - vae_r_loss: 6391.9551 - vae_kl_loss: 419.2845WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00031: val_loss improved from 17410.07726 to 17367.12765, saving model to vae_kdh_ckpt.31-17367.128.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6811.2366 - vae_r_loss: 6391.9551 - vae_kl_loss: 419.2845 - val_loss: 17367.1277 - val_vae_r_loss: 16964.3672 - val_vae_kl_loss: 402.7603
# Epoch 32/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6589.5714 - vae_r_loss: 6188.6582 - vae_kl_loss: 400.9142WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00032: val_loss improved from 17367.12765 to 16972.90740, saving model to vae_kdh_ckpt.32-16972.907.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6589.5714 - vae_r_loss: 6188.6582 - vae_kl_loss: 400.9142 - val_loss: 16972.9074 - val_vae_r_loss: 16569.2070 - val_vae_kl_loss: 403.6953
# Epoch 33/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6405.4991 - vae_r_loss: 6012.9390 - vae_kl_loss: 392.5685WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00033: val_loss did not improve from 16972.90740
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6405.4991 - vae_r_loss: 6012.9390 - vae_kl_loss: 392.5685 - val_loss: 17497.5446 - val_vae_r_loss: 17108.8965 - val_vae_kl_loss: 388.6644
# Epoch 34/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6318.4441 - vae_r_loss: 5943.4683 - vae_kl_loss: 374.9788WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00034: val_loss improved from 16972.90740 to 16858.44080, saving model to vae_kdh_ckpt.34-16858.441.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6318.4441 - vae_r_loss: 5943.4683 - vae_kl_loss: 374.9788 - val_loss: 16858.4408 - val_vae_r_loss: 16481.2773 - val_vae_kl_loss: 377.1754
# Epoch 35/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5862.3926 - vae_r_loss: 5505.1562 - vae_kl_loss: 357.2391WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00035: val_loss improved from 16858.44080 to 16760.79470, saving model to vae_kdh_ckpt.35-16760.795.h5
# 3127/3127 [==============================] - 374s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5862.3926 - vae_r_loss: 5505.1562 - vae_kl_loss: 357.2391 - val_loss: 16760.7947 - val_vae_r_loss: 16418.9863 - val_vae_kl_loss: 341.8085
# Epoch 36/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5479.0185 - vae_r_loss: 5141.0947 - vae_kl_loss: 337.9217WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00036: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5479.0185 - vae_r_loss: 5141.0947 - vae_kl_loss: 337.9217 - val_loss: 16998.5753 - val_vae_r_loss: 16684.0508 - val_vae_kl_loss: 314.5025
# Epoch 37/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5248.6336 - vae_r_loss: 4935.1714 - vae_kl_loss: 313.4649WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00037: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5248.6336 - vae_r_loss: 4935.1714 - vae_kl_loss: 313.4649 - val_loss: 17189.8047 - val_vae_r_loss: 16903.4746 - val_vae_kl_loss: 286.3325
# Epoch 38/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4824.6886 - vae_r_loss: 4530.0610 - vae_kl_loss: 294.6282WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00038: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4824.6886 - vae_r_loss: 4530.0610 - vae_kl_loss: 294.6282 - val_loss: 17067.9841 - val_vae_r_loss: 16807.6699 - val_vae_kl_loss: 260.3083
# Epoch 39/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4640.3116 - vae_r_loss: 4365.4961 - vae_kl_loss: 274.8116WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00039: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4640.3116 - vae_r_loss: 4365.4961 - vae_kl_loss: 274.8116 - val_loss: 16974.5275 - val_vae_r_loss: 16726.7246 - val_vae_kl_loss: 247.8042
# Epoch 40/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4535.7771 - vae_r_loss: 4273.7593 - vae_kl_loss: 262.0178WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00040: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4535.7771 - vae_r_loss: 4273.7593 - vae_kl_loss: 262.0178 - val_loss: 17031.7861 - val_vae_r_loss: 16783.8438 - val_vae_kl_loss: 247.9485
# Epoch 41/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4499.0723 - vae_r_loss: 4239.3423 - vae_kl_loss: 259.7242WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00041: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4499.0723 - vae_r_loss: 4239.3423 - vae_kl_loss: 259.7242 - val_loss: 16991.9946 - val_vae_r_loss: 16754.7422 - val_vae_kl_loss: 237.2551
# Epoch 42/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4477.5023 - vae_r_loss: 4219.6216 - vae_kl_loss: 257.8883WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00042: val_loss did not improve from 16760.79470
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4477.5023 - vae_r_loss: 4219.6216 - vae_kl_loss: 257.8883 - val_loss: 16959.9284 - val_vae_r_loss: 16724.9707 - val_vae_kl_loss: 234.9585
# Epoch 43/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4322.8845 - vae_r_loss: 4070.5249 - vae_kl_loss: 252.3611WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00043: val_loss improved from 16760.79470 to 16020.67829, saving model to vae_kdh_ckpt.43-16020.678.h5
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4322.8845 - vae_r_loss: 4070.5249 - vae_kl_loss: 252.3611 - val_loss: 16020.6783 - val_vae_r_loss: 15788.9375 - val_vae_kl_loss: 231.7442
# Epoch 44/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4112.5690 - vae_r_loss: 3870.3613 - vae_kl_loss: 242.2059WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00044: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4112.5690 - vae_r_loss: 3870.3613 - vae_kl_loss: 242.2059 - val_loss: 17030.9664 - val_vae_r_loss: 16801.9570 - val_vae_kl_loss: 229.0221
# Epoch 45/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4286.9891 - vae_r_loss: 4047.3560 - vae_kl_loss: 239.6313WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00045: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4286.9891 - vae_r_loss: 4047.3560 - vae_kl_loss: 239.6313 - val_loss: 16492.5514 - val_vae_r_loss: 16267.1885 - val_vae_kl_loss: 225.3575
# Epoch 46/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 4258.8141 - vae_r_loss: 4017.2632 - vae_kl_loss: 241.5544WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00046: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4259.7451 - vae_r_loss: 4018.1953 - vae_kl_loss: 241.5535 - val_loss: 16698.3619 - val_vae_r_loss: 16474.7070 - val_vae_kl_loss: 223.6728
# Epoch 47/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4095.5295 - vae_r_loss: 3858.9382 - vae_kl_loss: 236.5850WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00047: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4095.5295 - vae_r_loss: 3858.9382 - vae_kl_loss: 236.5850 - val_loss: 16601.3490 - val_vae_r_loss: 16377.6221 - val_vae_kl_loss: 223.7248
# Epoch 48/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3984.0604 - vae_r_loss: 3753.3325 - vae_kl_loss: 230.7290WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00048: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3984.0604 - vae_r_loss: 3753.3325 - vae_kl_loss: 230.7290 - val_loss: 16261.0850 - val_vae_r_loss: 16048.2744 - val_vae_kl_loss: 212.8136
# Epoch 49/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3933.8846 - vae_r_loss: 3704.3984 - vae_kl_loss: 229.4845WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00049: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3933.8846 - vae_r_loss: 3704.3984 - vae_kl_loss: 229.4845 - val_loss: 16493.8157 - val_vae_r_loss: 16273.8027 - val_vae_kl_loss: 220.0095
# Epoch 50/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3888.1539 - vae_r_loss: 3657.8770 - vae_kl_loss: 230.2758WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00050: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3888.1539 - vae_r_loss: 3657.8770 - vae_kl_loss: 230.2758 - val_loss: 16509.4048 - val_vae_r_loss: 16290.7100 - val_vae_kl_loss: 218.6965
# Epoch 51/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3887.7804 - vae_r_loss: 3659.3237 - vae_kl_loss: 228.4574WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00051: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3887.7804 - vae_r_loss: 3659.3237 - vae_kl_loss: 228.4574 - val_loss: 16106.1340 - val_vae_r_loss: 15883.8340 - val_vae_kl_loss: 222.2959
# Epoch 52/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3804.9833 - vae_r_loss: 3575.1196 - vae_kl_loss: 229.8620WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00052: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3804.9833 - vae_r_loss: 3575.1196 - vae_kl_loss: 229.8620 - val_loss: 16075.6210 - val_vae_r_loss: 15862.4316 - val_vae_kl_loss: 213.2005
# Epoch 53/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3791.1869 - vae_r_loss: 3564.1392 - vae_kl_loss: 227.0502WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00053: val_loss did not improve from 16020.67829
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3791.1869 - vae_r_loss: 3564.1392 - vae_kl_loss: 227.0502 - val_loss: 16090.1022 - val_vae_r_loss: 15873.0166 - val_vae_kl_loss: 217.0998
# Epoch 54/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3791.9069 - vae_r_loss: 3563.5540 - vae_kl_loss: 228.3499WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00054: val_loss improved from 16020.67829 to 15666.14163, saving model to vae_kdh_ckpt.54-15666.142.h5
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3791.4244 - vae_r_loss: 3563.0720 - vae_kl_loss: 228.3494 - val_loss: 15666.1416 - val_vae_r_loss: 15445.1299 - val_vae_kl_loss: 221.0100
# Epoch 55/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3584.6041 - vae_r_loss: 3358.0959 - vae_kl_loss: 226.5076WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00055: val_loss improved from 15666.14163 to 15534.26324, saving model to vae_kdh_ckpt.55-15534.263.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3584.5459 - vae_r_loss: 3358.0396 - vae_kl_loss: 226.5057 - val_loss: 15534.2632 - val_vae_r_loss: 15316.7285 - val_vae_kl_loss: 217.5219
# Epoch 56/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3525.7041 - vae_r_loss: 3298.6902 - vae_kl_loss: 227.0144- ETA: 1s - batch: 1553.5000 - size: 32.0000 - loss: 3525.8409 - vae_r_loss: 3298.8372 - vaeWARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00056: val_loss improved from 15534.26324 to 15389.75091, saving model to vae_kdh_ckpt.56-15389.751.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3525.7041 - vae_r_loss: 3298.6902 - vae_kl_loss: 227.0144 - val_loss: 15389.7509 - val_vae_r_loss: 15164.5840 - val_vae_kl_loss: 225.1791
# Epoch 57/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3576.2713 - vae_r_loss: 3346.6240 - vae_kl_loss: 229.6414WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00057: val_loss did not improve from 15389.75091
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3576.2713 - vae_r_loss: 3346.6240 - vae_kl_loss: 229.6414 - val_loss: 15658.9205 - val_vae_r_loss: 15438.5645 - val_vae_kl_loss: 220.3694
# Epoch 58/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3435.6202 - vae_r_loss: 3204.5354 - vae_kl_loss: 231.0864WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00058: val_loss improved from 15389.75091 to 15108.02908, saving model to vae_kdh_ckpt.58-15108.029.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3435.6202 - vae_r_loss: 3204.5354 - vae_kl_loss: 231.0864 - val_loss: 15108.0291 - val_vae_r_loss: 14886.6914 - val_vae_kl_loss: 221.3299
# Epoch 59/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3374.1157 - vae_r_loss: 3147.1116 - vae_kl_loss: 227.0023WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00059: val_loss improved from 15108.02908 to 14828.34054, saving model to vae_kdh_ckpt.59-14828.341.h5
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3374.1157 - vae_r_loss: 3147.1116 - vae_kl_loss: 227.0023 - val_loss: 14828.3405 - val_vae_r_loss: 14608.5850 - val_vae_kl_loss: 219.7598
# Epoch 60/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3400.9008 - vae_r_loss: 3173.2581 - vae_kl_loss: 227.6456WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00060: val_loss improved from 14828.34054 to 14370.37272, saving model to vae_kdh_ckpt.60-14370.373.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3400.9008 - vae_r_loss: 3173.2581 - vae_kl_loss: 227.6456 - val_loss: 14370.3727 - val_vae_r_loss: 14149.2520 - val_vae_kl_loss: 221.1266
# Epoch 61/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3315.8631 - vae_r_loss: 3088.1599 - vae_kl_loss: 227.7075WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00061: val_loss improved from 14370.37272 to 14048.95745, saving model to vae_kdh_ckpt.61-14048.957.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3315.8631 - vae_r_loss: 3088.1599 - vae_kl_loss: 227.7075 - val_loss: 14048.9575 - val_vae_r_loss: 13826.1865 - val_vae_kl_loss: 222.7726
# Epoch 62/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3223.8616 - vae_r_loss: 2995.3787 - vae_kl_loss: 228.4828WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00062: val_loss did not improve from 14048.95745
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3223.8616 - vae_r_loss: 2995.3787 - vae_kl_loss: 228.4828 - val_loss: 14500.6736 - val_vae_r_loss: 14272.8389 - val_vae_kl_loss: 227.8390
# Epoch 63/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3367.1938 - vae_r_loss: 3136.4211 - vae_kl_loss: 230.7683WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00063: val_loss improved from 14048.95745 to 14039.17150, saving model to vae_kdh_ckpt.63-14039.171.h5
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3367.1938 - vae_r_loss: 3136.4211 - vae_kl_loss: 230.7683 - val_loss: 14039.1715 - val_vae_r_loss: 13811.9385 - val_vae_kl_loss: 227.2372
# Epoch 64/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3195.0459 - vae_r_loss: 2965.0176 - vae_kl_loss: 230.0286WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00064: val_loss did not improve from 14039.17150
# 3127/3127 [==============================] - 374s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3195.0459 - vae_r_loss: 2965.0176 - vae_kl_loss: 230.0286 - val_loss: 14197.7753 - val_vae_r_loss: 13976.4434 - val_vae_kl_loss: 221.3321
# Epoch 65/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3107.5892 - vae_r_loss: 2878.5652 - vae_kl_loss: 229.0268WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00065: val_loss improved from 14039.17150 to 13798.38039, saving model to vae_kdh_ckpt.65-13798.380.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3107.5892 - vae_r_loss: 2878.5652 - vae_kl_loss: 229.0268 - val_loss: 13798.3804 - val_vae_r_loss: 13574.4863 - val_vae_kl_loss: 223.8905
# Epoch 66/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3285.9561 - vae_r_loss: 3058.3547 - vae_kl_loss: 227.6014WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00066: val_loss improved from 13798.38039 to 13765.75783, saving model to vae_kdh_ckpt.66-13765.758.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3286.5534 - vae_r_loss: 3058.9524 - vae_kl_loss: 227.6011 - val_loss: 13765.7578 - val_vae_r_loss: 13541.5996 - val_vae_kl_loss: 224.1815
# Epoch 67/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3110.6398 - vae_r_loss: 2880.1772 - vae_kl_loss: 230.4647WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00067: val_loss improved from 13765.75783 to 13612.22912, saving model to vae_kdh_ckpt.67-13612.229.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3110.6398 - vae_r_loss: 2880.1772 - vae_kl_loss: 230.4647 - val_loss: 13612.2291 - val_vae_r_loss: 13385.3076 - val_vae_kl_loss: 226.9121
# Epoch 68/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3057.6909 - vae_r_loss: 2828.5312 - vae_kl_loss: 229.1616WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00068: val_loss improved from 13612.22912 to 13449.69258, saving model to vae_kdh_ckpt.68-13449.693.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3057.6909 - vae_r_loss: 2828.5312 - vae_kl_loss: 229.1616 - val_loss: 13449.6926 - val_vae_r_loss: 13225.8213 - val_vae_kl_loss: 223.8614
# Epoch 69/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3109.9695 - vae_r_loss: 2878.3518 - vae_kl_loss: 231.6177WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00069: val_loss improved from 13449.69258 to 13216.39454, saving model to vae_kdh_ckpt.69-13216.395.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3109.9695 - vae_r_loss: 2878.3518 - vae_kl_loss: 231.6177 - val_loss: 13216.3945 - val_vae_r_loss: 12985.2207 - val_vae_kl_loss: 231.1869
# Epoch 70/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3111.8560 - vae_r_loss: 2879.8093 - vae_kl_loss: 232.0484WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00070: val_loss improved from 13216.39454 to 13194.83106, saving model to vae_kdh_ckpt.70-13194.831.h5
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3111.8560 - vae_r_loss: 2879.8093 - vae_kl_loss: 232.0484 - val_loss: 13194.8311 - val_vae_r_loss: 12964.6279 - val_vae_kl_loss: 230.1966
# Epoch 71/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3021.0626 - vae_r_loss: 2789.3518 - vae_kl_loss: 231.7108WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00071: val_loss improved from 13194.83106 to 13113.62297, saving model to vae_kdh_ckpt.71-13113.623.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3021.0626 - vae_r_loss: 2789.3518 - vae_kl_loss: 231.7108 - val_loss: 13113.6230 - val_vae_r_loss: 12879.4346 - val_vae_kl_loss: 234.1839
# Epoch 72/100000
# ...
#
# Epoch 00728: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 958.3932 - vae_r_loss: 777.8113 - vae_kl_loss: 180.5817 - val_loss: 6703.0635 - val_vae_r_loss: 6521.9761 - val_vae_kl_loss: 181.0823
# Epoch 729/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 962.1777 - vae_r_loss: 780.3204 - vae_kl_loss: 181.8575WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00729: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 962.1777 - vae_r_loss: 780.3204 - vae_kl_loss: 181.8575 - val_loss: 6727.9698 - val_vae_r_loss: 6546.7925 - val_vae_kl_loss: 181.1802
# Epoch 730/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 953.9266 - vae_r_loss: 772.0219 - vae_kl_loss: 181.9046WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00730: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 953.9266 - vae_r_loss: 772.0219 - vae_kl_loss: 181.9046 - val_loss: 6681.0258 - val_vae_r_loss: 6498.4648 - val_vae_kl_loss: 182.5561
# Epoch 731/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 967.2533 - vae_r_loss: 786.1332 - vae_kl_loss: 181.1205WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00731: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 967.2533 - vae_r_loss: 786.1332 - vae_kl_loss: 181.1205 - val_loss: 6706.2350 - val_vae_r_loss: 6524.4634 - val_vae_kl_loss: 181.7659
# Epoch 732/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 972.8732 - vae_r_loss: 791.1473 - vae_kl_loss: 181.7247WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00732: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 972.8732 - vae_r_loss: 791.1473 - vae_kl_loss: 181.7247 - val_loss: 6749.6681 - val_vae_r_loss: 6567.4702 - val_vae_kl_loss: 182.2030
# Epoch 733/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 962.2485 - vae_r_loss: 780.8829 - vae_kl_loss: 181.3672WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00733: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 962.2485 - vae_r_loss: 780.8829 - vae_kl_loss: 181.3672 - val_loss: 6802.5420 - val_vae_r_loss: 6620.1665 - val_vae_kl_loss: 182.3780
# Epoch 734/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 965.4389 - vae_r_loss: 783.7809 - vae_kl_loss: 181.6582WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00734: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 965.4004 - vae_r_loss: 783.7422 - vae_kl_loss: 181.6583 - val_loss: 6858.8221 - val_vae_r_loss: 6676.8291 - val_vae_kl_loss: 181.9928
# Epoch 735/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 968.7460 - vae_r_loss: 786.5562 - vae_kl_loss: 182.1902WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00735: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 968.7460 - vae_r_loss: 786.5562 - vae_kl_loss: 182.1902 - val_loss: 6884.8430 - val_vae_r_loss: 6702.6509 - val_vae_kl_loss: 182.1867
# Epoch 736/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 956.9487 - vae_r_loss: 775.7023 - vae_kl_loss: 181.2481- ETA: 3s - batch: 1542.0000 - size: 32.0000 - loss: 957.0707 - vae_r_loss: WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00736: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 956.9487 - vae_r_loss: 775.7023 - vae_kl_loss: 181.2481 - val_loss: 6868.4961 - val_vae_r_loss: 6687.2383 - val_vae_kl_loss: 181.2565
# Epoch 737/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 965.8929 - vae_r_loss: 784.3924 - vae_kl_loss: 181.5020WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00737: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 965.8929 - vae_r_loss: 784.3924 - vae_kl_loss: 181.5020 - val_loss: 6826.1198 - val_vae_r_loss: 6644.4111 - val_vae_kl_loss: 181.7035
# Epoch 738/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 963.6260 - vae_r_loss: 781.9342 - vae_kl_loss: 181.6912WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00738: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 963.6260 - vae_r_loss: 781.9342 - vae_kl_loss: 181.6912 - val_loss: 6861.5789 - val_vae_r_loss: 6680.2812 - val_vae_kl_loss: 181.2955
# Epoch 739/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 959.0045 - vae_r_loss: 777.7727 - vae_kl_loss: 181.2327WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00739: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 959.1071 - vae_r_loss: 777.8762 - vae_kl_loss: 181.2319 - val_loss: 6796.7437 - val_vae_r_loss: 6614.2998 - val_vae_kl_loss: 182.4492
# Epoch 740/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 956.7698 - vae_r_loss: 775.6677 - vae_kl_loss: 181.1017WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00740: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 956.7698 - vae_r_loss: 775.6677 - vae_kl_loss: 181.1017 - val_loss: 6736.6383 - val_vae_r_loss: 6554.7358 - val_vae_kl_loss: 181.8954
# Epoch 741/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 968.1960 - vae_r_loss: 786.4590 - vae_kl_loss: 181.7364WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00741: val_loss did not improve from 6441.39677
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 968.1960 - vae_r_loss: 786.4590 - vae_kl_loss: 181.7364 - val_loss: 6591.1497 - val_vae_r_loss: 6409.4067 - val_vae_kl_loss: 181.7417
# Epoch 742/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 978.7063 - vae_r_loss: 796.5829 - vae_kl_loss: 182.1229WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00742: val_loss improved from 6441.39677 to 6425.22973, saving model to vae_kdh_ckpt.742-6425.230.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 978.7063 - vae_r_loss: 796.5829 - vae_kl_loss: 182.1229 - val_loss: 6425.2297 - val_vae_r_loss: 6244.1436 - val_vae_kl_loss: 181.0909
# Epoch 743/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 973.9096 - vae_r_loss: 792.2780 - vae_kl_loss: 181.6323WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00743: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 973.8989 - vae_r_loss: 792.2665 - vae_kl_loss: 181.6330 - val_loss: 6488.1595 - val_vae_r_loss: 6305.5806 - val_vae_kl_loss: 182.5826
# Epoch 744/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 966.8431 - vae_r_loss: 785.4911 - vae_kl_loss: 181.3508WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00744: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 966.8431 - vae_r_loss: 785.4911 - vae_kl_loss: 181.3508 - val_loss: 6579.3508 - val_vae_r_loss: 6397.6157 - val_vae_kl_loss: 181.7367
# Epoch 745/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 974.0303 - vae_r_loss: 792.2548 - vae_kl_loss: 181.7760WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00745: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 974.0210 - vae_r_loss: 792.2449 - vae_kl_loss: 181.7766 - val_loss: 6540.7729 - val_vae_r_loss: 6359.5259 - val_vae_kl_loss: 181.2486
# Epoch 746/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 980.0247 - vae_r_loss: 798.0756 - vae_kl_loss: 181.9499WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00746: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 980.0247 - vae_r_loss: 798.0756 - vae_kl_loss: 181.9499 - val_loss: 6530.5589 - val_vae_r_loss: 6348.8394 - val_vae_kl_loss: 181.7180
# Epoch 747/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 966.8591 - vae_r_loss: 785.3215 - vae_kl_loss: 181.5365WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00747: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 966.8591 - vae_r_loss: 785.3215 - vae_kl_loss: 181.5365 - val_loss: 6549.5034 - val_vae_r_loss: 6367.5151 - val_vae_kl_loss: 181.9889
# Epoch 748/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 955.5831 - vae_r_loss: 774.1016 - vae_kl_loss: 181.4821WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00748: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 955.5831 - vae_r_loss: 774.1016 - vae_kl_loss: 181.4821 - val_loss: 6492.0292 - val_vae_r_loss: 6310.4106 - val_vae_kl_loss: 181.6120
# Epoch 749/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 965.1948 - vae_r_loss: 784.0119 - vae_kl_loss: 181.1820WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00749: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 965.1878 - vae_r_loss: 784.0046 - vae_kl_loss: 181.1822 - val_loss: 6438.1314 - val_vae_r_loss: 6256.5356 - val_vae_kl_loss: 181.5963
# Epoch 750/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 975.6226 - vae_r_loss: 794.4211 - vae_kl_loss: 181.2010WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00750: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 975.6226 - vae_r_loss: 794.4211 - vae_kl_loss: 181.2010 - val_loss: 6518.0445 - val_vae_r_loss: 6335.7144 - val_vae_kl_loss: 182.3327
# Epoch 751/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 976.9545 - vae_r_loss: 795.3964 - vae_kl_loss: 181.5577WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00751: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 976.9545 - vae_r_loss: 795.3964 - vae_kl_loss: 181.5577 - val_loss: 6629.4782 - val_vae_r_loss: 6447.3174 - val_vae_kl_loss: 182.1602
# Epoch 752/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 967.7483 - vae_r_loss: 786.2692 - vae_kl_loss: 181.4786WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00752: val_loss did not improve from 6425.22973
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 967.7073 - vae_r_loss: 786.2299 - vae_kl_loss: 181.4769 - val_loss: 6688.4162 - val_vae_r_loss: 6506.5195 - val_vae_kl_loss: 181.8999
# Epoch 753/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 968.6843 - vae_r_loss: 787.5366 - vae_kl_loss: 181.1472WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def plot_latent_space(trained_decoder, pimage, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    image = np.array(image).astype("float32")/255.0
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.5])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_tstr = np.array([0.3])
    X_tvel = np.expand_dims(X_tstr, axis=0)
    X_ttime = np.array([0.1])
    X_tvel = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    X_train = [image, X_tstr, X_tvel, X_ttime]

    x_encoded = VarAE.predict(X_train)*255.0
    # print(x_encoded)
    x_encoded_out = np.squeeze(x_encoded,axis=0)
    # pred_image = np.zeros([160,160,3], np.uint8)
    pred_image = array_to_img(x_encoded_out)
    pred_image = np.array(pred_image)
    pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # pred_img = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # print(type(pred_img))
    # print(pred_image.shape)
    plt.imshow(pred_image)
    # plt.imshow(cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB))
    plt.show()

    origin_image_name = '/home2/kdh/vae/vae_test/2022-12-08-14-30-12-332957.jpg'
    cv2.imwrite('/')
    # plt.xticks(pixel_range, sample_range_x)
    # plt.yticks(pixel_range, sample_range_y)
    # plt.xlabel("z[0]")
    # plt.ylabel("z[1]")

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-30-12-332957.jpg')
# plot_latent_space(decoder, test_img)
# Out:
# Running cells with 'Python 3.6.9 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space(trained_decoder, valid_data, n=50, figsize=15):
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in valid_data:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))

        cv2.imwrite('/home2/kdh/vae/vae_test/'+image_name, image)
        image = np.array(image).astype("float32")/255.0
        # image = image_process.process(image)
        steering_angle, throttle, brake = measurement
        
        image = np.expand_dims(image, axis=0)
        X_tvel = np.array([velocity])
        X_tvel = np.expand_dims(X_tvel, axis=0)
        X_tstr = np.array([steering_angle])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_ttime = np.array([tar_time])
        X_ttime = np.expand_dims(X_ttime, axis=0)
        
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image)
        # plt.imshow(pred_image)
        # plt.show()

        # image_name = '/home2/kdh/vae/vae_test/'+image_name
        pred_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'.jpg'
        gt_tar_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'_gt.jpg'
        cv2.imwrite(pred_image_name, pred_image)
        cv2.imwrite(gt_tar_image_name, tar_image)

        # print(pred_image_name,' done')
        # cv2.imwrite('/')


# save_latent_space(decoder, valid_data[3423:4422])
# Out:
# Running cells with 'Python 3.6.9 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space_diff_steer(trained_decoder, pimage, save_image_name, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    cv2.imwrite('/home2/kdh/vae/vae_diff_steer_test/'+save_image_name+'.jpg', image)
    image = np.array(image).astype("float32")/255.0
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.85])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_ttime = np.array([0.8])
    X_ttime = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    for s in np.arange(0, 0.8, 0.0125):
        X_tstr = np.array([s-0.4])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
        s_str = "{:.3f}".format(s)
        pred_image_name = ('/home2/kdh/vae/vae_diff_steer_test/'
                            +save_image_name
                            +'_'+str(s_str)
                            +'.jpg'
        )
        cv2.imwrite(pred_image_name, pred_image)
    
        

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-35-43-708754.jpg')
# save_latent_space_diff_steer(decoder, test_img, '2022-12-08-14-35-43-708754')
# Out:
# Running cells with 'Python 3.6.9 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
