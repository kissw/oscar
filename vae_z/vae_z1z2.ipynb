# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
# from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Activation, LeakyReLU, Dropout, BatchNormalization, MaxPooling2D, Lambda
from keras.models import Model
from sklearn.metrics import mean_squared_error as mse
from progressbar import ProgressBar
from image_process import ImageProcess
import const, cv2
from drive_data import DriveData
from config import Config

import matplotlib.pyplot as plt
import sys
sys.setrecursionlimit(10**7)
tf.compat.v1.disable_eager_execution()
# Out:
# =======================================================
#                Configuration Settings
# =======================================================
# Neural Net:     	fusion_kdh_jaerock3
# Data Collection:	fusion_kdh_jaerock3
# Run Neural:     	fusion_kdh_jaerock3

# %%
"""
## Dataset
"""
image_process = ImageProcess()
config = Config.neural_net
# data_path = "/mnt/exData/internal_simulation/test/2022-03-08-17-18-14/"
data_path = "/home2/kdh/av/latent/dataset/2022-12-08-14-25-28/"
if data_path[-1] == '/':
    data_path = data_path[:-1]

    loc_slash = data_path.rfind('/')
    if loc_slash != -1: # there is '/' in the data path
        model_name = data_path[loc_slash + 1:] # get folder name
        #model_name = model_name.strip('/')
    else:
        model_name = data_path
csv_path = data_path + '/' + model_name + const.DATA_EXT 
# data = DriveData(csv_path)
print(csv_path)
# data_path = data_path
# data.read()

csv_header = ['image_fname', 
                  'steering_angle', 'throttle', 'brake', 'linux_time', 
                  'vel', 'vel_x', 'vel_y', 'vel_z', 
                  'pos_x', 'pos_y', 'pos_z', 
                  'tar_image_fname', 'tar_steering_angle', 'tar_vel', 'tar_time']

df = pd.read_csv(csv_path, names=csv_header, index_col=False)
num_data = len(df)

bar = ProgressBar()
df_image_names = []
df_measurements = []
df_time_stamps= []
df_velocities= []
df_velocities_xyz= []
df_positions_xyz= []
df_tar_image_names= []
df_tar_steering_angle= []
df_tar_vel= []
df_tar_time= []
for i in bar(range(num_data)): # we don't have a title
    df_image_names.append(df.loc[i]['image_fname'])
    # if Config.data_collection['brake'] is True:
    df_measurements.append((float(df.loc[i]['steering_angle']),
                            float(df.loc[i]['throttle']), 
                            float(df.loc[i]['brake'])))
    df_time_stamps.append(float(df.loc[i]['linux_time']))
    df_velocities.append(float(df.loc[i]['vel']))
    df_velocities_xyz.append((float(df.loc[i]['vel_x']), 
                                float(df.loc[i]['vel_y']), 
                                float(df.loc[i]['vel_z'])))
    df_positions_xyz.append((float(df.loc[i]['pos_x']), 
                                float(df.loc[i]['pos_y']), 
                                float(df.loc[i]['pos_z'])))
    df_tar_image_names.append(df.loc[i]['tar_image_fname'])
    df_tar_steering_angle.append(float(df.loc[i]['tar_steering_angle']))
    df_tar_vel.append(float(df.loc[i]['tar_vel']))
    df_tar_time.append(float(df.loc[i]['tar_time']))
# Out:
# /home2/kdh/av/latent/dataset/2022-12-08-14-25-28/2022-12-08-14-25-28.csv
# 100% |########################################################################|

# %%
samples = list(zip( df_image_names, df_velocities, df_measurements, 
                    df_tar_image_names, df_tar_steering_angle, df_tar_vel, df_tar_time))

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
gpu_config = tf.compat.v1.ConfigProto()
gpu_config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=gpu_config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

sys.setrecursionlimit(10**7)
tf.compat.v1.disable_eager_execution()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12023804806090195141
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 13262979072
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4819479473275824415
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:18:00.0, compute capability: 8.6"
# ]

# %%
def prepare_vae_batch_samples(batch_samples):
    images = []
    steering_angles = []
    vels = []
    tar_images = []
    tar_steering_angles = []
    tar_vels = []
    tar_times = []
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in batch_samples:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        if Config.data_collection['crop'] is not True:
            image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
            tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        image = image_process.process(image)
        tar_image = image_process.process(tar_image)

        vels.append(velocity)
        tar_vels.append(tar_vel)
        tar_times.append(tar_time)
        tar_steering_angles.append(tar_steering_angle)
        # if no brake data in collected data, brake values are dummy
        steering_angle, throttle, brake = measurement
        steering_angles.append(steering_angle)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/image/'+image_name, image)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/tar_image/'+tar_image_name, tar_image)
        # if data == 'train':
        #     cv2.imwrite('/mnt/Data/oscar/train_data/'+image_name, image)
        # print(image.shape)
        images.append(image)
        tar_images.append(tar_image)
        # segimgs.append(segimg)


    return images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times

# %%
"""
## Encoder
"""

"""
## Create a sampling layer
"""
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon


encoder_inputs_img = tf.keras.Input(shape=(160, 160, 3))
encoder_inputs_str = tf.keras.Input(shape=(1))
encoder_inputs_vel = tf.keras.Input(shape=(1))
encoder_inputs_time = tf.keras.Input(shape=(1))
x = layers.Conv2D(24, (5, 5), padding='same', name='conv2d_1')(encoder_inputs_img)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1')(x)

x = layers.Conv2D(36, (5, 5), padding='same', name='conv2d_2')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_2')(x)

x = layers.Conv2D(48, (5, 5), padding='same', name='conv2d_3')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2d_4')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2d_5')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
latent = layers.Flatten()(x)

fc_s1  = layers.Dense(100)(encoder_inputs_str)
fc_s1  = layers.Activation('elu')(fc_s1)
fc_s2  = layers.Dense(50)(fc_s1)
fc_s2  = layers.Activation('elu')(fc_s2)

fc_v1  = layers.Dense(100)(encoder_inputs_vel)
fc_v1  = layers.Activation('elu')(fc_v1)
fc_v2  = layers.Dense(50)(fc_v1)
fc_v2  = layers.Activation('elu')(fc_v2)

fc_t1  = layers.Dense(100)(encoder_inputs_time)
fc_t1  = layers.Activation('elu')(fc_t1)
fc_t2  = layers.Dense(50)(fc_t1)
fc_t2  = layers.Activation('elu')(fc_t2)

conc_i_v_t = layers.concatenate([latent, fc_v2, fc_t2])
fc_1_ivt   = layers.Dense(100)(conc_i_v_t)
fc_1_ivt   = layers.Activation('elu')(fc_1_ivt)

z_mean_ivt = layers.Dense(100, name="z_mean_ivt")(fc_1_ivt)
z_log_var_ivt = layers.Dense(100, name="z_log_var_ivt")(fc_1_ivt)

conc_i_s  = layers.concatenate([z_mean_ivt, z_log_var_ivt, fc_s2])
fc_1_is   = layers.Dense(100)(conc_i_s)
fc_1_is   = layers.Activation('elu')(fc_1_is)

z_mean = layers.Dense(50, name="z_mean")(fc_1_is)
z_log_var = layers.Dense(50, name="z_log_var")(fc_1_is)

encoder_output = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model([ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time], 
                        [ z_mean, z_log_var, encoder_output], 
                        name="encoder")
encoder.summary()
# Out:
# WARNING:tensorflow:From /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 24) 1824        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160, 160, 24) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 160, 160, 24) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# pool2d_1 (MaxPooling2D)         (None, 80, 80, 24)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 80, 80, 36)   21636       pool2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 80, 36)   144         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 80, 80, 36)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# pool2d_2 (MaxPooling2D)         (None, 40, 40, 36)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 40, 40, 48)   43248       pool2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40, 40, 48)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 40, 40, 48)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 64)   27712       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 40, 40, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 40, 40, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          200         input_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          200         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 40, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 50)           5050        activation_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           5050        activation_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 102400)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 102500)       0           flatten[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          10250100    concatenate[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           5050        activation_5[0][0]
# __________________________________________________________________________________________________
# z_mean_ivt (Dense)              (None, 100)          10100       activation_11[0][0]
# __________________________________________________________________________________________________
# z_log_var_ivt (Dense)           (None, 100)          10100       activation_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 250)          0           z_mean_ivt[0][0]
#                                                                  z_log_var_ivt[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100)          25100       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 50)           5050        activation_12[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 50)           5050        activation_12[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 50)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 10,453,542
# Trainable params: 10,453,070
# Non-trainable params: 472
# __________________________________________________________________________________________________

# %%
"""
## Decoder
"""
latent_inputs = tf.keras.Input(shape=(50,))
x = layers.Dense(40 * 40 * 64, activation="elu")(latent_inputs)
x = layers.Reshape((40, 40, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="elu",  padding="same")(x)
x = layers.Conv2DTranspose(36, 3, activation="elu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(24, 3, activation="elu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = tf.keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 102400)            5222400
# _________________________________________________________________
# reshape (Reshape)            (None, 40, 40, 64)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 40, 40, 64)        36928
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 80, 80, 36)        20772
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 160, 160, 24)      7800
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 160, 160, 3)       651
# =================================================================
# Total params: 5,288,551
# Trainable params: 5,288,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
## VAE
"""
# [ encoder_inputs_img, encoder_inputs_str,
# encoder_inputs_vel, encoder_inputs_time], 
# [ z_mean_ivt, z_log_var_ivt, z_mean_is, z_log_var_is, 
# encoder_output_ivt, encoder_output_is]
model_input = [ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time]
model_output = decoder(encoder_output)

VarAE=Model(model_input, model_output)
# VarAE.run_eagerly = True

# %%
"""
Data generator
"""
from sklearn.model_selection import train_test_split

def _generator(samples, batch_size=config['batch_size']):
    num_samples = len(samples)
    while True: # Loop forever so the generator never terminates
        for offset in range(0, (num_samples//batch_size)*batch_size, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times = prepare_vae_batch_samples(batch_samples)

            X_img = np.array(images).astype("float32")/255.0
            X_tvel = np.array(tar_vels).astype("float32")
            X_tstr = np.array(tar_steering_angles).astype("float32")
            X_ttime = np.array(tar_times).astype("float32")

            y_train = np.array(tar_images).astype("float32")/255.0
            # if config['num_outputs'] == 1:
            # y_train = np.array(segimg)
            # print(y_train.max())
            # y_train = np.repeat(y_train[..., np.newaxis], 1, -1)/y_train.max()
            X_train = [X_img, X_tstr, X_tvel, X_ttime]
            # print(X_tstr, X_tvel, X_ttime)
            # print(y_train)
            # print(y_train.shape)
            yield X_train, y_train

train_data, valid_data = train_test_split(samples, test_size=config['validation_rate'])

train_generator = _generator(train_data, config['batch_size'])
valid_generator = _generator(valid_data, config['batch_size'])

# %%
"""
VAE loss
"""
optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.0000001)
# optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.00000001)
#                                  learning_rate=0.000005,decay=0.0000000001
r_loss_factor=160*160*100   # This is a Hyperparameter

def vae_r_loss(y_true, y_pred):    ## MSE
    r_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_pred), axis=[1,2,3])
    return r_loss_factor * r_loss

def vae_kl_loss(y_true, y_pred):   ## KL-Divergence
    kl_loss=( -0.5 * tf.keras.backend.sum(1+z_log_var 
                - tf.keras.backend.square(z_mean) 
                - tf.keras.backend.exp(z_log_var), axis=1)
    )
    return kl_loss

def vae_loss(y_true, y_pred): 
    r_loss=vae_r_loss(y_true, y_pred) #Loss of Decoder
    kl_loss = vae_kl_loss(y_true, y_pred) #Loss of Encoder
    return r_loss + kl_loss #Sum of these two


VarAE.compile(optimizer=optimizer,
                loss= vae_loss, 
                metrics=[vae_r_loss, vae_kl_loss])
# VarAE.summary()
#  vae_r_loss: 12.6586 - vae_kl_loss: 2251744.5000 
#  val_loss: 50649853.6174 
#  val_vae_r_loss: 28.6742 - val_vae_kl_loss: 50649896.0000

# %%
"""
## Train the VAE
"""
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.python.framework.ops import disable_eager_execution

        # checkpoint
callbacks = []
#weight_filename = self.data_path + '_' + Config.config_yaml_name \
#    + '_N' + str(config['network_type']) + '_ckpt'
model_ckpt_name = "vae_kdh_z1z2"
checkpoint = ModelCheckpoint(model_ckpt_name +'_ckpt.{epoch:02d}-{val_loss:.3f}.h5',
                                monitor='val_loss', 
                                verbose=1, save_best_only=True, mode='min')
callbacks.append(checkpoint)

# early stopping
patience = 1000
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, 
                            verbose=1, mode='min')
# callbacks.append(earlystop)

# validation_steps = len(valid_data)//config['batch_size']
# print(validation_steps)
train_hist = VarAE.fit( train_generator,  
                        steps_per_epoch=len(train_data)//config['batch_size'], 
                        epochs=100000, 
                        validation_data=valid_generator,
                        validation_steps=len(valid_data)//config['batch_size'],
                        # shuffle=True,
                        verbose=1, 
                        callbacks=callbacks, 
                        use_multiprocessing=True,
                        workers=48
                        )
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 16229.1608 - vae_r_loss: 15531.0703 - vae_kl_loss: 698.0774WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 18619.98234, saving model to vae_kdh_z1z2_ckpt.01-18619.982.h5
# 3127/3127 [==============================] - 383s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 16229.1608 - vae_r_loss: 15531.0703 - vae_kl_loss: 698.0774 - val_loss: 18619.9823 - val_vae_r_loss: 18282.0098 - val_vae_kl_loss: 337.9777
# Epoch 2/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 9003.1304 - vae_r_loss: 8664.6064 - vae_kl_loss: 338.5311WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00002: val_loss improved from 18619.98234 to 18130.14447, saving model to vae_kdh_z1z2_ckpt.02-18130.144.h5
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 9003.1304 - vae_r_loss: 8664.6064 - vae_kl_loss: 338.5311 - val_loss: 18130.1445 - val_vae_r_loss: 17839.0586 - val_vae_kl_loss: 291.0860
# Epoch 3/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7514.7870 - vae_r_loss: 7204.7095 - vae_kl_loss: 310.0782WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00003: val_loss did not improve from 18130.14447
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7514.7870 - vae_r_loss: 7204.7095 - vae_kl_loss: 310.0782 - val_loss: 18262.5814 - val_vae_r_loss: 17990.5176 - val_vae_kl_loss: 272.0741
# Epoch 4/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6678.9432 - vae_r_loss: 6400.1655 - vae_kl_loss: 278.7725WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00004: val_loss improved from 18130.14447 to 17991.99381, saving model to vae_kdh_z1z2_ckpt.04-17991.994.h5
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6678.9432 - vae_r_loss: 6400.1655 - vae_kl_loss: 278.7725 - val_loss: 17991.9938 - val_vae_r_loss: 17742.1543 - val_vae_kl_loss: 249.8285
# Epoch 5/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6168.3870 - vae_r_loss: 5902.6768 - vae_kl_loss: 265.7120WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00005: val_loss did not improve from 17991.99381
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6168.3870 - vae_r_loss: 5902.6768 - vae_kl_loss: 265.7120 - val_loss: 18104.2003 - val_vae_r_loss: 17862.5898 - val_vae_kl_loss: 241.6343
# Epoch 6/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5914.7853 - vae_r_loss: 5660.3462 - vae_kl_loss: 254.4404WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00006: val_loss did not improve from 17991.99381
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5914.7853 - vae_r_loss: 5660.3462 - vae_kl_loss: 254.4404 - val_loss: 18314.0682 - val_vae_r_loss: 18072.0605 - val_vae_kl_loss: 242.0117
# Epoch 7/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5852.1401 - vae_r_loss: 5600.6460 - vae_kl_loss: 251.4961- ETA: 9s - batch: 1506.0000 -WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00007: val_loss improved from 17991.99381 to 17621.59670, saving model to vae_kdh_z1z2_ckpt.07-17621.597.h5
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5852.1401 - vae_r_loss: 5600.6460 - vae_kl_loss: 251.4961 - val_loss: 17621.5967 - val_vae_r_loss: 17389.4355 - val_vae_kl_loss: 232.1640
# Epoch 8/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 5645.9790 - vae_r_loss: 5402.1821 - vae_kl_loss: 243.7970WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00008: val_loss improved from 17621.59670 to 17209.90760, saving model to vae_kdh_z1z2_ckpt.08-17209.908.h5
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5647.2565 - vae_r_loss: 5403.4678 - vae_kl_loss: 243.7893 - val_loss: 17209.9076 - val_vae_r_loss: 16985.7285 - val_vae_kl_loss: 224.1751
# Epoch 9/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5611.2090 - vae_r_loss: 5370.5381 - vae_kl_loss: 240.6755WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00009: val_loss did not improve from 17209.90760
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5611.2090 - vae_r_loss: 5370.5381 - vae_kl_loss: 240.6755 - val_loss: 17617.7090 - val_vae_r_loss: 17390.5410 - val_vae_kl_loss: 227.1473
# Epoch 10/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6184.1138 - vae_r_loss: 5927.5464 - vae_kl_loss: 256.5649- ETA: 4s - batch: 1537.0000 - size: 32.0000 - loss: 6196.8571 - vae_WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00010: val_loss did not improve from 17209.90760
# 3127/3127 [==============================] - 364s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6184.1138 - vae_r_loss: 5927.5464 - vae_kl_loss: 256.5649 - val_loss: 17359.3784 - val_vae_r_loss: 17133.9668 - val_vae_kl_loss: 225.4024
# Epoch 11/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5442.3242 - vae_r_loss: 5204.3926 - vae_kl_loss: 237.9320  ETA: 10sWARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00011: val_loss did not improve from 17209.90760
# 3127/3127 [==============================] - 364s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5442.3242 - vae_r_loss: 5204.3926 - vae_kl_loss: 237.9320 - val_loss: 17225.1105 - val_vae_r_loss: 16990.9629 - val_vae_kl_loss: 234.1387
# Epoch 12/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5314.6455 - vae_r_loss: 5079.5210 - vae_kl_loss: 235.1323WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00012: val_loss did not improve from 17209.90760
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5314.6455 - vae_r_loss: 5079.5210 - vae_kl_loss: 235.1323 - val_loss: 17324.2130 - val_vae_r_loss: 17099.2969 - val_vae_kl_loss: 224.9147
# Epoch 13/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5439.6153 - vae_r_loss: 5204.5381 - vae_kl_loss: 235.0781WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00013: val_loss improved from 17209.90760 to 16962.09430, saving model to vae_kdh_z1z2_ckpt.13-16962.094.h5
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5439.6153 - vae_r_loss: 5204.5381 - vae_kl_loss: 235.0781 - val_loss: 16962.0943 - val_vae_r_loss: 16737.5664 - val_vae_kl_loss: 224.5233
# Epoch 14/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5048.3482 - vae_r_loss: 4815.7241 - vae_kl_loss: 232.6236WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00014: val_loss improved from 16962.09430 to 16949.16857, saving model to vae_kdh_z1z2_ckpt.14-16949.169.h5
# 3127/3127 [==============================] - 363s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5048.3482 - vae_r_loss: 4815.7241 - vae_kl_loss: 232.6236 - val_loss: 16949.1686 - val_vae_r_loss: 16727.3320 - val_vae_kl_loss: 221.8456
# Epoch 15/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 5211.8833 - vae_r_loss: 4979.5005 - vae_kl_loss: 232.3855WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00015: val_loss improved from 16949.16857 to 16931.19424, saving model to vae_kdh_z1z2_ckpt.15-16931.194.h5
# 3127/3127 [==============================] - 365s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5216.4935 - vae_r_loss: 4984.1138 - vae_kl_loss: 232.3829 - val_loss: 16931.1942 - val_vae_r_loss: 16712.3066 - val_vae_kl_loss: 218.9015
# Epoch 16/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5124.0256 - vae_r_loss: 4891.5005 - vae_kl_loss: 232.5278WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00016: val_loss did not improve from 16931.19424
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5124.0256 - vae_r_loss: 4891.5005 - vae_kl_loss: 232.5278 - val_loss: 17240.7533 - val_vae_r_loss: 17019.1172 - val_vae_kl_loss: 221.6327
# Epoch 17/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5015.1508 - vae_r_loss: 4784.7583 - vae_kl_loss: 230.3960WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00017: val_loss improved from 16931.19424 to 16908.88386, saving model to vae_kdh_z1z2_ckpt.17-16908.884.h5
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5015.1508 - vae_r_loss: 4784.7583 - vae_kl_loss: 230.3960 - val_loss: 16908.8839 - val_vae_r_loss: 16694.4805 - val_vae_kl_loss: 214.3852
# Epoch 18/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5045.8826 - vae_r_loss: 4816.4321 - vae_kl_loss: 229.4470WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00018: val_loss did not improve from 16908.88386
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5045.8826 - vae_r_loss: 4816.4321 - vae_kl_loss: 229.4470 - val_loss: 17044.0997 - val_vae_r_loss: 16823.0391 - val_vae_kl_loss: 221.0592
# Epoch 19/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5113.3046 - vae_r_loss: 4882.7695 - vae_kl_loss: 230.5369WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00019: val_loss improved from 16908.88386 to 16259.29972, saving model to vae_kdh_z1z2_ckpt.19-16259.300.h5
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5113.3046 - vae_r_loss: 4882.7695 - vae_kl_loss: 230.5369 - val_loss: 16259.2997 - val_vae_r_loss: 16040.5137 - val_vae_kl_loss: 218.7949
# Epoch 20/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4963.5266 - vae_r_loss: 4736.1763 - vae_kl_loss: 227.3508WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00020: val_loss did not improve from 16259.29972
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4963.5266 - vae_r_loss: 4736.1763 - vae_kl_loss: 227.3508 - val_loss: 16557.6927 - val_vae_r_loss: 16336.9414 - val_vae_kl_loss: 220.7421
# Epoch 21/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4998.4304 - vae_r_loss: 4771.1201 - vae_kl_loss: 227.3101WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00021: val_loss did not improve from 16259.29972
# 3127/3127 [==============================] - 367s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4998.4304 - vae_r_loss: 4771.1201 - vae_kl_loss: 227.3101 - val_loss: 16438.0774 - val_vae_r_loss: 16222.6553 - val_vae_kl_loss: 215.4038
# Epoch 22/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5072.2753 - vae_r_loss: 4846.4229 - vae_kl_loss: 225.8546WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00022: val_loss did not improve from 16259.29972
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5072.2753 - vae_r_loss: 4846.4229 - vae_kl_loss: 225.8546 - val_loss: 16535.6476 - val_vae_r_loss: 16323.0195 - val_vae_kl_loss: 212.6189
# Epoch 23/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4973.5599 - vae_r_loss: 4745.2271 - vae_kl_loss: 228.3348WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00023: val_loss did not improve from 16259.29972
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4973.5599 - vae_r_loss: 4745.2271 - vae_kl_loss: 228.3348 - val_loss: 16342.2726 - val_vae_r_loss: 16120.5986 - val_vae_kl_loss: 221.6746
# Epoch 24/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4736.6115 - vae_r_loss: 4509.5205 - vae_kl_loss: 227.0907WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00024: val_loss improved from 16259.29972 to 16019.41058, saving model to vae_kdh_z1z2_ckpt.24-16019.411.h5
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4736.6115 - vae_r_loss: 4509.5205 - vae_kl_loss: 227.0907 - val_loss: 16019.4106 - val_vae_r_loss: 15795.2568 - val_vae_kl_loss: 224.1591
# Epoch 25/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4676.1507 - vae_r_loss: 4448.3262 - vae_kl_loss: 227.8182WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00025: val_loss improved from 16019.41058 to 15022.38491, saving model to vae_kdh_z1z2_ckpt.25-15022.385.h5
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4676.1507 - vae_r_loss: 4448.3262 - vae_kl_loss: 227.8182 - val_loss: 15022.3849 - val_vae_r_loss: 14799.5850 - val_vae_kl_loss: 222.8010
# Epoch 26/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 4637.8093 - vae_r_loss: 4408.4189 - vae_kl_loss: 229.3899WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00026: val_loss improved from 15022.38491 to 14846.99467, saving model to vae_kdh_z1z2_ckpt.26-14846.995.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4637.2703 - vae_r_loss: 4407.8779 - vae_kl_loss: 229.3920 - val_loss: 14846.9947 - val_vae_r_loss: 14626.5908 - val_vae_kl_loss: 220.3927
# Epoch 27/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4331.1947 - vae_r_loss: 4102.6733 - vae_kl_loss: 228.5185WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00027: val_loss did not improve from 14846.99467
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4331.1947 - vae_r_loss: 4102.6733 - vae_kl_loss: 228.5185 - val_loss: 15026.6562 - val_vae_r_loss: 14806.1348 - val_vae_kl_loss: 220.5114
# Epoch 28/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4258.2584 - vae_r_loss: 4029.8235 - vae_kl_loss: 228.4339WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00028: val_loss did not improve from 14846.99467
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4258.2584 - vae_r_loss: 4029.8235 - vae_kl_loss: 228.4339 - val_loss: 14965.7170 - val_vae_r_loss: 14744.4102 - val_vae_kl_loss: 221.3060
# Epoch 29/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4105.5238 - vae_r_loss: 3876.9639 - vae_kl_loss: 228.5568WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00029: val_loss improved from 14846.99467 to 14679.94150, saving model to vae_kdh_z1z2_ckpt.29-14679.942.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4105.5238 - vae_r_loss: 3876.9639 - vae_kl_loss: 228.5568 - val_loss: 14679.9415 - val_vae_r_loss: 14449.5137 - val_vae_kl_loss: 230.4254
# Epoch 30/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4192.9023 - vae_r_loss: 3960.8413 - vae_kl_loss: 232.0609WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00030: val_loss improved from 14679.94150 to 14628.28135, saving model to vae_kdh_z1z2_ckpt.30-14628.281.h5
# 3127/3127 [==============================] - 364s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4192.9023 - vae_r_loss: 3960.8413 - vae_kl_loss: 232.0609 - val_loss: 14628.2814 - val_vae_r_loss: 14400.2236 - val_vae_kl_loss: 228.0443
# Epoch 31/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4196.5676 - vae_r_loss: 3964.0662 - vae_kl_loss: 232.5002WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00031: val_loss improved from 14628.28135 to 13838.30133, saving model to vae_kdh_z1z2_ckpt.31-13838.301.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4196.5676 - vae_r_loss: 3964.0662 - vae_kl_loss: 232.5002 - val_loss: 13838.3013 - val_vae_r_loss: 13616.6436 - val_vae_kl_loss: 221.6678
# Epoch 32/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 4059.1582 - vae_r_loss: 3827.0566 - vae_kl_loss: 232.0988WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00032: val_loss improved from 13838.30133 to 13717.53530, saving model to vae_kdh_z1z2_ckpt.32-13717.535.h5
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4058.8269 - vae_r_loss: 3826.7244 - vae_kl_loss: 232.1000 - val_loss: 13717.5353 - val_vae_r_loss: 13488.9951 - val_vae_kl_loss: 228.5333
# Epoch 33/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3971.5704 - vae_r_loss: 3736.4512 - vae_kl_loss: 235.1170WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00033: val_loss did not improve from 13717.53530
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3971.1009 - vae_r_loss: 3735.9812 - vae_kl_loss: 235.1172 - val_loss: 13781.9023 - val_vae_r_loss: 13545.8057 - val_vae_kl_loss: 236.0956
# Epoch 34/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4139.2243 - vae_r_loss: 3905.4919 - vae_kl_loss: 233.7326WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00034: val_loss improved from 13717.53530 to 13250.78033, saving model to vae_kdh_z1z2_ckpt.34-13250.780.h5
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4139.2243 - vae_r_loss: 3905.4919 - vae_kl_loss: 233.7326 - val_loss: 13250.7803 - val_vae_r_loss: 13023.3447 - val_vae_kl_loss: 227.4273
# Epoch 35/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3768.2934 - vae_r_loss: 3534.0002 - vae_kl_loss: 234.2943WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00035: val_loss improved from 13250.78033 to 13248.83806, saving model to vae_kdh_z1z2_ckpt.35-13248.838.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3768.2934 - vae_r_loss: 3534.0002 - vae_kl_loss: 234.2943 - val_loss: 13248.8381 - val_vae_r_loss: 13020.4688 - val_vae_kl_loss: 228.3657
# Epoch 36/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3818.7564 - vae_r_loss: 3586.4404 - vae_kl_loss: 232.3130WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00036: val_loss improved from 13248.83806 to 12824.97374, saving model to vae_kdh_z1z2_ckpt.36-12824.974.h5
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3818.7906 - vae_r_loss: 3586.4739 - vae_kl_loss: 232.3139 - val_loss: 12824.9737 - val_vae_r_loss: 12596.4775 - val_vae_kl_loss: 228.5017
# Epoch 37/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3656.6507 - vae_r_loss: 3421.5361 - vae_kl_loss: 235.1183WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00037: val_loss did not improve from 12824.97374
# 3127/3127 [==============================] - 365s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3656.3445 - vae_r_loss: 3421.2295 - vae_kl_loss: 235.1188 - val_loss: 13043.4713 - val_vae_r_loss: 12815.9316 - val_vae_kl_loss: 227.5458
# Epoch 38/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3850.0492 - vae_r_loss: 3617.1118 - vae_kl_loss: 232.9350WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00038: val_loss did not improve from 12824.97374
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3850.0492 - vae_r_loss: 3617.1118 - vae_kl_loss: 232.9350 - val_loss: 13364.5484 - val_vae_r_loss: 13131.8076 - val_vae_kl_loss: 232.7400
# Epoch 39/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3639.8763 - vae_r_loss: 3407.1379 - vae_kl_loss: 232.7351WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00039: val_loss improved from 12824.97374 to 12598.47680, saving model to vae_kdh_z1z2_ckpt.39-12598.477.h5
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3639.8334 - vae_r_loss: 3407.0994 - vae_kl_loss: 232.7305 - val_loss: 12598.4768 - val_vae_r_loss: 12369.4287 - val_vae_kl_loss: 229.0490
# Epoch 40/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3545.0232 - vae_r_loss: 3309.6482 - vae_kl_loss: 235.3736WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00040: val_loss improved from 12598.47680 to 12549.62282, saving model to vae_kdh_z1z2_ckpt.40-12549.623.h5
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3545.0232 - vae_r_loss: 3309.6482 - vae_kl_loss: 235.3736 - val_loss: 12549.6228 - val_vae_r_loss: 12315.8438 - val_vae_kl_loss: 233.7842
# Epoch 41/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3553.6904 - vae_r_loss: 3319.7795 - vae_kl_loss: 233.9134WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00041: val_loss did not improve from 12549.62282
# 3127/3127 [==============================] - 364s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3553.3952 - vae_r_loss: 3319.4849 - vae_kl_loss: 233.9129 - val_loss: 12606.4170 - val_vae_r_loss: 12369.5586 - val_vae_kl_loss: 236.8511
# Epoch 42/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3487.7386 - vae_r_loss: 3254.2817 - vae_kl_loss: 233.4616WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00042: val_loss improved from 12549.62282 to 12117.60938, saving model to vae_kdh_z1z2_ckpt.42-12117.609.h5
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3487.7386 - vae_r_loss: 3254.2817 - vae_kl_loss: 233.4616 - val_loss: 12117.6094 - val_vae_r_loss: 11883.9355 - val_vae_kl_loss: 233.6763
# Epoch 43/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3440.1838 - vae_r_loss: 3207.1289 - vae_kl_loss: 233.0576WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00043: val_loss did not improve from 12117.60938
# 3127/3127 [==============================] - 365s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3440.1838 - vae_r_loss: 3207.1289 - vae_kl_loss: 233.0576 - val_loss: 12127.4202 - val_vae_r_loss: 11892.5576 - val_vae_kl_loss: 234.8562
# Epoch 44/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3476.5509 - vae_r_loss: 3241.1890 - vae_kl_loss: 235.3611WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00044: val_loss improved from 12117.60938 to 11699.76421, saving model to vae_kdh_z1z2_ckpt.44-11699.764.h5
# 3127/3127 [==============================] - 364s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3476.5509 - vae_r_loss: 3241.1890 - vae_kl_loss: 235.3611 - val_loss: 11699.7642 - val_vae_r_loss: 11466.4258 - val_vae_kl_loss: 233.3352
# Epoch 45/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3308.9177 - vae_r_loss: 3072.5156 - vae_kl_loss: 236.4053WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00045: val_loss did not improve from 11699.76421
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3308.9177 - vae_r_loss: 3072.5156 - vae_kl_loss: 236.4053 - val_loss: 11901.4692 - val_vae_r_loss: 11666.6094 - val_vae_kl_loss: 234.8450
# Epoch 46/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3381.4226 - vae_r_loss: 3146.7861 - vae_kl_loss: 234.6425WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00046: val_loss improved from 11699.76421 to 11297.55320, saving model to vae_kdh_z1z2_ckpt.46-11297.553.h5
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3381.4226 - vae_r_loss: 3146.7861 - vae_kl_loss: 234.6425 - val_loss: 11297.5532 - val_vae_r_loss: 11063.0713 - val_vae_kl_loss: 234.4791
# Epoch 47/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3384.8631 - vae_r_loss: 3150.4583 - vae_kl_loss: 234.4039WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00047: val_loss did not improve from 11297.55320
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3384.8631 - vae_r_loss: 3150.4583 - vae_kl_loss: 234.4039 - val_loss: 11324.6628 - val_vae_r_loss: 11092.1553 - val_vae_kl_loss: 232.5126
# Epoch 48/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3344.9224 - vae_r_loss: 3110.1995 - vae_kl_loss: 234.7208WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00048: val_loss improved from 11297.55320 to 11174.05729, saving model to vae_kdh_z1z2_ckpt.48-11174.057.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3344.9224 - vae_r_loss: 3110.1995 - vae_kl_loss: 234.7208 - val_loss: 11174.0573 - val_vae_r_loss: 10938.1729 - val_vae_kl_loss: 235.8851
# Epoch 49/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3331.6897 - vae_r_loss: 3098.3635 - vae_kl_loss: 233.3222- ETA: 1s - batch: 1555.0000 - size: 32.0000 - loss: 3332.1773 - vae_r_loss: 3098.8440 - vae_kWARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00049: val_loss improved from 11174.05729 to 11163.87018, saving model to vae_kdh_z1z2_ckpt.49-11163.870.h5
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3331.6897 - vae_r_loss: 3098.3635 - vae_kl_loss: 233.3222 - val_loss: 11163.8702 - val_vae_r_loss: 10926.8975 - val_vae_kl_loss: 236.9666
# Epoch 50/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3162.8970 - vae_r_loss: 2928.5750 - vae_kl_loss: 234.3220WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00050: val_loss did not improve from 11163.87018
# 3127/3127 [==============================] - 366s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3162.8970 - vae_r_loss: 2928.5750 - vae_kl_loss: 234.3220 - val_loss: 11232.5246 - val_vae_r_loss: 10999.1729 - val_vae_kl_loss: 233.3499
# Epoch 51/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3185.1339 - vae_r_loss: 2949.5791 - vae_kl_loss: 235.5534WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00051: val_loss improved from 11163.87018 to 10969.11675, saving model to vae_kdh_z1z2_ckpt.51-10969.117.h5
# 3127/3127 [==============================] - 364s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3185.3553 - vae_r_loss: 2949.7957 - vae_kl_loss: 235.5580 - val_loss: 10969.1167 - val_vae_r_loss: 10732.8193 - val_vae_kl_loss: 236.3029
# Epoch 52/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3124.9901 - vae_r_loss: 2892.4963 - vae_kl_loss: 232.4948WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00052: val_loss improved from 10969.11675 to 10693.66767, saving model to vae_kdh_z1z2_ckpt.52-10693.668.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3124.9901 - vae_r_loss: 2892.4963 - vae_kl_loss: 232.4948 - val_loss: 10693.6677 - val_vae_r_loss: 10461.9512 - val_vae_kl_loss: 231.7087
# Epoch 53/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3123.4553 - vae_r_loss: 2889.2107 - vae_kl_loss: 234.2411WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00053: val_loss improved from 10693.66767 to 10484.22779, saving model to vae_kdh_z1z2_ckpt.53-10484.228.h5
# 3127/3127 [==============================] - 367s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3123.4553 - vae_r_loss: 2889.2107 - vae_kl_loss: 234.2411 - val_loss: 10484.2278 - val_vae_r_loss: 10247.4160 - val_vae_kl_loss: 236.8190
# Epoch 54/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3138.0453 - vae_r_loss: 2903.8010 - vae_kl_loss: 234.2456WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00054: val_loss did not improve from 10484.22779
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3138.0453 - vae_r_loss: 2903.8010 - vae_kl_loss: 234.2456 - val_loss: 10609.0197 - val_vae_r_loss: 10373.1914 - val_vae_kl_loss: 235.8386
# Epoch 55/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3258.0757 - vae_r_loss: 3022.6160 - vae_kl_loss: 235.4595WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00055: val_loss improved from 10484.22779 to 10439.89074, saving model to vae_kdh_z1z2_ckpt.55-10439.891.h5
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3258.0757 - vae_r_loss: 3022.6160 - vae_kl_loss: 235.4595 - val_loss: 10439.8907 - val_vae_r_loss: 10202.2246 - val_vae_kl_loss: 237.6601
# Epoch 56/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3057.3512 - vae_r_loss: 2823.8015 - vae_kl_loss: 233.5528WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00056: val_loss did not improve from 10439.89074
# 3127/3127 [==============================] - 364s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3057.3512 - vae_r_loss: 2823.8015 - vae_kl_loss: 233.5528 - val_loss: 10472.7593 - val_vae_r_loss: 10239.2666 - val_vae_kl_loss: 233.5000
# Epoch 57/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3188.9975 - vae_r_loss: 2955.2048 - vae_kl_loss: 233.7949WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00057: val_loss improved from 10439.89074 to 10222.92198, saving model to vae_kdh_z1z2_ckpt.57-10222.922.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3188.7802 - vae_r_loss: 2954.9832 - vae_kl_loss: 233.7991 - val_loss: 10222.9220 - val_vae_r_loss: 9991.2549 - val_vae_kl_loss: 231.6684
# Epoch 58/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3103.9523 - vae_r_loss: 2870.8040 - vae_kl_loss: 233.1455WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00058: val_loss improved from 10222.92198 to 10130.85935, saving model to vae_kdh_z1z2_ckpt.58-10130.859.h5
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3103.9523 - vae_r_loss: 2870.8040 - vae_kl_loss: 233.1455 - val_loss: 10130.8593 - val_vae_r_loss: 9898.4414 - val_vae_kl_loss: 232.4172
# Epoch 59/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3001.1054 - vae_r_loss: 2769.3860 - vae_kl_loss: 231.7207WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00059: val_loss improved from 10130.85935 to 10056.49271, saving model to vae_kdh_z1z2_ckpt.59-10056.493.h5
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3001.1054 - vae_r_loss: 2769.3860 - vae_kl_loss: 231.7207 - val_loss: 10056.4927 - val_vae_r_loss: 9825.1465 - val_vae_kl_loss: 231.3520
# Epoch 60/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3079.8571 - vae_r_loss: 2846.2546 - vae_kl_loss: 233.6059WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00060: val_loss improved from 10056.49271 to 9963.56431, saving model to vae_kdh_z1z2_ckpt.60-9963.564.h5
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3079.8571 - vae_r_loss: 2846.2546 - vae_kl_loss: 233.6059 - val_loss: 9963.5643 - val_vae_r_loss: 9731.5938 - val_vae_kl_loss: 231.9681
# Epoch 61/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3108.9959 - vae_r_loss: 2876.0217 - vae_kl_loss: 232.9717WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00061: val_loss did not improve from 9963.56431
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3108.9959 - vae_r_loss: 2876.0217 - vae_kl_loss: 232.9717 - val_loss: 10055.2773 - val_vae_r_loss: 9824.3818 - val_vae_kl_loss: 230.9029
# Epoch 62/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 2917.3990 - vae_r_loss: 2684.6702 - vae_kl_loss: 232.7301WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00062: val_loss did not improve from 9963.56431
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2917.2470 - vae_r_loss: 2684.5161 - vae_kl_loss: 232.7321 - val_loss: 10086.2001 - val_vae_r_loss: 9853.5078 - val_vae_kl_loss: 232.6942
# Epoch 63/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2910.0713 - vae_r_loss: 2678.6040 - vae_kl_loss: 231.4699WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00063: val_loss did not improve from 9963.56431
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2910.0713 - vae_r_loss: 2678.6040 - vae_kl_loss: 231.4699 - val_loss: 10056.4255 - val_vae_r_loss: 9825.1084 - val_vae_kl_loss: 231.3210
# Epoch 64/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2930.5388 - vae_r_loss: 2697.3901 - vae_kl_loss: 233.1494WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00064: val_loss improved from 9963.56431 to 9762.47943, saving model to vae_kdh_z1z2_ckpt.64-9762.479.h5
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2930.5388 - vae_r_loss: 2697.3901 - vae_kl_loss: 233.1494 - val_loss: 9762.4794 - val_vae_r_loss: 9528.7461 - val_vae_kl_loss: 233.7322
# Epoch 65/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2815.1513 - vae_r_loss: 2583.8081 - vae_kl_loss: 231.3458- ETA: 6s - batch: 1521.5000 - size: 32.00WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00065: val_loss improved from 9762.47943 to 9559.88288, saving model to vae_kdh_z1z2_ckpt.65-9559.883.h5
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2815.1513 - vae_r_loss: 2583.8081 - vae_kl_loss: 231.3458 - val_loss: 9559.8829 - val_vae_r_loss: 9330.0107 - val_vae_kl_loss: 229.8716
# Epoch 66/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2870.9956 - vae_r_loss: 2639.1174 - vae_kl_loss: 231.8780WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00066: val_loss did not improve from 9559.88288
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2870.9956 - vae_r_loss: 2639.1174 - vae_kl_loss: 231.8780 - val_loss: 9624.7641 - val_vae_r_loss: 9392.5400 - val_vae_kl_loss: 232.2350
# Epoch 67/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2922.9276 - vae_r_loss: 2689.8835 - vae_kl_loss: 233.0435WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00067: val_loss improved from 9559.88288 to 9511.63822, saving model to vae_kdh_z1z2_ckpt.67-9511.638.h5
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2922.9276 - vae_r_loss: 2689.8835 - vae_kl_loss: 233.0435 - val_loss: 9511.6382 - val_vae_r_loss: 9281.4668 - val_vae_kl_loss: 230.1743
# Epoch 68/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2758.1755 - vae_r_loss: 2527.0471 - vae_kl_loss: 231.1276WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00068: val_loss improved from 9511.63822 to 9489.81215, saving model to vae_kdh_z1z2_ckpt.68-9489.812.h5
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2758.1755 - vae_r_loss: 2527.0471 - vae_kl_loss: 231.1276 - val_loss: 9489.8122 - val_vae_r_loss: 9259.6816 - val_vae_kl_loss: 230.1290
# Epoch 69/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2802.0053 - vae_r_loss: 2571.5410 - vae_kl_loss: 230.4649WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00069: val_loss did not improve from 9489.81215
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2802.0053 - vae_r_loss: 2571.5410 - vae_kl_loss: 230.4649 - val_loss: 9555.6320 - val_vae_r_loss: 9322.9893 - val_vae_kl_loss: 232.6369
# Epoch 70/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2791.5532 - vae_r_loss: 2560.1299 - vae_kl_loss: 231.4208WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00070: val_loss did not improve from 9489.81215
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2791.5532 - vae_r_loss: 2560.1299 - vae_kl_loss: 231.4208 - val_loss: 9826.0147 - val_vae_r_loss: 9597.0156 - val_vae_kl_loss: 228.9947
# Epoch 71/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2759.5205 - vae_r_loss: 2527.2039 - vae_kl_loss: 232.3163WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# ...
#
# Epoch 00735: val_loss did not improve from 4795.74854
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1018.7386 - vae_r_loss: 837.3357 - vae_kl_loss: 181.4015 - val_loss: 4908.9446 - val_vae_r_loss: 4727.5562 - val_vae_kl_loss: 181.3872
# Epoch 736/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1033.0933 - vae_r_loss: 851.5736 - vae_kl_loss: 181.5193WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00736: val_loss did not improve from 4795.74854
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1033.0933 - vae_r_loss: 851.5736 - vae_kl_loss: 181.5193 - val_loss: 4876.7815 - val_vae_r_loss: 4695.5576 - val_vae_kl_loss: 181.2182
# Epoch 737/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1028.1676 - vae_r_loss: 846.9255 - vae_kl_loss: 181.2418WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00737: val_loss did not improve from 4795.74854
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1028.1676 - vae_r_loss: 846.9255 - vae_kl_loss: 181.2418 - val_loss: 4861.5192 - val_vae_r_loss: 4680.1279 - val_vae_kl_loss: 181.3948
# Epoch 738/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1033.3356 - vae_r_loss: 851.9361 - vae_kl_loss: 181.3991WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00738: val_loss did not improve from 4795.74854
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1033.3356 - vae_r_loss: 851.9361 - vae_kl_loss: 181.3991 - val_loss: 4866.1429 - val_vae_r_loss: 4684.7002 - val_vae_kl_loss: 181.4470
# Epoch 739/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1030.6601 - vae_r_loss: 849.2516 - vae_kl_loss: 181.4079WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00739: val_loss did not improve from 4795.74854
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1030.6601 - vae_r_loss: 849.2516 - vae_kl_loss: 181.4079 - val_loss: 4842.3385 - val_vae_r_loss: 4661.5371 - val_vae_kl_loss: 180.8044
# Epoch 740/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1031.9988 - vae_r_loss: 850.9412 - vae_kl_loss: 181.0568WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00740: val_loss did not improve from 4795.74854
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1031.9988 - vae_r_loss: 850.9412 - vae_kl_loss: 181.0568 - val_loss: 4839.6510 - val_vae_r_loss: 4658.6289 - val_vae_kl_loss: 181.0207
# Epoch 741/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1042.8812 - vae_r_loss: 861.5062 - vae_kl_loss: 181.3738WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00741: val_loss improved from 4795.74854 to 4774.63711, saving model to vae_kdh_z1z2_ckpt.741-4774.637.h5
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1042.8812 - vae_r_loss: 861.5062 - vae_kl_loss: 181.3738 - val_loss: 4774.6371 - val_vae_r_loss: 4593.8203 - val_vae_kl_loss: 180.8163
# Epoch 742/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1037.8735 - vae_r_loss: 856.5582 - vae_kl_loss: 181.3147WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00742: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 371s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1037.8735 - vae_r_loss: 856.5582 - vae_kl_loss: 181.3147 - val_loss: 4802.6041 - val_vae_r_loss: 4621.9810 - val_vae_kl_loss: 180.6246
# Epoch 743/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 1040.0267 - vae_r_loss: 858.4062 - vae_kl_loss: 181.6209WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00743: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 369s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1040.0808 - vae_r_loss: 858.4598 - vae_kl_loss: 181.6215 - val_loss: 4793.3863 - val_vae_r_loss: 4613.1938 - val_vae_kl_loss: 180.1920
# Epoch 744/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1031.7234 - vae_r_loss: 850.0927 - vae_kl_loss: 181.6298WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00744: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1031.7234 - vae_r_loss: 850.0927 - vae_kl_loss: 181.6298 - val_loss: 4788.9043 - val_vae_r_loss: 4607.7808 - val_vae_kl_loss: 181.1217
# Epoch 745/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1026.7177 - vae_r_loss: 845.4131 - vae_kl_loss: 181.3045WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00745: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1026.7177 - vae_r_loss: 845.4131 - vae_kl_loss: 181.3045 - val_loss: 4803.2639 - val_vae_r_loss: 4622.0903 - val_vae_kl_loss: 181.1736
# Epoch 746/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1017.8256 - vae_r_loss: 836.7172 - vae_kl_loss: 181.1091WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00746: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1017.8256 - vae_r_loss: 836.7172 - vae_kl_loss: 181.1091 - val_loss: 4861.3311 - val_vae_r_loss: 4680.7842 - val_vae_kl_loss: 180.5450
# Epoch 747/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1012.5777 - vae_r_loss: 832.0222 - vae_kl_loss: 180.5559WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00747: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1012.5777 - vae_r_loss: 832.0222 - vae_kl_loss: 180.5559 - val_loss: 4887.3681 - val_vae_r_loss: 4706.5137 - val_vae_kl_loss: 180.8542
# Epoch 748/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1020.6172 - vae_r_loss: 840.0099 - vae_kl_loss: 180.6069WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00748: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 368s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1020.6172 - vae_r_loss: 840.0099 - vae_kl_loss: 180.6069 - val_loss: 4915.3839 - val_vae_r_loss: 4734.2285 - val_vae_kl_loss: 181.1567
# Epoch 749/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1019.1825 - vae_r_loss: 838.0881 - vae_kl_loss: 181.0941WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00749: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1019.1825 - vae_r_loss: 838.0881 - vae_kl_loss: 181.0941 - val_loss: 4960.9603 - val_vae_r_loss: 4780.4531 - val_vae_kl_loss: 180.5055
# Epoch 750/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1029.4232 - vae_r_loss: 847.7745 - vae_kl_loss: 181.6481WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00750: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 365s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1029.4232 - vae_r_loss: 847.7745 - vae_kl_loss: 181.6481 - val_loss: 5016.9518 - val_vae_r_loss: 4836.1172 - val_vae_kl_loss: 180.8336
# Epoch 751/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 1038.8590 - vae_r_loss: 857.2445 - vae_kl_loss: 181.6157WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00751: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 364s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1038.8486 - vae_r_loss: 857.2357 - vae_kl_loss: 181.6142 - val_loss: 5059.9406 - val_vae_r_loss: 4878.9819 - val_vae_kl_loss: 180.9592
# Epoch 752/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 1042.6430 - vae_r_loss: 861.2983 - vae_kl_loss: 181.3441WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00752: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 365s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1042.7110 - vae_r_loss: 861.3664 - vae_kl_loss: 181.3440 - val_loss: 5094.5090 - val_vae_r_loss: 4914.2085 - val_vae_kl_loss: 180.2986
# Epoch 753/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 1032.4077 - vae_r_loss: 851.0595 - vae_kl_loss: 181.3490WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00753: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 365s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1032.3821 - vae_r_loss: 851.0345 - vae_kl_loss: 181.3483 - val_loss: 5037.5662 - val_vae_r_loss: 4856.7725 - val_vae_kl_loss: 180.7968
# Epoch 754/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1029.5469 - vae_r_loss: 848.2350 - vae_kl_loss: 181.3114WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00754: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1029.5469 - vae_r_loss: 848.2350 - vae_kl_loss: 181.3114 - val_loss: 4962.5584 - val_vae_r_loss: 4782.4136 - val_vae_kl_loss: 180.1454
# Epoch 755/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1033.5695 - vae_r_loss: 852.7131 - vae_kl_loss: 180.8561WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00755: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 363s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1033.5695 - vae_r_loss: 852.7131 - vae_kl_loss: 180.8561 - val_loss: 5014.8207 - val_vae_r_loss: 4834.7852 - val_vae_kl_loss: 180.0342
# Epoch 756/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1024.6711 - vae_r_loss: 844.1208 - vae_kl_loss: 180.5506WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00756: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1024.6711 - vae_r_loss: 844.1208 - vae_kl_loss: 180.5506 - val_loss: 5002.8902 - val_vae_r_loss: 4822.5020 - val_vae_kl_loss: 180.3850
# Epoch 757/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1037.1153 - vae_r_loss: 855.6774 - vae_kl_loss: 181.4381WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00757: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1037.1153 - vae_r_loss: 855.6774 - vae_kl_loss: 181.4381 - val_loss: 5019.0323 - val_vae_r_loss: 4837.8081 - val_vae_kl_loss: 181.2210
# Epoch 758/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 1027.1626 - vae_r_loss: 846.0552 - vae_kl_loss: 181.1070WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00758: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 364s 116ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1027.1335 - vae_r_loss: 846.0269 - vae_kl_loss: 181.1064 - val_loss: 5017.5726 - val_vae_r_loss: 4837.3130 - val_vae_kl_loss: 180.2583
# Epoch 759/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1023.5900 - vae_r_loss: 842.4017 - vae_kl_loss: 181.1865WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00759: val_loss did not improve from 4774.63711
# 3127/3127 [==============================] - 367s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 1023.5900 - vae_r_loss: 842.4017 - vae_kl_loss: 181.1865 - val_loss: 5022.9464 - val_vae_r_loss: 4842.1523 - val_vae_kl_loss: 180.8000
# Epoch 760/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 1010.5687 - vae_r_loss: 829.8431 - vae_kl_loss: 180.7253WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def plot_latent_space(trained_decoder, pimage, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    image = np.array(image).astype("float32")/255.0
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.5])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_tstr = np.array([0.3])
    X_tvel = np.expand_dims(X_tstr, axis=0)
    X_ttime = np.array([0.1])
    X_tvel = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    X_train = [image, X_tstr, X_tvel, X_ttime]

    x_encoded = VarAE.predict(X_train)*255.0
    # print(x_encoded)
    x_encoded_out = np.squeeze(x_encoded,axis=0)
    # pred_image = np.zeros([160,160,3], np.uint8)
    pred_image = array_to_img(x_encoded_out)
    pred_image = np.array(pred_image)
    pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # pred_img = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # print(type(pred_img))
    # print(pred_image.shape)
    plt.imshow(pred_image)
    # plt.imshow(cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB))
    plt.show()

    origin_image_name = '/home2/kdh/vae/vae_test/2022-12-08-14-30-12-332957.jpg'
    cv2.imwrite('/')
    # plt.xticks(pixel_range, sample_range_x)
    # plt.yticks(pixel_range, sample_range_y)
    # plt.xlabel("z[0]")
    # plt.ylabel("z[1]")

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-30-12-332957.jpg')
# plot_latent_space(decoder, test_img)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space(trained_decoder, valid_data, n=50, figsize=15):
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in valid_data:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))

        cv2.imwrite('/home2/kdh/vae/vae_test/'+image_name, image)
        image = np.array(image).astype("float32")/255.0
        # image = image_process.process(image)
        steering_angle, throttle, brake = measurement
        
        image = np.expand_dims(image, axis=0)
        X_tvel = np.array([velocity])
        X_tvel = np.expand_dims(X_tvel, axis=0)
        X_tstr = np.array([steering_angle])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_ttime = np.array([tar_time])
        X_ttime = np.expand_dims(X_ttime, axis=0)
        
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image)
        # plt.imshow(pred_image)
        # plt.show()

        # image_name = '/home2/kdh/vae/vae_test/'+image_name
        pred_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'.jpg'
        gt_tar_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'_gt.jpg'
        cv2.imwrite(pred_image_name, pred_image)
        cv2.imwrite(gt_tar_image_name, tar_image)

        # print(pred_image_name,' done')
        # cv2.imwrite('/')


# save_latent_space(decoder, valid_data[3423:4422])

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space_diff_steer(trained_decoder, pimage, save_image_name, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    cv2.imwrite('/home2/kdh/vae/vae_diff_steer_test/'+save_image_name+'.jpg', image)
    image = np.array(image).astype("float32")/255.0
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.85])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_ttime = np.array([0.8])
    X_ttime = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    for s in np.arange(0, 0.8, 0.0125):
        X_tstr = np.array([s-0.4])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
        s_str = "{:.3f}".format(s)
        pred_image_name = ('/home2/kdh/vae/vae_diff_steer_test/'
                            +save_image_name
                            +'_'+str(s_str)
                            +'.jpg'
        )
        cv2.imwrite(pred_image_name, pred_image)
    
        

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-35-43-708754.jpg')
# save_latent_space_diff_steer(decoder, test_img, '2022-12-08-14-35-43-708754')
