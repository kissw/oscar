# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
# from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Activation, LeakyReLU, Dropout, BatchNormalization, MaxPooling2D, Lambda
from keras.models import Model
from sklearn.metrics import mean_squared_error as mse
from progressbar import ProgressBar
from image_process import ImageProcess
import const, cv2
from drive_data import DriveData
from config import Config

import matplotlib.pyplot as plt
import sys
config = Config.neural_net
sys.setrecursionlimit(10**7)
tf.compat.v1.experimental.output_all_intermediates(True)
tf.compat.v1.disable_eager_execution()

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
gpu_config = tf.compat.v1.ConfigProto()
gpu_config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=gpu_config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
"""
## Encoder
"""

"""
## Create a sampling layer
"""
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

encoder_inputs_img = tf.keras.Input(batch_shape=(10, 1, 160, 160, 3))
encoder_inputs_str = tf.keras.Input(batch_shape=(10, 1, 1))
encoder_inputs_vel = tf.keras.Input(batch_shape=(10, 1, 1))
encoder_inputs_time = tf.keras.Input(batch_shape=(10, 1, 1))
x = layers.TimeDistributed(layers.Conv2D(24, (5, 5), padding='same', name='conv2d_1'))(encoder_inputs_img)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1'))(x)
# x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1'))(x)
x = layers.TimeDistributed(layers.Conv2D(36, (5, 5), padding='same', name='conv2d_2'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_2'))(x)
x = layers.TimeDistributed(layers.Conv2D(48, (5, 5), padding='same', name='conv2d_3'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.Conv2D(64, (3, 3), padding='same', name='conv2d_4'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.Conv2D(64, (3, 3), padding='same', name='conv2d_5'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
latent = layers.TimeDistributed(layers.Flatten())(x)
latent = layers.TimeDistributed(layers.Dense(500))(latent)
latent = layers.TimeDistributed(layers.LayerNormalization())(latent)
latent = layers.TimeDistributed(layers.Activation('tanh'))(latent)
fc_s1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_str)
fc_s1  = layers.TimeDistributed(layers.BatchNormalization())(fc_s1)
fc_s1  = layers.TimeDistributed(layers.Activation('elu'))(fc_s1)
fc_s2  = layers.TimeDistributed(layers.Dense(50))(fc_s1)
fc_s2  = layers.TimeDistributed(layers.BatchNormalization())(fc_s2)
fc_s2  = layers.TimeDistributed(layers.Activation('elu'))(fc_s2)
fc_v1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_vel)
fc_v1  = layers.TimeDistributed(layers.BatchNormalization())(fc_v1)
fc_v1  = layers.TimeDistributed(layers.Activation('elu'))(fc_v1)
fc_v2  = layers.TimeDistributed(layers.Dense(50))(fc_v1)
fc_v2  = layers.TimeDistributed(layers.BatchNormalization())(fc_v2)
fc_v2  = layers.TimeDistributed(layers.Activation('elu'))(fc_v2)
fc_t1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_time)
fc_t1  = layers.TimeDistributed(layers.BatchNormalization())(fc_t1)
fc_t1  = layers.TimeDistributed(layers.Activation('elu'))(fc_t1)
fc_t2  = layers.TimeDistributed(layers.Dense(50))(fc_t1)
fc_t2  = layers.TimeDistributed(layers.BatchNormalization())(fc_t2)
fc_t2  = layers.TimeDistributed(layers.Activation('elu'))(fc_t2)
conc_1 = layers.concatenate([latent, fc_s2, fc_v2, fc_t2])
bilstm = layers.Bidirectional(layers.LSTM(500, batch_size=10, stateful=True))(conc_1)
# bilstm = layers.Bidirectional(layers.LSTM(500, input_shape=(1000, 1), batch_size=10, stateful=True))(conc_1)
fc_1   = layers.Dense(500)(bilstm)
fc_1   = layers.Activation('elu')(fc_1)
fc_2   = layers.Dense(100)(fc_1)
x   = layers.Activation('elu')(fc_2)
z_mean = layers.Dense(50, name="z_mean")(x)
z_log_var = layers.Dense(50, name="z_log_var")(x)
encoder_output = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model([ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time], 
                        [z_mean, z_log_var, encoder_output], 
                        name="encoder")

"""
## Decoder
"""
latent_inputs = tf.keras.Input(shape=(50,))
x = layers.Dense(40 * 40 * 64, activation="elu")(latent_inputs)
x = layers.Reshape((40, 40, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="elu",  padding="same")(x)
x = layers.Conv2DTranspose(36, 3, activation="elu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(24, 3, activation="elu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = tf.keras.Model(latent_inputs, decoder_outputs, name="decoder")

"""
## VAE
"""
model_input = [ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time]
model_output = decoder(encoder_output)

VarAE=Model(model_input, model_output)
VarAE.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(10, 1, 160, 160, 3 0
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (10, 1, 160, 160, 24 1824        input_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (10, 1, 160, 160, 24 96          time_distributed_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (10, 1, 160, 160, 24 0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (10, 1, 80, 80, 24)  0           time_distributed_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (10, 1, 80, 80, 36)  21636       time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (10, 1, 80, 80, 36)  144         time_distributed_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (10, 1, 80, 80, 36)  0           time_distributed_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (10, 1, 40, 40, 36)  0           time_distributed_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (10, 1, 40, 40, 48)  43248       time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (10, 1, 40, 40, 48)  192         time_distributed_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (10, 1, 40, 40, 48)  0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (10, 1, 40, 40, 64)  27712       time_distributed_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (10, 1, 40, 40, 64)  256         time_distributed_33[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (10, 1, 40, 40, 64)  0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (10, 1, 40, 40, 64)  36928       time_distributed_35[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(10, 1, 1)]         0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(10, 1, 1)]         0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(10, 1, 1)]         0
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (10, 1, 40, 40, 64)  256         time_distributed_36[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (10, 1, 100)         200         input_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (10, 1, 100)         200         input_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (10, 1, 100)         200         input_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (10, 1, 40, 40, 64)  0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (10, 1, 100)         400         time_distributed_43[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (10, 1, 100)         400         time_distributed_49[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (10, 1, 100)         400         time_distributed_55[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (10, 1, 102400)      0           time_distributed_38[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (10, 1, 100)         0           time_distributed_44[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (10, 1, 100)         0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (10, 1, 100)         0           time_distributed_56[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (10, 1, 500)         51200500    time_distributed_39[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (10, 1, 50)          5050        time_distributed_45[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (10, 1, 50)          5050        time_distributed_51[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (10, 1, 50)          5050        time_distributed_57[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (10, 1, 500)         1000        time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (10, 1, 50)          200         time_distributed_46[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (10, 1, 50)          200         time_distributed_52[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (10, 1, 50)          200         time_distributed_58[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (10, 1, 500)         0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (10, 1, 50)          0           time_distributed_47[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (10, 1, 50)          0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (10, 1, 50)          0           time_distributed_59[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (10, 1, 650)         0           time_distributed_42[0][0]
#                                                                  time_distributed_48[0][0]
#                                                                  time_distributed_54[0][0]
#                                                                  time_distributed_60[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (10, 1000)           4604000     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (10, 500)            500500      bidirectional[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (10, 500)            0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (10, 100)            50100       activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (10, 100)            0           dense_10[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (10, 50)             5050        activation_19[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (10, 50)             5050        activation_19[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (10, 50)             0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 160, 160, 3)  5288551     sampling[0][0]
# ==================================================================================================
# Total params: 61,804,593
# Trainable params: 61,803,221
# Non-trainable params: 1,372
# __________________________________________________________________________________________________

# %%
"""
## Dataset
"""
image_process = ImageProcess()
config = Config.neural_net
# data_path = "/mnt/exData/internal_simulation/test/2022-03-08-17-18-14/"
data_path = "/home2/kdh/vae/2022-12-08-14-25-29/"
if data_path[-1] == '/':
    data_path = data_path[:-1]

    loc_slash = data_path.rfind('/')
    if loc_slash != -1: # there is '/' in the data path
        model_name = data_path[loc_slash + 1:] # get folder name
        #model_name = model_name.strip('/')
    else:
        model_name = data_path
csv_path = data_path + '/' + model_name + const.DATA_EXT 
# data = DriveData(csv_path)
print(csv_path)
# data_path = data_path
# data.read()

csv_header = ['image_fname', 
                  'steering_angle', 'throttle', 'brake', 'linux_time', 
                  'vel', 'vel_x', 'vel_y', 'vel_z', 
                  'pos_x', 'pos_y', 'pos_z', 
                  'tar_image_fname', 'tar_steering_angle', 'tar_vel', 'tar_time']

df = pd.read_csv(csv_path, names=csv_header, index_col=False)
num_data = len(df)

bar = ProgressBar()
df_image_names = []
df_measurements = []
df_time_stamps= []
df_velocities= []
df_velocities_xyz= []
df_positions_xyz= []
df_tar_image_names= []
df_tar_steering_angle= []
df_tar_vel= []
df_tar_time= []
for i in bar(range(num_data)): # we don't have a title
    df_image_names.append(df.loc[i]['image_fname'])
    # if Config.data_collection['brake'] is True:
    df_measurements.append((float(df.loc[i]['steering_angle']),
                            float(df.loc[i]['throttle']), 
                            float(df.loc[i]['brake'])))
    df_time_stamps.append(float(df.loc[i]['linux_time']))
    df_velocities.append(float(df.loc[i]['vel']))
    df_velocities_xyz.append((float(df.loc[i]['vel_x']), 
                                float(df.loc[i]['vel_y']), 
                                float(df.loc[i]['vel_z'])))
    df_positions_xyz.append((float(df.loc[i]['pos_x']), 
                                float(df.loc[i]['pos_y']), 
                                float(df.loc[i]['pos_z'])))
    df_tar_image_names.append(df.loc[i]['tar_image_fname'])
    df_tar_steering_angle.append(float(df.loc[i]['tar_steering_angle']))
    df_tar_vel.append(float(df.loc[i]['tar_vel']))
    df_tar_time.append(float(df.loc[i]['tar_time']))
# Out:
# /home2/kdh/vae/2022-12-08-14-25-29/2022-12-08-14-25-29.csv
# 100% |########################################################################|

# %%
samples = list(zip( df_image_names, df_velocities, df_measurements, 
                    df_tar_image_names, df_tar_steering_angle, df_tar_vel, df_tar_time))

# %%
def prepare_vae_batch_samples(batch_samples):
    images = []
    steering_angles = []
    vels = []
    tar_images = []
    tar_steering_angles = []
    tar_vels = []
    tar_times = []


    batch_images = []
    batch_steering_angles = []
    batch_vels = []
    batch_tar_images = []
    batch_tar_steering_angles = []
    batch_tar_vels = []
    batch_tar_times = []
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in batch_samples:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        if Config.data_collection['crop'] is not True:
            image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
            tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        image = image_process.process(image)
        tar_image = image_process.process(tar_image)

        batch_vels.append(velocity)
        batch_tar_vels.append(tar_vel)
        batch_tar_times.append(tar_time)
        batch_tar_steering_angles.append(tar_steering_angle)
        # if no brake data in collected data, brake values are dummy
        steering_angle, throttle, brake = measurement
        batch_steering_angles.append(steering_angle)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/image/'+image_name, image)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/tar_image/'+tar_image_name, tar_image)
        # if data == 'train':
        #     cv2.imwrite('/mnt/Data/oscar/train_data/'+image_name, image)
        # print(image.shape)
        batch_images.append(image)
        tar_images.append(tar_image)
        # segimgs.append(segimg)


    images.append(batch_images)
    steering_angles.append(batch_steering_angles)
    vels.append(batch_vels)
    # tar_images.append(batch_tar_images)
    tar_steering_angles.append(batch_tar_steering_angles)
    tar_vels.append(batch_tar_vels)
    tar_times.append(batch_tar_times)
    # print(np.array(tar_times).shape)
    return images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times

# %%
"""
Data generator
"""
from sklearn.model_selection import train_test_split

def _generator(samples, batch_size=10):
    num_samples = len(samples)
    while True: # Loop forever so the generator never terminates
        for offset in range(0, (num_samples//batch_size)*batch_size, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times = prepare_vae_batch_samples(batch_samples)

            X_img = np.array(images).astype("float32")/255.0
            X_tvel = np.array(tar_vels).astype("float32")
            X_tstr = np.array(tar_steering_angles).astype("float32")
            X_ttime = np.array(tar_times).astype("float32")

            X_img = X_img.swapaxes(0,1)
            
            X_tvel = X_tvel.swapaxes(0,1)
            X_tstr = X_tstr.swapaxes(0,1)
            X_ttime = X_ttime.swapaxes(0,1)
            X_tvel = X_tvel.reshape(-1, 1, 1)
            X_tstr = X_tstr.reshape(-1, 1, 1)
            X_ttime = X_ttime.reshape(-1, 1, 1)
            y_train = np.array(tar_images).astype("float32")/255.0
            # print(X_img.shape)
            # print(X_tvel.shape)
            # print(y_train.shape)
            # if config['num_outputs'] == 1:
            # y_train = np.array(segimg)
            # print(y_train.max())
            # y_train = np.repeat(y_train[..., np.newaxis], 1, -1)/y_train.max()
            X_train = [X_img, X_tstr, X_tvel, X_ttime]
            # print(X_tstr, X_tvel, X_ttime)
            # print(y_train)
            # print(y_train.shape)
            yield X_train, y_train

train_data, valid_data = train_test_split(samples, test_size=config['validation_rate'])

train_generator = _generator(train_data, 10)
valid_generator = _generator(valid_data, 10)

# %%
"""
VAE loss
"""
optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.0000001)
# optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.00000001)
#                                  learning_rate=0.000005,decay=0.0000000001
r_loss_factor=160*160*100   # This is a Hyperparameter

def vae_r_loss(y_true, y_pred):    ## MSE
    r_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_pred), axis=[1,2,3])
    return r_loss_factor * r_loss

def vae_kl_loss(y_true, y_pred):   ## KL-Divergence
    kl_loss=( -0.5 * tf.keras.backend.sum(1+z_log_var 
                - tf.keras.backend.square(z_mean) 
                - tf.keras.backend.exp(z_log_var), axis=1)
    )
    return kl_loss

def vae_loss(y_true, y_pred): 
    r_loss=vae_r_loss(y_true, y_pred) #Loss of Decoder
    kl_loss = vae_kl_loss(y_true, y_pred) #Loss of Encoder
    return r_loss + kl_loss #Sum of these two


VarAE.compile(optimizer=optimizer,
                loss= vae_loss, 
                metrics=[vae_r_loss, vae_kl_loss])
# VarAE.summary()
#  vae_r_loss: 12.6586 - vae_kl_loss: 2251744.5000 
#  val_loss: 50649853.6174 
#  val_vae_r_loss: 28.6742 - val_vae_kl_loss: 50649896.0000

# %%
"""
## Train the VAE
"""
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.python.framework.ops import disable_eager_execution

        # checkpoint
callbacks = []
#weight_filename = self.data_path + '_' + Config.config_yaml_name \
#    + '_N' + str(config['network_type']) + '_ckpt'
model_ckpt_name = "vae_kdh_batch10_timestep1_2"
checkpoint = ModelCheckpoint(model_ckpt_name +'_ckpt.{epoch:02d}-{val_loss:.3f}.h5',
                                monitor='val_loss', 
                                verbose=1, save_best_only=True, mode='min')
callbacks.append(checkpoint)

# early stopping
patience = 5000
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, 
                            verbose=1, mode='min')
# callbacks.append(earlystop)

# validation_steps = len(valid_data)//config['batch_size']
# print(validation_steps)
train_hist = VarAE.fit( train_generator,  
                        steps_per_epoch=len(train_data)//10, 
                        epochs=100000, 
                        validation_data=valid_generator,
                        validation_steps=len(valid_data)//10,
                        # shuffle=True,
                        verbose=1, 
                        callbacks=callbacks, 
                        use_multiprocessing=True,
                        workers=48
                        )
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 11103.0068 - vae_r_loss: 10814.9346 - vae_kl_loss: 288.0438WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 20213.94057, saving model to vae_kdh_batch10_timestep1_2_ckpt.01-20213.941.h5
# 11700/11700 [==============================] - 570s 48ms/step - batch: 5849.5000 - size: 10.0000 - loss: 11103.0068 - vae_r_loss: 10814.9346 - vae_kl_loss: 288.0438 - val_loss: 20213.9406 - val_vae_r_loss: 19992.3613 - val_vae_kl_loss: 221.5557
# Epoch 2/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 5646.1266 - vae_r_loss: 5432.0474 - vae_kl_loss: 214.0758-WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00002: val_loss improved from 20213.94057 to 18558.12357, saving model to vae_kdh_batch10_timestep1_2_ckpt.02-18558.124.h5
# 11700/11700 [==============================] - 566s 48ms/step - batch: 5849.5000 - size: 10.0000 - loss: 5646.1266 - vae_r_loss: 5432.0474 - vae_kl_loss: 214.0758 - val_loss: 18558.1236 - val_vae_r_loss: 18361.6758 - val_vae_kl_loss: 196.4306
# Epoch 3/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 4903.5380 - vae_r_loss: 4703.8638 - vae_kl_loss: 199.6754WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00003: val_loss improved from 18558.12357 to 16714.66312, saving model to vae_kdh_batch10_timestep1_2_ckpt.03-16714.663.h5
# 11700/11700 [==============================] - 558s 48ms/step - batch: 5849.5000 - size: 10.0000 - loss: 4903.3269 - vae_r_loss: 4703.6533 - vae_kl_loss: 199.6748 - val_loss: 16714.6631 - val_vae_r_loss: 16530.8770 - val_vae_kl_loss: 183.8060
# Epoch 4/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 4221.5730 - vae_r_loss: 4027.0991 - vae_kl_loss: 194.4729WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00004: val_loss improved from 16714.66312 to 16311.03741, saving model to vae_kdh_batch10_timestep1_2_ckpt.04-16311.037.h5
# 11700/11700 [==============================] - 542s 46ms/step - batch: 5849.5000 - size: 10.0000 - loss: 4221.7279 - vae_r_loss: 4027.2556 - vae_kl_loss: 194.4716 - val_loss: 16311.0374 - val_vae_r_loss: 16127.5977 - val_vae_kl_loss: 183.4790
# Epoch 5/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 3885.3692 - vae_r_loss: 3693.1829 - vae_kl_loss: 192.1783WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00005: val_loss did not improve from 16311.03741
# 11700/11700 [==============================] - 431s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3885.4448 - vae_r_loss: 3693.2590 - vae_kl_loss: 192.1780 - val_loss: 17064.2585 - val_vae_r_loss: 16880.3301 - val_vae_kl_loss: 183.9328
# Epoch 6/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 3528.8269 - vae_r_loss: 3338.9375 - vae_kl_loss: 189.8955WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00006: val_loss improved from 16311.03741 to 15088.76803, saving model to vae_kdh_batch10_timestep1_2_ckpt.06-15088.768.h5
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3528.7024 - vae_r_loss: 3338.8132 - vae_kl_loss: 189.8953 - val_loss: 15088.7680 - val_vae_r_loss: 14906.8740 - val_vae_kl_loss: 181.9047
# Epoch 7/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 3320.6762 - vae_r_loss: 3133.2734 - vae_kl_loss: 187.4048WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00007: val_loss did not improve from 15088.76803
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3320.6762 - vae_r_loss: 3133.2734 - vae_kl_loss: 187.4048 - val_loss: 16599.1031 - val_vae_r_loss: 16417.9805 - val_vae_kl_loss: 181.1154
# Epoch 8/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 3214.2674 - vae_r_loss: 3028.3181 - vae_kl_loss: 185.9534WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00008: val_loss did not improve from 15088.76803
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3214.2674 - vae_r_loss: 3028.3181 - vae_kl_loss: 185.9534 - val_loss: 16737.6658 - val_vae_r_loss: 16557.3496 - val_vae_kl_loss: 180.3173
# Epoch 9/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 3110.3696 - vae_r_loss: 2924.4260 - vae_kl_loss: 185.9529WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00009: val_loss did not improve from 15088.76803
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3110.3696 - vae_r_loss: 2924.4260 - vae_kl_loss: 185.9529 - val_loss: 16381.8290 - val_vae_r_loss: 16200.7266 - val_vae_kl_loss: 181.1092
# Epoch 10/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2971.6456 - vae_r_loss: 2787.9294 - vae_kl_loss: 183.7135WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00010: val_loss improved from 15088.76803 to 13829.05843, saving model to vae_kdh_batch10_timestep1_2_ckpt.10-13829.058.h5
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2971.4828 - vae_r_loss: 2787.7673 - vae_kl_loss: 183.7129 - val_loss: 13829.0584 - val_vae_r_loss: 13653.4795 - val_vae_kl_loss: 175.5837
# Epoch 11/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2846.5558 - vae_r_loss: 2662.9001 - vae_kl_loss: 183.6528WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00011: val_loss improved from 13829.05843 to 13186.69353, saving model to vae_kdh_batch10_timestep1_2_ckpt.11-13186.694.h5
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2846.5558 - vae_r_loss: 2662.9001 - vae_kl_loss: 183.6528 - val_loss: 13186.6935 - val_vae_r_loss: 13010.6494 - val_vae_kl_loss: 176.0544
# Epoch 12/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2748.7000 - vae_r_loss: 2564.9136 - vae_kl_loss: 183.7891WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00012: val_loss did not improve from 13186.69353
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2748.7000 - vae_r_loss: 2564.9136 - vae_kl_loss: 183.7891 - val_loss: 13780.4948 - val_vae_r_loss: 13604.4639 - val_vae_kl_loss: 176.0519
# Epoch 13/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2656.2200 - vae_r_loss: 2473.1150 - vae_kl_loss: 183.1053WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00013: val_loss improved from 13186.69353 to 12288.78969, saving model to vae_kdh_batch10_timestep1_2_ckpt.13-12288.790.h5
# 11700/11700 [==============================] - 412s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2656.2200 - vae_r_loss: 2473.1150 - vae_kl_loss: 183.1053 - val_loss: 12288.7897 - val_vae_r_loss: 12110.4980 - val_vae_kl_loss: 178.3033
# Epoch 14/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2631.7887 - vae_r_loss: 2449.0574 - vae_kl_loss: 182.7287WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00014: val_loss improved from 12288.78969 to 12108.86791, saving model to vae_kdh_batch10_timestep1_2_ckpt.14-12108.868.h5
# 11700/11700 [==============================] - 414s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2631.7887 - vae_r_loss: 2449.0574 - vae_kl_loss: 182.7287 - val_loss: 12108.8679 - val_vae_r_loss: 11931.8857 - val_vae_kl_loss: 176.9719
# Epoch 15/100000
# 11698/11700 [============================>.] - ETA: 0s - batch: 5848.5000 - size: 10.0000 - loss: 2514.0432 - vae_r_loss: 2331.8611 - vae_kl_loss: 182.1725WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00015: val_loss did not improve from 12108.86791
# 11700/11700 [==============================] - 416s 36ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2513.8814 - vae_r_loss: 2331.7002 - vae_kl_loss: 182.1718 - val_loss: 12126.0012 - val_vae_r_loss: 11947.5068 - val_vae_kl_loss: 178.5013
# Epoch 16/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2465.3175 - vae_r_loss: 2284.6267 - vae_kl_loss: 180.6904WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00016: val_loss improved from 12108.86791 to 11523.47998, saving model to vae_kdh_batch10_timestep1_2_ckpt.16-11523.480.h5
# 11700/11700 [==============================] - 414s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2465.3175 - vae_r_loss: 2284.6267 - vae_kl_loss: 180.6904 - val_loss: 11523.4800 - val_vae_r_loss: 11347.6611 - val_vae_kl_loss: 175.8359
# Epoch 17/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2394.7761 - vae_r_loss: 2213.3918 - vae_kl_loss: 181.3821WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00017: val_loss improved from 11523.47998 to 11436.49933, saving model to vae_kdh_batch10_timestep1_2_ckpt.17-11436.499.h5
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2394.7761 - vae_r_loss: 2213.3918 - vae_kl_loss: 181.3821 - val_loss: 11436.4993 - val_vae_r_loss: 11260.5879 - val_vae_kl_loss: 175.9103
# Epoch 18/100000
# 11698/11700 [============================>.] - ETA: 0s - batch: 5848.5000 - size: 10.0000 - loss: 2318.0478 - vae_r_loss: 2137.6899 - vae_kl_loss: 180.3600WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00018: val_loss did not improve from 11436.49933
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2317.9038 - vae_r_loss: 2137.5466 - vae_kl_loss: 180.3595 - val_loss: 14881.7014 - val_vae_r_loss: 14703.0225 - val_vae_kl_loss: 178.6745
# Epoch 19/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2330.3754 - vae_r_loss: 2149.8218 - vae_kl_loss: 180.5512WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00019: val_loss did not improve from 11436.49933
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2330.3139 - vae_r_loss: 2149.7605 - vae_kl_loss: 180.5512 - val_loss: 12233.8622 - val_vae_r_loss: 12057.9854 - val_vae_kl_loss: 175.8719
# Epoch 20/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2192.9632 - vae_r_loss: 2012.8584 - vae_kl_loss: 180.1075WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00020: val_loss did not improve from 11436.49933
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2192.9632 - vae_r_loss: 2012.8584 - vae_kl_loss: 180.1075 - val_loss: 14259.0107 - val_vae_r_loss: 14084.6934 - val_vae_kl_loss: 174.2939
# Epoch 21/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2255.3328 - vae_r_loss: 2076.0134 - vae_kl_loss: 179.3226WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00021: val_loss improved from 11436.49933 to 11015.26281, saving model to vae_kdh_batch10_timestep1_2_ckpt.21-11015.263.h5
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2255.3328 - vae_r_loss: 2076.0134 - vae_kl_loss: 179.3226 - val_loss: 11015.2628 - val_vae_r_loss: 10839.6914 - val_vae_kl_loss: 175.5844
# Epoch 22/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2211.9893 - vae_r_loss: 2032.2529 - vae_kl_loss: 179.7375WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00022: val_loss did not improve from 11015.26281
# 11700/11700 [==============================] - 404s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2211.8897 - vae_r_loss: 2032.1544 - vae_kl_loss: 179.7364 - val_loss: 13536.0254 - val_vae_r_loss: 13360.9463 - val_vae_kl_loss: 175.0741
# Epoch 23/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2210.2149 - vae_r_loss: 2030.8756 - vae_kl_loss: 179.3431WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00023: val_loss improved from 11015.26281 to 10674.21859, saving model to vae_kdh_batch10_timestep1_2_ckpt.23-10674.219.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2210.2149 - vae_r_loss: 2030.8756 - vae_kl_loss: 179.3431 - val_loss: 10674.2186 - val_vae_r_loss: 10498.3096 - val_vae_kl_loss: 175.8804
# Epoch 24/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2119.5968 - vae_r_loss: 1941.0939 - vae_kl_loss: 178.5007WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00024: val_loss improved from 10674.21859 to 10282.90777, saving model to vae_kdh_batch10_timestep1_2_ckpt.24-10282.908.h5
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2119.5968 - vae_r_loss: 1941.0939 - vae_kl_loss: 178.5007 - val_loss: 10282.9078 - val_vae_r_loss: 10107.2520 - val_vae_kl_loss: 175.6600
# Epoch 25/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2106.7658 - vae_r_loss: 1929.1426 - vae_kl_loss: 177.6221WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00025: val_loss did not improve from 10282.90777
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2106.7512 - vae_r_loss: 1929.1284 - vae_kl_loss: 177.6216 - val_loss: 10446.6766 - val_vae_r_loss: 10272.5088 - val_vae_kl_loss: 174.1658
# Epoch 26/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2066.0245 - vae_r_loss: 1887.6663 - vae_kl_loss: 178.3586WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00026: val_loss improved from 10282.90777 to 10272.89526, saving model to vae_kdh_batch10_timestep1_2_ckpt.26-10272.895.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2066.1569 - vae_r_loss: 1887.7983 - vae_kl_loss: 178.3591 - val_loss: 10272.8953 - val_vae_r_loss: 10099.1484 - val_vae_kl_loss: 173.7368
# Epoch 27/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2030.8876 - vae_r_loss: 1852.5564 - vae_kl_loss: 178.3289WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00027: val_loss improved from 10272.89526 to 9880.96026, saving model to vae_kdh_batch10_timestep1_2_ckpt.27-9880.960.h5
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2030.8876 - vae_r_loss: 1852.5564 - vae_kl_loss: 178.3289 - val_loss: 9880.9603 - val_vae_r_loss: 9705.6191 - val_vae_kl_loss: 175.3511
# Epoch 28/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2001.7583 - vae_r_loss: 1822.4236 - vae_kl_loss: 179.3344WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00028: val_loss did not improve from 9880.96026
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2001.6899 - vae_r_loss: 1822.3557 - vae_kl_loss: 179.3340 - val_loss: 13441.1967 - val_vae_r_loss: 13267.3047 - val_vae_kl_loss: 173.8994
# Epoch 29/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1912.2018 - vae_r_loss: 1735.3324 - vae_kl_loss: 176.8767WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00029: val_loss did not improve from 9880.96026
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1912.2018 - vae_r_loss: 1735.3324 - vae_kl_loss: 176.8767 - val_loss: 12245.0180 - val_vae_r_loss: 12071.3457 - val_vae_kl_loss: 173.6707
# Epoch 30/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1942.7690 - vae_r_loss: 1765.9319 - vae_kl_loss: 176.8391WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00030: val_loss improved from 9880.96026 to 9870.49927, saving model to vae_kdh_batch10_timestep1_2_ckpt.30-9870.499.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1942.7690 - vae_r_loss: 1765.9319 - vae_kl_loss: 176.8391 - val_loss: 9870.4993 - val_vae_r_loss: 9695.3545 - val_vae_kl_loss: 175.1499
# Epoch 31/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1998.6373 - vae_r_loss: 1820.5752 - vae_kl_loss: 178.0583WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00031: val_loss did not improve from 9870.49927
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1999.3858 - vae_r_loss: 1821.3240 - vae_kl_loss: 178.0580 - val_loss: 15181.6918 - val_vae_r_loss: 15007.7617 - val_vae_kl_loss: 173.9392
# Epoch 32/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1934.0444 - vae_r_loss: 1756.8604 - vae_kl_loss: 177.1856WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00032: val_loss improved from 9870.49927 to 9516.37608, saving model to vae_kdh_batch10_timestep1_2_ckpt.32-9516.376.h5
# 11700/11700 [==============================] - 412s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1933.9900 - vae_r_loss: 1756.8069 - vae_kl_loss: 177.1847 - val_loss: 9516.3761 - val_vae_r_loss: 9341.5820 - val_vae_kl_loss: 174.7771
# Epoch 33/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1929.2838 - vae_r_loss: 1752.4756 - vae_kl_loss: 176.8069WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00033: val_loss improved from 9516.37608 to 9293.30260, saving model to vae_kdh_batch10_timestep1_2_ckpt.33-9293.303.h5
# 11700/11700 [==============================] - 414s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1929.2838 - vae_r_loss: 1752.4756 - vae_kl_loss: 176.8069 - val_loss: 9293.3026 - val_vae_r_loss: 9120.9473 - val_vae_kl_loss: 172.3524
# Epoch 34/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1893.4115 - vae_r_loss: 1716.5382 - vae_kl_loss: 176.8726WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00034: val_loss improved from 9293.30260 to 9163.95106, saving model to vae_kdh_batch10_timestep1_2_ckpt.34-9163.951.h5
# 11700/11700 [==============================] - 417s 36ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1893.3379 - vae_r_loss: 1716.4646 - vae_kl_loss: 176.8727 - val_loss: 9163.9511 - val_vae_r_loss: 8989.8301 - val_vae_kl_loss: 174.1189
# Epoch 35/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1888.7371 - vae_r_loss: 1711.9019 - vae_kl_loss: 176.8283WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00035: val_loss did not improve from 9163.95106
# 11700/11700 [==============================] - 413s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1888.7371 - vae_r_loss: 1711.9019 - vae_kl_loss: 176.8283 - val_loss: 11056.7400 - val_vae_r_loss: 10886.1396 - val_vae_kl_loss: 170.6050
# Epoch 36/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1844.7357 - vae_r_loss: 1668.4825 - vae_kl_loss: 176.2499WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00036: val_loss did not improve from 9163.95106
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1844.6832 - vae_r_loss: 1668.4291 - vae_kl_loss: 176.2509 - val_loss: 9173.8996 - val_vae_r_loss: 9000.6367 - val_vae_kl_loss: 173.2617
# Epoch 37/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1829.0113 - vae_r_loss: 1653.0969 - vae_kl_loss: 175.9140WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00037: val_loss improved from 9163.95106 to 8823.96754, saving model to vae_kdh_batch10_timestep1_2_ckpt.37-8823.968.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1828.9655 - vae_r_loss: 1653.0510 - vae_kl_loss: 175.9140 - val_loss: 8823.9675 - val_vae_r_loss: 8649.3857 - val_vae_kl_loss: 174.6034
# Epoch 38/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1786.2553 - vae_r_loss: 1610.8103 - vae_kl_loss: 175.4435WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00038: val_loss did not improve from 8823.96754
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1786.2553 - vae_r_loss: 1610.8103 - vae_kl_loss: 175.4435 - val_loss: 9088.4024 - val_vae_r_loss: 8914.9834 - val_vae_kl_loss: 173.4005
# Epoch 39/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1870.7842 - vae_r_loss: 1694.9646 - vae_kl_loss: 175.8221WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00039: val_loss improved from 8823.96754 to 8749.97875, saving model to vae_kdh_batch10_timestep1_2_ckpt.39-8749.979.h5
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1870.7541 - vae_r_loss: 1694.9343 - vae_kl_loss: 175.8224 - val_loss: 8749.9787 - val_vae_r_loss: 8577.9814 - val_vae_kl_loss: 171.9822
# Epoch 40/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1794.2097 - vae_r_loss: 1618.4302 - vae_kl_loss: 175.7786WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00040: val_loss did not improve from 8749.97875
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1794.2097 - vae_r_loss: 1618.4302 - vae_kl_loss: 175.7786 - val_loss: 12617.9690 - val_vae_r_loss: 12443.3486 - val_vae_kl_loss: 174.6271
# Epoch 41/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1777.2578 - vae_r_loss: 1602.2517 - vae_kl_loss: 175.0090WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00041: val_loss did not improve from 8749.97875
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1777.2652 - vae_r_loss: 1602.2596 - vae_kl_loss: 175.0085 - val_loss: 14428.1211 - val_vae_r_loss: 14254.5381 - val_vae_kl_loss: 173.6040
# Epoch 42/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1779.2284 - vae_r_loss: 1603.9882 - vae_kl_loss: 175.2420WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00042: val_loss did not improve from 8749.97875
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1779.2081 - vae_r_loss: 1603.9670 - vae_kl_loss: 175.2429 - val_loss: 10456.1035 - val_vae_r_loss: 10284.6377 - val_vae_kl_loss: 171.4693
# Epoch 43/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1691.4843 - vae_r_loss: 1516.6530 - vae_kl_loss: 174.8284WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00043: val_loss improved from 8749.97875 to 8713.51252, saving model to vae_kdh_batch10_timestep1_2_ckpt.43-8713.513.h5
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1691.4227 - vae_r_loss: 1516.5913 - vae_kl_loss: 174.8285 - val_loss: 8713.5125 - val_vae_r_loss: 8539.9648 - val_vae_kl_loss: 173.5502
# Epoch 44/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1690.2088 - vae_r_loss: 1515.4419 - vae_kl_loss: 174.7651WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00044: val_loss improved from 8713.51252 to 8519.18762, saving model to vae_kdh_batch10_timestep1_2_ckpt.44-8519.188.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1690.1845 - vae_r_loss: 1515.4175 - vae_kl_loss: 174.7654 - val_loss: 8519.1876 - val_vae_r_loss: 8347.0293 - val_vae_kl_loss: 172.1466
# Epoch 45/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1708.1985 - vae_r_loss: 1533.6542 - vae_kl_loss: 174.5412WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00045: val_loss improved from 8519.18762 to 8468.79902, saving model to vae_kdh_batch10_timestep1_2_ckpt.45-8468.799.h5
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1708.1985 - vae_r_loss: 1533.6542 - vae_kl_loss: 174.5412 - val_loss: 8468.7990 - val_vae_r_loss: 8295.4189 - val_vae_kl_loss: 173.3740
# Epoch 46/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1740.5682 - vae_r_loss: 1565.6351 - vae_kl_loss: 174.9311WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00046: val_loss did not improve from 8468.79902
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1740.5299 - vae_r_loss: 1565.5959 - vae_kl_loss: 174.9320 - val_loss: 14153.5018 - val_vae_r_loss: 13982.0488 - val_vae_kl_loss: 171.4547
# Epoch 47/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1714.8377 - vae_r_loss: 1540.1346 - vae_kl_loss: 174.7058WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00047: val_loss improved from 8468.79902 to 8321.81329, saving model to vae_kdh_batch10_timestep1_2_ckpt.47-8321.813.h5
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1714.8377 - vae_r_loss: 1540.1346 - vae_kl_loss: 174.7058 - val_loss: 8321.8133 - val_vae_r_loss: 8150.6060 - val_vae_kl_loss: 171.2023
# Epoch 48/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1602.0460 - vae_r_loss: 1427.9419 - vae_kl_loss: 174.1039WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00048: val_loss did not improve from 8321.81329
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1602.1981 - vae_r_loss: 1428.0945 - vae_kl_loss: 174.1034 - val_loss: 13631.8150 - val_vae_r_loss: 13460.1787 - val_vae_kl_loss: 171.6414
# Epoch 49/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1665.3508 - vae_r_loss: 1492.0131 - vae_kl_loss: 173.3360WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00049: val_loss improved from 8321.81329 to 8283.77505, saving model to vae_kdh_batch10_timestep1_2_ckpt.49-8283.775.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1665.3724 - vae_r_loss: 1492.0342 - vae_kl_loss: 173.3364 - val_loss: 8283.7751 - val_vae_r_loss: 8111.5552 - val_vae_kl_loss: 172.2243
# Epoch 50/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1614.7819 - vae_r_loss: 1441.8223 - vae_kl_loss: 172.9621WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00050: val_loss did not improve from 8283.77505
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1614.7819 - vae_r_loss: 1441.8223 - vae_kl_loss: 172.9621 - val_loss: 8828.2520 - val_vae_r_loss: 8658.0420 - val_vae_kl_loss: 170.2191
# Epoch 51/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1707.7879 - vae_r_loss: 1533.4714 - vae_kl_loss: 174.3149WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00051: val_loss did not improve from 8283.77505
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1707.7879 - vae_r_loss: 1533.4714 - vae_kl_loss: 174.3149 - val_loss: 8302.6596 - val_vae_r_loss: 8130.8906 - val_vae_kl_loss: 171.7710
# Epoch 52/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1670.1372 - vae_r_loss: 1496.5205 - vae_kl_loss: 173.6165WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00052: val_loss did not improve from 8283.77505
# 11700/11700 [==============================] - 415s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1670.1635 - vae_r_loss: 1496.5459 - vae_kl_loss: 173.6174 - val_loss: 9226.5938 - val_vae_r_loss: 9053.8643 - val_vae_kl_loss: 172.7292
# Epoch 53/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1626.5448 - vae_r_loss: 1451.3765 - vae_kl_loss: 175.1689WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00053: val_loss did not improve from 8283.77505
# 11700/11700 [==============================] - 414s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1626.4928 - vae_r_loss: 1451.3242 - vae_kl_loss: 175.1692 - val_loss: 13018.6625 - val_vae_r_loss: 12846.5898 - val_vae_kl_loss: 172.0860
# Epoch 54/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1602.6491 - vae_r_loss: 1429.0244 - vae_kl_loss: 173.6249WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00054: val_loss improved from 8283.77505 to 8113.52408, saving model to vae_kdh_batch10_timestep1_2_ckpt.54-8113.524.h5
# 11700/11700 [==============================] - 414s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1602.6014 - vae_r_loss: 1428.9768 - vae_kl_loss: 173.6248 - val_loss: 8113.5241 - val_vae_r_loss: 7941.6074 - val_vae_kl_loss: 171.9093
# Epoch 55/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1577.4547 - vae_r_loss: 1404.4922 - vae_kl_loss: 172.9640WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00055: val_loss did not improve from 8113.52408
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1577.4547 - vae_r_loss: 1404.4922 - vae_kl_loss: 172.9640 - val_loss: 12576.9794 - val_vae_r_loss: 12406.0078 - val_vae_kl_loss: 170.9730
# Epoch 56/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1591.6144 - vae_r_loss: 1418.5928 - vae_kl_loss: 173.0227WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00056: val_loss did not improve from 8113.52408
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1591.5749 - vae_r_loss: 1418.5537 - vae_kl_loss: 173.0222 - val_loss: 14234.2508 - val_vae_r_loss: 14064.3652 - val_vae_kl_loss: 169.8992
# Epoch 57/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1537.5530 - vae_r_loss: 1364.0701 - vae_kl_loss: 173.4857WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00057: val_loss did not improve from 8113.52408
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1537.5017 - vae_r_loss: 1364.0189 - vae_kl_loss: 173.4855 - val_loss: 12300.3668 - val_vae_r_loss: 12128.1797 - val_vae_kl_loss: 172.1836
# Epoch 58/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1515.0430 - vae_r_loss: 1342.5907 - vae_kl_loss: 172.4542WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00058: val_loss did not improve from 8113.52408
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1515.0241 - vae_r_loss: 1342.5718 - vae_kl_loss: 172.4541 - val_loss: 8172.3309 - val_vae_r_loss: 8003.4580 - val_vae_kl_loss: 168.8597
# Epoch 59/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1536.6194 - vae_r_loss: 1364.6185 - vae_kl_loss: 172.0006WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00059: val_loss improved from 8113.52408 to 8100.89495, saving model to vae_kdh_batch10_timestep1_2_ckpt.59-8100.895.h5
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1536.6161 - vae_r_loss: 1364.6152 - vae_kl_loss: 172.0006 - val_loss: 8100.8950 - val_vae_r_loss: 7931.9961 - val_vae_kl_loss: 168.8876
# Epoch 60/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1548.2630 - vae_r_loss: 1375.5256 - vae_kl_loss: 172.7330WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00060: val_loss did not improve from 8100.89495
# 11700/11700 [==============================] - 405s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1548.2630 - vae_r_loss: 1375.5256 - vae_kl_loss: 172.7330 - val_loss: 12224.1888 - val_vae_r_loss: 12053.5381 - val_vae_kl_loss: 170.6416
# Epoch 61/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1497.2719 - vae_r_loss: 1325.0404 - vae_kl_loss: 172.2313WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00061: val_loss improved from 8100.89495 to 7774.85561, saving model to vae_kdh_batch10_timestep1_2_ckpt.61-7774.856.h5
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1497.2209 - vae_r_loss: 1324.9891 - vae_kl_loss: 172.2317 - val_loss: 7774.8556 - val_vae_r_loss: 7604.5786 - val_vae_kl_loss: 170.2771
# Epoch 62/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1520.9004 - vae_r_loss: 1349.0551 - vae_kl_loss: 171.8431WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00062: val_loss improved from 7774.85561 to 7773.61004, saving model to vae_kdh_batch10_timestep1_2_ckpt.62-7773.610.h5
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1520.8761 - vae_r_loss: 1349.0303 - vae_kl_loss: 171.8436 - val_loss: 7773.6100 - val_vae_r_loss: 7604.5576 - val_vae_kl_loss: 169.0467
# Epoch 63/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1464.5496 - vae_r_loss: 1292.9333 - vae_kl_loss: 171.6189WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00063: val_loss did not improve from 7773.61004
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1464.4911 - vae_r_loss: 1292.8756 - vae_kl_loss: 171.6181 - val_loss: 7960.2968 - val_vae_r_loss: 7790.5947 - val_vae_kl_loss: 169.6985
# Epoch 64/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1461.7027 - vae_r_loss: 1291.1016 - vae_kl_loss: 170.6021WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00064: val_loss improved from 7773.61004 to 7634.19335, saving model to vae_kdh_batch10_timestep1_2_ckpt.64-7634.193.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1461.7027 - vae_r_loss: 1291.1016 - vae_kl_loss: 170.6021 - val_loss: 7634.1934 - val_vae_r_loss: 7465.2549 - val_vae_kl_loss: 168.9350
# Epoch 65/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1477.9953 - vae_r_loss: 1306.8705 - vae_kl_loss: 171.1253WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00065: val_loss improved from 7634.19335 to 7552.58984, saving model to vae_kdh_batch10_timestep1_2_ckpt.65-7552.590.h5
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1477.9498 - vae_r_loss: 1306.8254 - vae_kl_loss: 171.1249 - val_loss: 7552.5898 - val_vae_r_loss: 7383.8892 - val_vae_kl_loss: 168.7001
# Epoch 66/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1417.0112 - vae_r_loss: 1246.5709 - vae_kl_loss: 170.4379WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00066: val_loss did not improve from 7552.58984
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1417.0112 - vae_r_loss: 1246.5709 - vae_kl_loss: 170.4379 - val_loss: 12607.7913 - val_vae_r_loss: 12438.7549 - val_vae_kl_loss: 169.0080
# Epoch 67/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1441.2999 - vae_r_loss: 1270.7273 - vae_kl_loss: 170.5701WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00067: val_loss did not improve from 7552.58984
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1441.2999 - vae_r_loss: 1270.7273 - vae_kl_loss: 170.5701 - val_loss: 12818.3108 - val_vae_r_loss: 12649.1865 - val_vae_kl_loss: 169.1048
# Epoch 68/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1427.8702 - vae_r_loss: 1257.9333 - vae_kl_loss: 169.9392WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00068: val_loss did not improve from 7552.58984
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1427.8146 - vae_r_loss: 1257.8781 - vae_kl_loss: 169.9388 - val_loss: 9523.7783 - val_vae_r_loss: 9353.9424 - val_vae_kl_loss: 169.8336
# Epoch 69/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1397.0208 - vae_r_loss: 1227.2924 - vae_kl_loss: 169.7278WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00069: val_loss did not improve from 7552.58984
# 11700/11700 [==============================] - 406s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1397.0208 - vae_r_loss: 1227.2924 - vae_kl_loss: 169.7278 - val_loss: 7752.4159 - val_vae_r_loss: 7583.5913 - val_vae_kl_loss: 168.8238
# Epoch 70/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1370.8117 - vae_r_loss: 1200.3450 - vae_kl_loss: 170.4664WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00070: val_loss did not improve from 7552.58984
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1370.8117 - vae_r_loss: 1200.3450 - vae_kl_loss: 170.4664 - val_loss: 13487.5785 - val_vae_r_loss: 13319.0557 - val_vae_kl_loss: 168.5208
# Epoch 71/100000
# ...
#
# Epoch 01493: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 431s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 539.3633 - vae_r_loss: 391.4864 - vae_kl_loss: 147.8764 - val_loss: 10567.0301 - val_vae_r_loss: 10421.0869 - val_vae_kl_loss: 145.9300
# Epoch 1494/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 533.5432 - vae_r_loss: 385.9109 - vae_kl_loss: 147.6326WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01494: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 434s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 533.5435 - vae_r_loss: 385.9118 - vae_kl_loss: 147.6319 - val_loss: 7378.4262 - val_vae_r_loss: 7232.8203 - val_vae_kl_loss: 145.6074
# Epoch 1495/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 533.7155 - vae_r_loss: 386.6767 - vae_kl_loss: 147.0391WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01495: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 434s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 533.7122 - vae_r_loss: 386.6735 - vae_kl_loss: 147.0390 - val_loss: 8137.7760 - val_vae_r_loss: 7992.0264 - val_vae_kl_loss: 145.7583
# Epoch 1496/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 536.8404 - vae_r_loss: 389.9472 - vae_kl_loss: 146.8940WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01496: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 435s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 536.8404 - vae_r_loss: 389.9472 - vae_kl_loss: 146.8940 - val_loss: 14243.9376 - val_vae_r_loss: 14098.3867 - val_vae_kl_loss: 145.5591
# Epoch 1497/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 535.8619 - vae_r_loss: 389.1345 - vae_kl_loss: 146.7276WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01497: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 435s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 535.8619 - vae_r_loss: 389.1345 - vae_kl_loss: 146.7276 - val_loss: 8637.8283 - val_vae_r_loss: 8492.2695 - val_vae_kl_loss: 145.5709
# Epoch 1498/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 531.3876 - vae_r_loss: 384.8279 - vae_kl_loss: 146.5610WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01498: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 432s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 531.3912 - vae_r_loss: 384.8314 - vae_kl_loss: 146.5611 - val_loss: 9564.9348 - val_vae_r_loss: 9419.3828 - val_vae_kl_loss: 145.5480
# Epoch 1499/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 534.0135 - vae_r_loss: 387.1303 - vae_kl_loss: 146.8825WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01499: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 433s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 534.0135 - vae_r_loss: 387.1303 - vae_kl_loss: 146.8825 - val_loss: 6178.8689 - val_vae_r_loss: 6033.5566 - val_vae_kl_loss: 145.2993
# Epoch 1500/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 536.4730 - vae_r_loss: 388.7371 - vae_kl_loss: 147.7360WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01500: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 437s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 536.4749 - vae_r_loss: 388.7393 - vae_kl_loss: 147.7356 - val_loss: 7332.3842 - val_vae_r_loss: 7186.8042 - val_vae_kl_loss: 145.5777
# Epoch 1501/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 535.1616 - vae_r_loss: 387.6978 - vae_kl_loss: 147.4649WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01501: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 433s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 535.1616 - vae_r_loss: 387.6978 - vae_kl_loss: 147.4649 - val_loss: 7499.8346 - val_vae_r_loss: 7353.8940 - val_vae_kl_loss: 145.9372
# Epoch 1502/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 536.7669 - vae_r_loss: 389.3235 - vae_kl_loss: 147.4430WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01502: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 439s 38ms/step - batch: 5849.5000 - size: 10.0000 - loss: 536.7671 - vae_r_loss: 389.3234 - vae_kl_loss: 147.4434 - val_loss: 8197.3421 - val_vae_r_loss: 8051.3027 - val_vae_kl_loss: 146.0396
# Epoch 1503/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 538.4452 - vae_r_loss: 391.3947 - vae_kl_loss: 147.0519WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01503: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 435s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 538.4503 - vae_r_loss: 391.4002 - vae_kl_loss: 147.0514 - val_loss: 6366.6788 - val_vae_r_loss: 6221.0864 - val_vae_kl_loss: 145.5935
# Epoch 1504/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 532.7386 - vae_r_loss: 386.2381 - vae_kl_loss: 146.5012WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01504: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 437s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 532.7386 - vae_r_loss: 386.2381 - vae_kl_loss: 146.5012 - val_loss: 6442.5169 - val_vae_r_loss: 6296.6421 - val_vae_kl_loss: 145.8697
# Epoch 1505/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 531.4212 - vae_r_loss: 384.4667 - vae_kl_loss: 146.9546WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01505: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 437s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 531.4189 - vae_r_loss: 384.4640 - vae_kl_loss: 146.9550 - val_loss: 6989.8787 - val_vae_r_loss: 6844.1816 - val_vae_kl_loss: 145.6890
# Epoch 1506/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 533.4122 - vae_r_loss: 387.0608 - vae_kl_loss: 146.3507WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01506: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 437s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 533.4122 - vae_r_loss: 387.0608 - vae_kl_loss: 146.3507 - val_loss: 9610.8347 - val_vae_r_loss: 9464.8389 - val_vae_kl_loss: 146.0048
# Epoch 1507/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 535.6824 - vae_r_loss: 388.7166 - vae_kl_loss: 146.9653WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01507: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 436s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 535.6752 - vae_r_loss: 388.7100 - vae_kl_loss: 146.9647 - val_loss: 11286.8178 - val_vae_r_loss: 11140.6934 - val_vae_kl_loss: 146.1133
# Epoch 1508/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 533.1856 - vae_r_loss: 386.1555 - vae_kl_loss: 147.0300WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01508: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 433s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 533.1895 - vae_r_loss: 386.1582 - vae_kl_loss: 147.0311 - val_loss: 8641.7483 - val_vae_r_loss: 8496.0674 - val_vae_kl_loss: 145.6674
# Epoch 1509/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 538.5590 - vae_r_loss: 391.5920 - vae_kl_loss: 146.9672WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01509: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 434s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 538.5590 - vae_r_loss: 391.5920 - vae_kl_loss: 146.9672 - val_loss: 7124.9197 - val_vae_r_loss: 6978.9810 - val_vae_kl_loss: 145.9397
# Epoch 1510/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 531.9589 - vae_r_loss: 384.8984 - vae_kl_loss: 147.0604WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01510: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 432s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 531.9589 - vae_r_loss: 384.8984 - vae_kl_loss: 147.0604 - val_loss: 7459.7192 - val_vae_r_loss: 7314.3003 - val_vae_kl_loss: 145.4330
# Epoch 1511/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 537.7214 - vae_r_loss: 390.4591 - vae_kl_loss: 147.2623WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01511: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 432s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 537.7238 - vae_r_loss: 390.4610 - vae_kl_loss: 147.2627 - val_loss: 7279.0133 - val_vae_r_loss: 7133.1470 - val_vae_kl_loss: 145.8552
# Epoch 1512/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 533.9751 - vae_r_loss: 387.5208 - vae_kl_loss: 146.4530WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01512: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 428s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 533.9751 - vae_r_loss: 387.5208 - vae_kl_loss: 146.4530 - val_loss: 6179.7010 - val_vae_r_loss: 6034.6001 - val_vae_kl_loss: 145.1066
# Epoch 1513/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 530.8585 - vae_r_loss: 384.4147 - vae_kl_loss: 146.4442WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01513: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 435s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 530.8585 - vae_r_loss: 384.4147 - vae_kl_loss: 146.4442 - val_loss: 7402.7004 - val_vae_r_loss: 7257.5840 - val_vae_kl_loss: 145.1259
# Epoch 1514/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 535.0329 - vae_r_loss: 388.3346 - vae_kl_loss: 146.6982WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01514: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 435s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 535.0283 - vae_r_loss: 388.3298 - vae_kl_loss: 146.6984 - val_loss: 6184.3019 - val_vae_r_loss: 6038.8936 - val_vae_kl_loss: 145.4102
# Epoch 1515/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 534.0452 - vae_r_loss: 386.6300 - vae_kl_loss: 147.4151WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01515: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 437s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 534.0452 - vae_r_loss: 386.6300 - vae_kl_loss: 147.4151 - val_loss: 7551.9942 - val_vae_r_loss: 7406.3022 - val_vae_kl_loss: 145.6929
# Epoch 1516/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 538.5124 - vae_r_loss: 390.8935 - vae_kl_loss: 147.6183WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01516: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 435s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 538.5124 - vae_r_loss: 390.8935 - vae_kl_loss: 147.6183 - val_loss: 11184.5874 - val_vae_r_loss: 11038.7568 - val_vae_kl_loss: 145.8083
# Epoch 1517/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 531.0868 - vae_r_loss: 384.4128 - vae_kl_loss: 146.6732WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01517: val_loss did not improve from 5899.89544
# 11700/11700 [==============================] - 436s 37ms/step - batch: 5849.5000 - size: 10.0000 - loss: 531.0868 - vae_r_loss: 384.4128 - vae_kl_loss: 146.6732 - val_loss: 7689.3629 - val_vae_r_loss: 7543.5234 - val_vae_kl_loss: 145.8439
# Epoch 1518/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 529.4567 - vae_r_loss: 382.6645 - vae_kl_loss: 146.7921WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def plot_latent_space(trained_decoder, pimage, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    image = np.array(image).astype("float32")/255.0
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.5])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_tstr = np.array([0.3])
    X_tvel = np.expand_dims(X_tstr, axis=0)
    X_ttime = np.array([0.1])
    X_tvel = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    X_train = [image, X_tstr, X_tvel, X_ttime]

    x_encoded = VarAE.predict(X_train)*255.0
    # print(x_encoded)
    x_encoded_out = np.squeeze(x_encoded,axis=0)
    # pred_image = np.zeros([160,160,3], np.uint8)
    pred_image = array_to_img(x_encoded_out)
    pred_image = np.array(pred_image)
    pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # pred_img = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # print(type(pred_img))
    # print(pred_image.shape)
    plt.imshow(pred_image)
    # plt.imshow(cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB))
    plt.show()

    origin_image_name = '/home2/kdh/vae/vae_test/2022-12-08-14-30-12-332957.jpg'
    cv2.imwrite('/')
    # plt.xticks(pixel_range, sample_range_x)
    # plt.yticks(pixel_range, sample_range_y)
    # plt.xlabel("z[0]")
    # plt.ylabel("z[1]")

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-30-12-332957.jpg')
# plot_latent_space(decoder, test_img)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space(trained_decoder, valid_data, n=50, figsize=15):
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in valid_data:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))

        cv2.imwrite('/home2/kdh/vae/vae_test/'+image_name, image)
        image = np.array(image).astype("float32")/255.0
        # image = image_process.process(image)
        steering_angle, throttle, brake = measurement
        
        image = np.expand_dims(image, axis=0)
        X_tvel = np.array([velocity])
        X_tvel = np.expand_dims(X_tvel, axis=0)
        X_tstr = np.array([steering_angle])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_ttime = np.array([tar_time])
        X_ttime = np.expand_dims(X_ttime, axis=0)
        
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image)
        # plt.imshow(pred_image)
        # plt.show()

        # image_name = '/home2/kdh/vae/vae_test/'+image_name
        pred_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'.jpg'
        gt_tar_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'_gt.jpg'
        cv2.imwrite(pred_image_name, pred_image)
        cv2.imwrite(gt_tar_image_name, tar_image)

        # print(pred_image_name,' done')
        # cv2.imwrite('/')


# save_latent_space(decoder, valid_data[3423:4422])

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space_diff_steer(trained_decoder, pimage, save_image_name, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    cv2.imwrite('/home2/kdh/vae/vae_diff_steer_test/'+save_image_name+'.jpg', image)
    image = np.array(image).astype("float32")/255.0
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.85])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_ttime = np.array([0.8])
    X_ttime = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    for s in np.arange(0, 0.8, 0.0125):
        X_tstr = np.array([s-0.4])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
        s_str = "{:.3f}".format(s)
        pred_image_name = ('/home2/kdh/vae/vae_diff_steer_test/'
                            +save_image_name
                            +'_'+str(s_str)
                            +'.jpg'
        )
        cv2.imwrite(pred_image_name, pred_image)
    
        

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-35-43-708754.jpg')
# save_latent_space_diff_steer(decoder, test_img, '2022-12-08-14-35-43-708754')
