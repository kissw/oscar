# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
# from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Activation, LeakyReLU, Dropout, BatchNormalization, MaxPooling2D, Lambda
from keras.models import Model
from sklearn.metrics import mean_squared_error as mse
from progressbar import ProgressBar
from image_process import ImageProcess
import const, cv2
from drive_data import DriveData
from config import Config

import matplotlib.pyplot as plt
import sys
config = Config.neural_net
sys.setrecursionlimit(10**7)
tf.compat.v1.experimental.output_all_intermediates(True)
tf.compat.v1.disable_eager_execution()
# Out:
# =======================================================
#                Configuration Settings
# =======================================================
# Neural Net:     	fusion_kdh_jaerock3
# Data Collection:	fusion_kdh_jaerock3
# Run Neural:     	fusion_kdh_jaerock3

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
gpu_config = tf.compat.v1.ConfigProto()
gpu_config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=gpu_config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
"""
## Encoder
"""

"""
## Create a sampling layer
"""
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

encoder_inputs_img = tf.keras.Input(batch_shape=(10, 1, 160, 160, 3))
encoder_inputs_str = tf.keras.Input(batch_shape=(10, 1, 1))
encoder_inputs_vel = tf.keras.Input(batch_shape=(10, 1, 1))
encoder_inputs_time = tf.keras.Input(batch_shape=(10, 1, 1))
x = layers.TimeDistributed(layers.Conv2D(24, (5, 5), padding='same', name='conv2d_1'))(encoder_inputs_img)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1'))(x)
# x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1'))(x)
x = layers.TimeDistributed(layers.Conv2D(36, (5, 5), padding='same', name='conv2d_2'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_2'))(x)
x = layers.TimeDistributed(layers.Conv2D(48, (5, 5), padding='same', name='conv2d_3'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.Conv2D(64, (3, 3), padding='same', name='conv2d_4'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.Conv2D(64, (3, 3), padding='same', name='conv2d_5'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
latent = layers.TimeDistributed(layers.Flatten())(x)
latent = layers.TimeDistributed(layers.Dense(500))(latent)
latent = layers.TimeDistributed(layers.LayerNormalization())(latent)
latent = layers.TimeDistributed(layers.Activation('tanh'))(latent)
fc_s1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_str)
fc_s1  = layers.TimeDistributed(layers.Activation('elu'))(fc_s1)
fc_s2  = layers.TimeDistributed(layers.Dense(50))(fc_s1)
fc_s2  = layers.TimeDistributed(layers.Activation('elu'))(fc_s2)
fc_v1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_vel)
fc_v1  = layers.TimeDistributed(layers.Activation('elu'))(fc_v1)
fc_v2  = layers.TimeDistributed(layers.Dense(50))(fc_v1)
fc_v2  = layers.TimeDistributed(layers.Activation('elu'))(fc_v2)
fc_t1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_time)
fc_t1  = layers.TimeDistributed(layers.Activation('elu'))(fc_t1)
fc_t2  = layers.TimeDistributed(layers.Dense(50))(fc_t1)
fc_t2  = layers.TimeDistributed(layers.Activation('elu'))(fc_t2)
conc_1 = layers.concatenate([latent, fc_s2, fc_v2, fc_t2])
bilstm = layers.Bidirectional(layers.LSTM(500, batch_size=10, stateful=True))(conc_1)
# bilstm = layers.Bidirectional(layers.LSTM(500, input_shape=(1000, 1), batch_size=10, stateful=True))(conc_1)
fc_1   = layers.Dense(500)(bilstm)
fc_1   = layers.Activation('elu')(fc_1)
fc_2   = layers.Dense(100)(fc_1)
x   = layers.Activation('elu')(fc_2)
z_mean = layers.Dense(50, name="z_mean")(x)
z_log_var = layers.Dense(50, name="z_log_var")(x)
encoder_output = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model([ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time], 
                        [z_mean, z_log_var, encoder_output], 
                        name="encoder")

"""
## Decoder
"""
latent_inputs = tf.keras.Input(shape=(50,))
x = layers.Dense(40 * 40 * 64, activation="elu")(latent_inputs)
x = layers.Reshape((40, 40, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="elu",  padding="same")(x)
x = layers.Conv2DTranspose(36, 3, activation="elu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(24, 3, activation="elu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = tf.keras.Model(latent_inputs, decoder_outputs, name="decoder")

"""
## VAE
"""
model_input = [ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time]
model_output = decoder(encoder_output)

VarAE=Model(model_input, model_output)
VarAE.summary()
# Out:
# WARNING:tensorflow:From /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(10, 1, 160, 160, 3 0
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (10, 1, 160, 160, 24 1824        input_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (10, 1, 160, 160, 24 96          time_distributed[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (10, 1, 160, 160, 24 0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (10, 1, 80, 80, 24)  0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (10, 1, 80, 80, 36)  21636       time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (10, 1, 80, 80, 36)  144         time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (10, 1, 80, 80, 36)  0           time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (10, 1, 40, 40, 36)  0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (10, 1, 40, 40, 48)  43248       time_distributed_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (10, 1, 40, 40, 48)  192         time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (10, 1, 40, 40, 48)  0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (10, 1, 40, 40, 64)  27712       time_distributed_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (10, 1, 40, 40, 64)  256         time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (10, 1, 40, 40, 64)  0           time_distributed_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (10, 1, 40, 40, 64)  36928       time_distributed_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (10, 1, 40, 40, 64)  256         time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (10, 1, 40, 40, 64)  0           time_distributed_15[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(10, 1, 1)]         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(10, 1, 1)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(10, 1, 1)]         0
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (10, 1, 102400)      0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (10, 1, 100)         200         input_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (10, 1, 100)         200         input_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (10, 1, 100)         200         input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (10, 1, 500)         51200500    time_distributed_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (10, 1, 100)         0           time_distributed_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (10, 1, 100)         0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (10, 1, 100)         0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (10, 1, 500)         1000        time_distributed_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (10, 1, 50)          5050        time_distributed_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (10, 1, 50)          5050        time_distributed_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (10, 1, 50)          5050        time_distributed_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (10, 1, 500)         0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (10, 1, 50)          0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (10, 1, 50)          0           time_distributed_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (10, 1, 50)          0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (10, 1, 650)         0           time_distributed_20[0][0]
#                                                                  time_distributed_24[0][0]
#                                                                  time_distributed_28[0][0]
#                                                                  time_distributed_32[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (10, 1000)           4604000     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (10, 500)            500500      bidirectional[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (10, 500)            0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (10, 100)            50100       activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (10, 100)            0           dense_8[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (10, 50)             5050        activation_13[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (10, 50)             5050        activation_13[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (10, 50)             0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 160, 160, 3)  5288551     sampling[0][0]
# ==================================================================================================
# Total params: 61,802,793
# Trainable params: 61,802,321
# Non-trainable params: 472
# __________________________________________________________________________________________________

# %%
"""
## Dataset
"""
image_process = ImageProcess()
config = Config.neural_net
# data_path = "/mnt/exData/internal_simulation/test/2022-03-08-17-18-14/"
data_path = "/home2/kdh/vae/2022-12-08-14-25-29/"
if data_path[-1] == '/':
    data_path = data_path[:-1]

    loc_slash = data_path.rfind('/')
    if loc_slash != -1: # there is '/' in the data path
        model_name = data_path[loc_slash + 1:] # get folder name
        #model_name = model_name.strip('/')
    else:
        model_name = data_path
csv_path = data_path + '/' + model_name + const.DATA_EXT 
# data = DriveData(csv_path)
print(csv_path)
# data_path = data_path
# data.read()

csv_header = ['image_fname', 
                  'steering_angle', 'throttle', 'brake', 'linux_time', 
                  'vel', 'vel_x', 'vel_y', 'vel_z', 
                  'pos_x', 'pos_y', 'pos_z', 
                  'tar_image_fname', 'tar_steering_angle', 'tar_vel', 'tar_time']

df = pd.read_csv(csv_path, names=csv_header, index_col=False)
num_data = len(df)

bar = ProgressBar()
df_image_names = []
df_measurements = []
df_time_stamps= []
df_velocities= []
df_velocities_xyz= []
df_positions_xyz= []
df_tar_image_names= []
df_tar_steering_angle= []
df_tar_vel= []
df_tar_time= []
for i in bar(range(num_data)): # we don't have a title
    df_image_names.append(df.loc[i]['image_fname'])
    # if Config.data_collection['brake'] is True:
    df_measurements.append((float(df.loc[i]['steering_angle']),
                            float(df.loc[i]['throttle']), 
                            float(df.loc[i]['brake'])))
    df_time_stamps.append(float(df.loc[i]['linux_time']))
    df_velocities.append(float(df.loc[i]['vel']))
    df_velocities_xyz.append((float(df.loc[i]['vel_x']), 
                                float(df.loc[i]['vel_y']), 
                                float(df.loc[i]['vel_z'])))
    df_positions_xyz.append((float(df.loc[i]['pos_x']), 
                                float(df.loc[i]['pos_y']), 
                                float(df.loc[i]['pos_z'])))
    df_tar_image_names.append(df.loc[i]['tar_image_fname'])
    df_tar_steering_angle.append(float(df.loc[i]['tar_steering_angle']))
    df_tar_vel.append(float(df.loc[i]['tar_vel']))
    df_tar_time.append(float(df.loc[i]['tar_time']))
# Out:
# /home2/kdh/vae/2022-12-08-14-25-29/2022-12-08-14-25-29.csv
# 100% |########################################################################|

# %%
samples = list(zip( df_image_names, df_velocities, df_measurements, 
                    df_tar_image_names, df_tar_steering_angle, df_tar_vel, df_tar_time))

# %%
def prepare_vae_batch_samples(batch_samples):
    images = []
    steering_angles = []
    vels = []
    tar_images = []
    tar_steering_angles = []
    tar_vels = []
    tar_times = []


    batch_images = []
    batch_steering_angles = []
    batch_vels = []
    batch_tar_images = []
    batch_tar_steering_angles = []
    batch_tar_vels = []
    batch_tar_times = []
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in batch_samples:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        if Config.data_collection['crop'] is not True:
            image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
            tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        image = image_process.process(image)
        tar_image = image_process.process(tar_image)

        batch_vels.append(velocity)
        batch_tar_vels.append(tar_vel)
        batch_tar_times.append(tar_time)
        batch_tar_steering_angles.append(tar_steering_angle)
        # if no brake data in collected data, brake values are dummy
        steering_angle, throttle, brake = measurement
        batch_steering_angles.append(steering_angle)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/image/'+image_name, image)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/tar_image/'+tar_image_name, tar_image)
        # if data == 'train':
        #     cv2.imwrite('/mnt/Data/oscar/train_data/'+image_name, image)
        # print(image.shape)
        batch_images.append(image)
        tar_images.append(tar_image)
        # segimgs.append(segimg)


    images.append(batch_images)
    steering_angles.append(batch_steering_angles)
    vels.append(batch_vels)
    # tar_images.append(batch_tar_images)
    tar_steering_angles.append(batch_tar_steering_angles)
    tar_vels.append(batch_tar_vels)
    tar_times.append(batch_tar_times)
    # print(np.array(tar_times).shape)
    return images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times

# %%
"""
Data generator
"""
from sklearn.model_selection import train_test_split

def _generator(samples, batch_size=10):
    num_samples = len(samples)
    while True: # Loop forever so the generator never terminates
        for offset in range(0, (num_samples//batch_size)*batch_size, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times = prepare_vae_batch_samples(batch_samples)

            X_img = np.array(images).astype("float32")/255.0
            X_tvel = np.array(tar_vels).astype("float32")
            X_tstr = np.array(tar_steering_angles).astype("float32")
            X_ttime = np.array(tar_times).astype("float32")

            X_img = X_img.swapaxes(0,1)
            
            X_tvel = X_tvel.swapaxes(0,1)
            X_tstr = X_tstr.swapaxes(0,1)
            X_ttime = X_ttime.swapaxes(0,1)
            X_tvel = X_tvel.reshape(-1, 1, 1)
            X_tstr = X_tstr.reshape(-1, 1, 1)
            X_ttime = X_ttime.reshape(-1, 1, 1)
            y_train = np.array(tar_images).astype("float32")/255.0
            # print(X_img.shape)
            # print(X_tvel.shape)
            # print(y_train.shape)
            # if config['num_outputs'] == 1:
            # y_train = np.array(segimg)
            # print(y_train.max())
            # y_train = np.repeat(y_train[..., np.newaxis], 1, -1)/y_train.max()
            X_train = [X_img, X_tstr, X_tvel, X_ttime]
            # print(X_tstr, X_tvel, X_ttime)
            # print(y_train)
            # print(y_train.shape)
            yield X_train, y_train

train_data, valid_data = train_test_split(samples, test_size=config['validation_rate'])

train_generator = _generator(train_data, 10)
valid_generator = _generator(valid_data, 10)

# %%
"""
VAE loss
"""
optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.0000001)
# optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.00000001)
#                                  learning_rate=0.000005,decay=0.0000000001
r_loss_factor=160*160*100   # This is a Hyperparameter

def vae_r_loss(y_true, y_pred):    ## MSE
    r_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_pred), axis=[1,2,3])
    return r_loss_factor * r_loss

def vae_kl_loss(y_true, y_pred):   ## KL-Divergence
    kl_loss=( -0.5 * tf.keras.backend.sum(1+z_log_var 
                - tf.keras.backend.square(z_mean) 
                - tf.keras.backend.exp(z_log_var), axis=1)
    )
    return kl_loss

def vae_loss(y_true, y_pred): 
    r_loss=vae_r_loss(y_true, y_pred) #Loss of Decoder
    kl_loss = vae_kl_loss(y_true, y_pred) #Loss of Encoder
    return r_loss + kl_loss #Sum of these two


VarAE.compile(optimizer=optimizer,
                loss= vae_loss, 
                metrics=[vae_r_loss, vae_kl_loss])
# VarAE.summary()
#  vae_r_loss: 12.6586 - vae_kl_loss: 2251744.5000 
#  val_loss: 50649853.6174 
#  val_vae_r_loss: 28.6742 - val_vae_kl_loss: 50649896.0000

# %%
"""
## Train the VAE
"""
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.python.framework.ops import disable_eager_execution

        # checkpoint
callbacks = []
#weight_filename = self.data_path + '_' + Config.config_yaml_name \
#    + '_N' + str(config['network_type']) + '_ckpt'
model_ckpt_name = "vae_kdh_batch10_timestep1"
checkpoint = ModelCheckpoint(model_ckpt_name +'_ckpt.{epoch:02d}-{val_loss:.3f}.h5',
                                monitor='val_loss', 
                                verbose=1, save_best_only=True, mode='min')
callbacks.append(checkpoint)

# early stopping
patience = 5000
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, 
                            verbose=1, mode='min')
# callbacks.append(earlystop)

# validation_steps = len(valid_data)//config['batch_size']
# print(validation_steps)
train_hist = VarAE.fit( train_generator,  
                        steps_per_epoch=len(train_data)//10, 
                        epochs=100000, 
                        validation_data=valid_generator,
                        validation_steps=len(valid_data)//10,
                        # shuffle=True,
                        verbose=1, 
                        callbacks=callbacks, 
                        use_multiprocessing=True,
                        workers=48
                        )
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 11832.3271 - vae_r_loss: 11560.0596 - vae_kl_loss: 272.2555WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 20452.60051, saving model to vae_kdh_batch10_timestep1_ckpt.01-20452.601.h5
# 11700/11700 [==============================] - 367s 31ms/step - batch: 5849.5000 - size: 10.0000 - loss: 11831.8013 - vae_r_loss: 11559.5352 - vae_kl_loss: 272.2534 - val_loss: 20452.6005 - val_vae_r_loss: 20227.7891 - val_vae_kl_loss: 224.7919
# Epoch 2/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 6357.4012 - vae_r_loss: 6145.2041 - vae_kl_loss: 212.1958WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00002: val_loss improved from 20452.60051 to 19772.57306, saving model to vae_kdh_batch10_timestep1_ckpt.02-19772.573.h5
# 11700/11700 [==============================] - 368s 31ms/step - batch: 5849.5000 - size: 10.0000 - loss: 6357.7502 - vae_r_loss: 6145.5562 - vae_kl_loss: 212.1927 - val_loss: 19772.5731 - val_vae_r_loss: 19582.1562 - val_vae_kl_loss: 190.3935
# Epoch 3/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 5345.0781 - vae_r_loss: 5148.4487 - vae_kl_loss: 196.6360WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00003: val_loss improved from 19772.57306 to 18586.81299, saving model to vae_kdh_batch10_timestep1_ckpt.03-18586.813.h5
# 11700/11700 [==============================] - 366s 31ms/step - batch: 5849.5000 - size: 10.0000 - loss: 5345.0781 - vae_r_loss: 5148.4487 - vae_kl_loss: 196.6360 - val_loss: 18586.8130 - val_vae_r_loss: 18403.2715 - val_vae_kl_loss: 183.5587
# Epoch 4/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 4791.7170 - vae_r_loss: 4599.2256 - vae_kl_loss: 192.4868WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00004: val_loss improved from 18586.81299 to 17876.30981, saving model to vae_kdh_batch10_timestep1_ckpt.04-17876.310.h5
# 11700/11700 [==============================] - 278s 24ms/step - batch: 5849.5000 - size: 10.0000 - loss: 4791.5858 - vae_r_loss: 4599.0952 - vae_kl_loss: 192.4859 - val_loss: 17876.3098 - val_vae_r_loss: 17695.5898 - val_vae_kl_loss: 180.7505
# Epoch 5/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 4447.4363 - vae_r_loss: 4259.9121 - vae_kl_loss: 187.5202WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00005: val_loss did not improve from 17876.30981
# 11700/11700 [==============================] - 284s 24ms/step - batch: 5849.5000 - size: 10.0000 - loss: 4447.4363 - vae_r_loss: 4259.9121 - vae_kl_loss: 187.5202 - val_loss: 18119.4486 - val_vae_r_loss: 17942.9238 - val_vae_kl_loss: 176.5240
# Epoch 6/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 4141.6142 - vae_r_loss: 3957.3940 - vae_kl_loss: 184.2274WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00006: val_loss improved from 17876.30981 to 17851.95891, saving model to vae_kdh_batch10_timestep1_ckpt.06-17851.959.h5
# 11700/11700 [==============================] - 351s 30ms/step - batch: 5849.5000 - size: 10.0000 - loss: 4141.6142 - vae_r_loss: 3957.3940 - vae_kl_loss: 184.2274 - val_loss: 17851.9589 - val_vae_r_loss: 17674.6680 - val_vae_kl_loss: 177.3214
# Epoch 7/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 3924.9877 - vae_r_loss: 3740.4805 - vae_kl_loss: 184.5066WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00007: val_loss improved from 17851.95891 to 16540.13809, saving model to vae_kdh_batch10_timestep1_ckpt.07-16540.138.h5
# 11700/11700 [==============================] - 501s 43ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3924.9877 - vae_r_loss: 3740.4805 - vae_kl_loss: 184.5066 - val_loss: 16540.1381 - val_vae_r_loss: 16360.5166 - val_vae_kl_loss: 179.6457
# Epoch 8/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 3528.2681 - vae_r_loss: 3343.1736 - vae_kl_loss: 185.1002WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00008: val_loss improved from 16540.13809 to 15436.73972, saving model to vae_kdh_batch10_timestep1_ckpt.08-15436.740.h5
# 11700/11700 [==============================] - 527s 45ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3528.2681 - vae_r_loss: 3343.1736 - vae_kl_loss: 185.1002 - val_loss: 15436.7397 - val_vae_r_loss: 15258.5918 - val_vae_kl_loss: 178.1198
# Epoch 9/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 3440.3510 - vae_r_loss: 3254.4951 - vae_kl_loss: 185.8578WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00009: val_loss improved from 15436.73972 to 14351.95875, saving model to vae_kdh_batch10_timestep1_ckpt.09-14351.959.h5
# 11700/11700 [==============================] - 523s 45ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3440.2684 - vae_r_loss: 3254.4119 - vae_kl_loss: 185.8586 - val_loss: 14351.9587 - val_vae_r_loss: 14175.8281 - val_vae_kl_loss: 176.1447
# Epoch 10/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 3174.8752 - vae_r_loss: 2990.1531 - vae_kl_loss: 184.7187- ETA: 6s - WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00010: val_loss improved from 14351.95875 to 13602.54091, saving model to vae_kdh_batch10_timestep1_ckpt.10-13602.541.h5
# 11700/11700 [==============================] - 512s 44ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3174.8752 - vae_r_loss: 2990.1531 - vae_kl_loss: 184.7187 - val_loss: 13602.5409 - val_vae_r_loss: 13422.5420 - val_vae_kl_loss: 180.0032
# Epoch 11/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 3116.8981 - vae_r_loss: 2929.5042 - vae_kl_loss: 187.3849WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00011: val_loss improved from 13602.54091 to 13059.15657, saving model to vae_kdh_batch10_timestep1_ckpt.11-13059.157.h5
# 11700/11700 [==============================] - 455s 39ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3117.5540 - vae_r_loss: 2930.1597 - vae_kl_loss: 187.3854 - val_loss: 13059.1566 - val_vae_r_loss: 12877.0225 - val_vae_kl_loss: 182.1040
# Epoch 12/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 3029.3190 - vae_r_loss: 2842.5703 - vae_kl_loss: 186.7526WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00012: val_loss improved from 13059.15657 to 12715.40056, saving model to vae_kdh_batch10_timestep1_ckpt.12-12715.401.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 3029.2801 - vae_r_loss: 2842.5312 - vae_kl_loss: 186.7526 - val_loss: 12715.4006 - val_vae_r_loss: 12532.2188 - val_vae_kl_loss: 183.1606
# Epoch 13/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2789.7825 - vae_r_loss: 2603.4756 - vae_kl_loss: 186.3056WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00013: val_loss improved from 12715.40056 to 11976.27042, saving model to vae_kdh_batch10_timestep1_ckpt.13-11976.270.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2789.7825 - vae_r_loss: 2603.4756 - vae_kl_loss: 186.3056 - val_loss: 11976.2704 - val_vae_r_loss: 11794.7148 - val_vae_kl_loss: 181.5561
# Epoch 14/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2719.3729 - vae_r_loss: 2532.6384 - vae_kl_loss: 186.7350WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00014: val_loss improved from 11976.27042 to 11440.37860, saving model to vae_kdh_batch10_timestep1_ckpt.14-11440.379.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2719.2363 - vae_r_loss: 2532.5027 - vae_kl_loss: 186.7340 - val_loss: 11440.3786 - val_vae_r_loss: 11258.4492 - val_vae_kl_loss: 181.9439
# Epoch 15/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2594.0314 - vae_r_loss: 2407.8525 - vae_kl_loss: 186.1746WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00015: val_loss improved from 11440.37860 to 11277.33579, saving model to vae_kdh_batch10_timestep1_ckpt.15-11277.336.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2594.0314 - vae_r_loss: 2407.8525 - vae_kl_loss: 186.1746 - val_loss: 11277.3358 - val_vae_r_loss: 11096.2979 - val_vae_kl_loss: 181.0257
# Epoch 16/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2536.8172 - vae_r_loss: 2349.7996 - vae_kl_loss: 187.0172WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00016: val_loss improved from 11277.33579 to 10747.39177, saving model to vae_kdh_batch10_timestep1_ckpt.16-10747.392.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2536.8172 - vae_r_loss: 2349.7996 - vae_kl_loss: 187.0172 - val_loss: 10747.3918 - val_vae_r_loss: 10564.8896 - val_vae_kl_loss: 182.5006
# Epoch 17/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2500.1644 - vae_r_loss: 2313.7456 - vae_kl_loss: 186.4165WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00017: val_loss improved from 10747.39177 to 10532.64060, saving model to vae_kdh_batch10_timestep1_ckpt.17-10532.641.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2500.1265 - vae_r_loss: 2313.7073 - vae_kl_loss: 186.4170 - val_loss: 10532.6406 - val_vae_r_loss: 10351.0557 - val_vae_kl_loss: 181.5771
# Epoch 18/100000
# 11698/11700 [============================>.] - ETA: 0s - batch: 5848.5000 - size: 10.0000 - loss: 2237.4231 - vae_r_loss: 2051.3635 - vae_kl_loss: 186.0619WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00018: val_loss improved from 10532.64060 to 10203.57314, saving model to vae_kdh_batch10_timestep1_ckpt.18-10203.573.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2237.3268 - vae_r_loss: 2051.2666 - vae_kl_loss: 186.0625 - val_loss: 10203.5731 - val_vae_r_loss: 10021.7891 - val_vae_kl_loss: 181.7994
# Epoch 19/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 2266.6723 - vae_r_loss: 2079.8826 - vae_kl_loss: 186.7869WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00019: val_loss improved from 10203.57314 to 9946.01032, saving model to vae_kdh_batch10_timestep1_ckpt.19-9946.010.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2266.5995 - vae_r_loss: 2079.8105 - vae_kl_loss: 186.7863 - val_loss: 9946.0103 - val_vae_r_loss: 9762.7256 - val_vae_kl_loss: 183.2821
# Epoch 20/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2223.1167 - vae_r_loss: 2035.7284 - vae_kl_loss: 187.3900WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00020: val_loss improved from 9946.01032 to 9779.63530, saving model to vae_kdh_batch10_timestep1_ckpt.20-9779.635.h5
# 11700/11700 [==============================] - 390s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2223.1167 - vae_r_loss: 2035.7284 - vae_kl_loss: 187.3900 - val_loss: 9779.6353 - val_vae_r_loss: 9597.2227 - val_vae_kl_loss: 182.4113
# Epoch 21/100000
# 11698/11700 [============================>.] - ETA: 0s - batch: 5848.5000 - size: 10.0000 - loss: 2208.1166 - vae_r_loss: 2021.3474 - vae_kl_loss: 186.7656WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00021: val_loss improved from 9779.63530 to 9311.93513, saving model to vae_kdh_batch10_timestep1_ckpt.21-9311.935.h5
# 11700/11700 [==============================] - 394s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2207.9796 - vae_r_loss: 2021.2102 - vae_kl_loss: 186.7658 - val_loss: 9311.9351 - val_vae_r_loss: 9130.0752 - val_vae_kl_loss: 181.8554
# Epoch 22/100000
# 11698/11700 [============================>.] - ETA: 0s - batch: 5848.5000 - size: 10.0000 - loss: 2204.5502 - vae_r_loss: 2018.4536 - vae_kl_loss: 186.0951WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00022: val_loss improved from 9311.93513 to 9216.91071, saving model to vae_kdh_batch10_timestep1_ckpt.22-9216.911.h5
# 11700/11700 [==============================] - 395s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2204.4142 - vae_r_loss: 2018.3181 - vae_kl_loss: 186.0946 - val_loss: 9216.9107 - val_vae_r_loss: 9035.3818 - val_vae_kl_loss: 181.5325
# Epoch 23/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 2114.4839 - vae_r_loss: 1926.8904 - vae_kl_loss: 187.5892WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00023: val_loss improved from 9216.91071 to 8884.34475, saving model to vae_kdh_batch10_timestep1_ckpt.23-8884.345.h5
# 11700/11700 [==============================] - 392s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 2114.4839 - vae_r_loss: 1926.8904 - vae_kl_loss: 187.5892 - val_loss: 8884.3448 - val_vae_r_loss: 8700.5117 - val_vae_kl_loss: 183.8253
# Epoch 24/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1995.3528 - vae_r_loss: 1809.3031 - vae_kl_loss: 186.0498WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00024: val_loss did not improve from 8884.34475
# 11700/11700 [==============================] - 390s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1995.3528 - vae_r_loss: 1809.3031 - vae_kl_loss: 186.0498 - val_loss: 8922.2700 - val_vae_r_loss: 8740.9697 - val_vae_kl_loss: 181.3078
# Epoch 25/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1958.9935 - vae_r_loss: 1773.6416 - vae_kl_loss: 185.3506WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00025: val_loss improved from 8884.34475 to 8587.39624, saving model to vae_kdh_batch10_timestep1_ckpt.25-8587.396.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1958.9935 - vae_r_loss: 1773.6416 - vae_kl_loss: 185.3506 - val_loss: 8587.3962 - val_vae_r_loss: 8403.3623 - val_vae_kl_loss: 184.0447
# Epoch 26/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1987.8767 - vae_r_loss: 1800.6525 - vae_kl_loss: 187.2238WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00026: val_loss did not improve from 8587.39624
# 11700/11700 [==============================] - 384s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1988.2249 - vae_r_loss: 1801.0018 - vae_kl_loss: 187.2228 - val_loss: 8647.7408 - val_vae_r_loss: 8464.7520 - val_vae_kl_loss: 182.9900
# Epoch 27/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1973.5691 - vae_r_loss: 1786.6871 - vae_kl_loss: 186.8858WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00027: val_loss improved from 8587.39624 to 8471.59650, saving model to vae_kdh_batch10_timestep1_ckpt.27-8471.597.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1973.5220 - vae_r_loss: 1786.6396 - vae_kl_loss: 186.8861 - val_loss: 8471.5965 - val_vae_r_loss: 8287.5127 - val_vae_kl_loss: 184.0842
# Epoch 28/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1927.1008 - vae_r_loss: 1741.0509 - vae_kl_loss: 186.0437WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00028: val_loss improved from 8471.59650 to 8168.40617, saving model to vae_kdh_batch10_timestep1_ckpt.28-8168.406.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1927.0399 - vae_r_loss: 1740.9904 - vae_kl_loss: 186.0435 - val_loss: 8168.4062 - val_vae_r_loss: 7986.8804 - val_vae_kl_loss: 181.5324
# Epoch 29/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1834.8060 - vae_r_loss: 1649.8760 - vae_kl_loss: 184.9338WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00029: val_loss improved from 8168.40617 to 7984.47431, saving model to vae_kdh_batch10_timestep1_ckpt.29-7984.474.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1834.7384 - vae_r_loss: 1649.8093 - vae_kl_loss: 184.9327 - val_loss: 7984.4743 - val_vae_r_loss: 7802.0820 - val_vae_kl_loss: 182.4043
# Epoch 30/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1799.7671 - vae_r_loss: 1615.2133 - vae_kl_loss: 184.5517WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00030: val_loss did not improve from 7984.47431
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1799.7091 - vae_r_loss: 1615.1552 - vae_kl_loss: 184.5518 - val_loss: 7997.1984 - val_vae_r_loss: 7816.5752 - val_vae_kl_loss: 180.6303
# Epoch 31/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1810.3216 - vae_r_loss: 1626.0864 - vae_kl_loss: 184.2349WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00031: val_loss improved from 7984.47431 to 7897.05639, saving model to vae_kdh_batch10_timestep1_ckpt.31-7897.056.h5
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1810.3216 - vae_r_loss: 1626.0864 - vae_kl_loss: 184.2349 - val_loss: 7897.0564 - val_vae_r_loss: 7716.5947 - val_vae_kl_loss: 180.4703
# Epoch 32/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1727.4503 - vae_r_loss: 1543.7166 - vae_kl_loss: 183.7392WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00032: val_loss improved from 7897.05639 to 7586.94926, saving model to vae_kdh_batch10_timestep1_ckpt.32-7586.949.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1727.4503 - vae_r_loss: 1543.7166 - vae_kl_loss: 183.7392 - val_loss: 7586.9493 - val_vae_r_loss: 7405.5928 - val_vae_kl_loss: 181.3623
# Epoch 33/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1721.2944 - vae_r_loss: 1537.4871 - vae_kl_loss: 183.8066WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00033: val_loss did not improve from 7586.94926
# 11700/11700 [==============================] - 384s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1721.2406 - vae_r_loss: 1537.4330 - vae_kl_loss: 183.8068 - val_loss: 7669.6513 - val_vae_r_loss: 7489.5303 - val_vae_kl_loss: 180.1247
# Epoch 34/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1664.0620 - vae_r_loss: 1481.2802 - vae_kl_loss: 182.7834WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00034: val_loss improved from 7586.94926 to 7539.86417, saving model to vae_kdh_batch10_timestep1_ckpt.34-7539.864.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1664.0115 - vae_r_loss: 1481.2296 - vae_kl_loss: 182.7834 - val_loss: 7539.8642 - val_vae_r_loss: 7358.2715 - val_vae_kl_loss: 181.5931
# Epoch 35/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1658.8844 - vae_r_loss: 1475.0559 - vae_kl_loss: 183.8253WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00035: val_loss improved from 7539.86417 to 7479.58435, saving model to vae_kdh_batch10_timestep1_ckpt.35-7479.584.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1658.8844 - vae_r_loss: 1475.0559 - vae_kl_loss: 183.8253 - val_loss: 7479.5843 - val_vae_r_loss: 7298.4526 - val_vae_kl_loss: 181.1378
# Epoch 36/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1692.1431 - vae_r_loss: 1509.3197 - vae_kl_loss: 182.8207WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00036: val_loss improved from 7479.58435 to 7221.64706, saving model to vae_kdh_batch10_timestep1_ckpt.36-7221.647.h5
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1692.1858 - vae_r_loss: 1509.3625 - vae_kl_loss: 182.8206 - val_loss: 7221.6471 - val_vae_r_loss: 7042.5586 - val_vae_kl_loss: 179.0935
# Epoch 37/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1651.4022 - vae_r_loss: 1468.5895 - vae_kl_loss: 182.8138WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00037: val_loss improved from 7221.64706 to 7040.65727, saving model to vae_kdh_batch10_timestep1_ckpt.37-7040.657.h5
# 11700/11700 [==============================] - 389s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1651.3617 - vae_r_loss: 1468.5485 - vae_kl_loss: 182.8143 - val_loss: 7040.6573 - val_vae_r_loss: 6860.4243 - val_vae_kl_loss: 180.2500
# Epoch 38/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1612.5870 - vae_r_loss: 1429.7687 - vae_kl_loss: 182.8203WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00038: val_loss improved from 7040.65727 to 6871.38216, saving model to vae_kdh_batch10_timestep1_ckpt.38-6871.382.h5
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1612.5409 - vae_r_loss: 1429.7222 - vae_kl_loss: 182.8208 - val_loss: 6871.3822 - val_vae_r_loss: 6690.9180 - val_vae_kl_loss: 180.4592
# Epoch 39/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1612.9253 - vae_r_loss: 1430.5781 - vae_kl_loss: 182.3471WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00039: val_loss did not improve from 6871.38216
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1612.8988 - vae_r_loss: 1430.5518 - vae_kl_loss: 182.3469 - val_loss: 6893.7982 - val_vae_r_loss: 6713.4653 - val_vae_kl_loss: 180.3300
# Epoch 40/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1640.2423 - vae_r_loss: 1457.1365 - vae_kl_loss: 183.1078WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00040: val_loss improved from 6871.38216 to 6759.07397, saving model to vae_kdh_batch10_timestep1_ckpt.40-6759.074.h5
# 11700/11700 [==============================] - 392s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1640.3523 - vae_r_loss: 1457.2463 - vae_kl_loss: 183.1079 - val_loss: 6759.0740 - val_vae_r_loss: 6578.2930 - val_vae_kl_loss: 180.7818
# Epoch 41/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1590.7330 - vae_r_loss: 1408.0641 - vae_kl_loss: 182.6678WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00041: val_loss did not improve from 6759.07397
# 11700/11700 [==============================] - 392s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1590.9841 - vae_r_loss: 1408.3157 - vae_kl_loss: 182.6674 - val_loss: 6771.4743 - val_vae_r_loss: 6590.5942 - val_vae_kl_loss: 180.8793
# Epoch 42/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1565.1800 - vae_r_loss: 1382.4744 - vae_kl_loss: 182.7069WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00042: val_loss improved from 6759.07397 to 6696.81758, saving model to vae_kdh_batch10_timestep1_ckpt.42-6696.818.h5
# 11700/11700 [==============================] - 398s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1565.1669 - vae_r_loss: 1382.4612 - vae_kl_loss: 182.7071 - val_loss: 6696.8176 - val_vae_r_loss: 6515.9985 - val_vae_kl_loss: 180.8241
# Epoch 43/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1573.5978 - vae_r_loss: 1391.3340 - vae_kl_loss: 182.2639WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00043: val_loss did not improve from 6696.81758
# 11700/11700 [==============================] - 394s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1573.5831 - vae_r_loss: 1391.3193 - vae_kl_loss: 182.2638 - val_loss: 6702.1154 - val_vae_r_loss: 6521.3599 - val_vae_kl_loss: 180.7596
# Epoch 44/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1541.1521 - vae_r_loss: 1358.7650 - vae_kl_loss: 182.3868WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00044: val_loss improved from 6696.81758 to 6385.66765, saving model to vae_kdh_batch10_timestep1_ckpt.44-6385.668.h5
# 11700/11700 [==============================] - 389s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1541.1521 - vae_r_loss: 1358.7650 - vae_kl_loss: 182.3868 - val_loss: 6385.6676 - val_vae_r_loss: 6204.8760 - val_vae_kl_loss: 180.7941
# Epoch 45/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1508.3052 - vae_r_loss: 1326.4990 - vae_kl_loss: 181.8080WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00045: val_loss improved from 6385.66765 to 6383.22294, saving model to vae_kdh_batch10_timestep1_ckpt.45-6383.223.h5
# 11700/11700 [==============================] - 387s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1508.4415 - vae_r_loss: 1326.6365 - vae_kl_loss: 181.8069 - val_loss: 6383.2229 - val_vae_r_loss: 6203.5898 - val_vae_kl_loss: 179.6239
# Epoch 46/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1524.3868 - vae_r_loss: 1342.8759 - vae_kl_loss: 181.5097WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00046: val_loss improved from 6383.22294 to 6377.51600, saving model to vae_kdh_batch10_timestep1_ckpt.46-6377.516.h5
# 11700/11700 [==============================] - 387s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1524.3570 - vae_r_loss: 1342.8456 - vae_kl_loss: 181.5102 - val_loss: 6377.5160 - val_vae_r_loss: 6198.8052 - val_vae_kl_loss: 178.7133
# Epoch 47/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1458.1734 - vae_r_loss: 1277.3502 - vae_kl_loss: 180.8239WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00047: val_loss did not improve from 6377.51600
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1458.2542 - vae_r_loss: 1277.4324 - vae_kl_loss: 180.8226 - val_loss: 6433.8275 - val_vae_r_loss: 6253.6680 - val_vae_kl_loss: 180.1563
# Epoch 48/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1485.5484 - vae_r_loss: 1304.3965 - vae_kl_loss: 181.1507WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00048: val_loss improved from 6377.51600 to 6269.57963, saving model to vae_kdh_batch10_timestep1_ckpt.48-6269.580.h5
# 11700/11700 [==============================] - 387s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1485.5213 - vae_r_loss: 1304.3688 - vae_kl_loss: 181.1512 - val_loss: 6269.5796 - val_vae_r_loss: 6090.2661 - val_vae_kl_loss: 179.3150
# Epoch 49/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1450.7554 - vae_r_loss: 1269.9631 - vae_kl_loss: 180.7956WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00049: val_loss improved from 6269.57963 to 6185.60896, saving model to vae_kdh_batch10_timestep1_ckpt.49-6185.609.h5
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1450.7554 - vae_r_loss: 1269.9631 - vae_kl_loss: 180.7956 - val_loss: 6185.6090 - val_vae_r_loss: 6007.1963 - val_vae_kl_loss: 178.4148
# Epoch 50/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1437.4393 - vae_r_loss: 1256.5856 - vae_kl_loss: 180.8545WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00050: val_loss improved from 6185.60896 to 6137.43430, saving model to vae_kdh_batch10_timestep1_ckpt.50-6137.434.h5
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1437.5089 - vae_r_loss: 1256.6560 - vae_kl_loss: 180.8537 - val_loss: 6137.4343 - val_vae_r_loss: 5958.5903 - val_vae_kl_loss: 178.8472
# Epoch 51/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1396.1530 - vae_r_loss: 1216.4979 - vae_kl_loss: 179.6524WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00051: val_loss improved from 6137.43430 to 6005.67877, saving model to vae_kdh_batch10_timestep1_ckpt.51-6005.679.h5
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1396.1530 - vae_r_loss: 1216.4979 - vae_kl_loss: 179.6524 - val_loss: 6005.6788 - val_vae_r_loss: 5827.2036 - val_vae_kl_loss: 178.4661
# Epoch 52/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1376.4906 - vae_r_loss: 1196.6804 - vae_kl_loss: 179.8090WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00052: val_loss improved from 6005.67877 to 5982.22434, saving model to vae_kdh_batch10_timestep1_ckpt.52-5982.224.h5
# 11700/11700 [==============================] - 384s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1376.4763 - vae_r_loss: 1196.6656 - vae_kl_loss: 179.8094 - val_loss: 5982.2243 - val_vae_r_loss: 5804.3892 - val_vae_kl_loss: 177.8363
# Epoch 53/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1386.0307 - vae_r_loss: 1206.3955 - vae_kl_loss: 179.6346WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00053: val_loss did not improve from 5982.22434
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1386.0740 - vae_r_loss: 1206.4398 - vae_kl_loss: 179.6335 - val_loss: 6017.3295 - val_vae_r_loss: 5838.9258 - val_vae_kl_loss: 178.4132
# Epoch 54/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1354.4915 - vae_r_loss: 1175.2925 - vae_kl_loss: 179.1973WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00054: val_loss did not improve from 5982.22434
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1354.4915 - vae_r_loss: 1175.2925 - vae_kl_loss: 179.1973 - val_loss: 5998.1788 - val_vae_r_loss: 5820.3291 - val_vae_kl_loss: 177.8467
# Epoch 55/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1377.9143 - vae_r_loss: 1199.0693 - vae_kl_loss: 178.8481WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00055: val_loss improved from 5982.22434 to 5837.09000, saving model to vae_kdh_batch10_timestep1_ckpt.55-5837.090.h5
# 11700/11700 [==============================] - 387s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1377.8784 - vae_r_loss: 1199.0328 - vae_kl_loss: 178.8486 - val_loss: 5837.0900 - val_vae_r_loss: 5660.5645 - val_vae_kl_loss: 176.5259
# Epoch 56/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1353.2454 - vae_r_loss: 1175.1522 - vae_kl_loss: 178.0962WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00056: val_loss improved from 5837.09000 to 5704.04171, saving model to vae_kdh_batch10_timestep1_ckpt.56-5704.042.h5
# 11700/11700 [==============================] - 387s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1353.2454 - vae_r_loss: 1175.1522 - vae_kl_loss: 178.0962 - val_loss: 5704.0417 - val_vae_r_loss: 5527.3584 - val_vae_kl_loss: 176.6897
# Epoch 57/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1321.8358 - vae_r_loss: 1142.4440 - vae_kl_loss: 179.3949WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00057: val_loss did not improve from 5704.04171
# 11700/11700 [==============================] - 386s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1321.7957 - vae_r_loss: 1142.4036 - vae_kl_loss: 179.3952 - val_loss: 5728.4917 - val_vae_r_loss: 5550.4766 - val_vae_kl_loss: 178.0127
# Epoch 58/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1300.9136 - vae_r_loss: 1122.8931 - vae_kl_loss: 178.0201WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00058: val_loss improved from 5704.04171 to 5606.51997, saving model to vae_kdh_batch10_timestep1_ckpt.58-5606.520.h5
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1300.8724 - vae_r_loss: 1122.8527 - vae_kl_loss: 178.0193 - val_loss: 5606.5200 - val_vae_r_loss: 5430.3789 - val_vae_kl_loss: 176.1448
# Epoch 59/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1331.0789 - vae_r_loss: 1151.5088 - vae_kl_loss: 179.5720WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00059: val_loss improved from 5606.51997 to 5443.62386, saving model to vae_kdh_batch10_timestep1_ckpt.59-5443.624.h5
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1331.0789 - vae_r_loss: 1151.5088 - vae_kl_loss: 179.5720 - val_loss: 5443.6239 - val_vae_r_loss: 5266.7949 - val_vae_kl_loss: 176.8304
# Epoch 60/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1358.8951 - vae_r_loss: 1179.9135 - vae_kl_loss: 178.9843WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00060: val_loss did not improve from 5443.62386
# 11700/11700 [==============================] - 391s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1358.8951 - vae_r_loss: 1179.9135 - vae_kl_loss: 178.9843 - val_loss: 5473.8266 - val_vae_r_loss: 5297.0034 - val_vae_kl_loss: 176.8326
# Epoch 61/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1270.0945 - vae_r_loss: 1092.6074 - vae_kl_loss: 177.4870WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00061: val_loss improved from 5443.62386 to 5424.28270, saving model to vae_kdh_batch10_timestep1_ckpt.61-5424.283.h5
# 11700/11700 [==============================] - 394s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1270.0945 - vae_r_loss: 1092.6074 - vae_kl_loss: 177.4870 - val_loss: 5424.2827 - val_vae_r_loss: 5248.2549 - val_vae_kl_loss: 176.0257
# Epoch 62/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1294.0719 - vae_r_loss: 1116.2812 - vae_kl_loss: 177.7903WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00062: val_loss improved from 5424.28270 to 5351.99703, saving model to vae_kdh_batch10_timestep1_ckpt.62-5351.997.h5
# 11700/11700 [==============================] - 396s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1294.0331 - vae_r_loss: 1116.2427 - vae_kl_loss: 177.7902 - val_loss: 5351.9970 - val_vae_r_loss: 5175.6104 - val_vae_kl_loss: 176.3832
# Epoch 63/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1286.7998 - vae_r_loss: 1108.8893 - vae_kl_loss: 177.9100WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00063: val_loss improved from 5351.99703 to 5349.68697, saving model to vae_kdh_batch10_timestep1_ckpt.63-5349.687.h5
# 11700/11700 [==============================] - 392s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1286.8199 - vae_r_loss: 1108.9091 - vae_kl_loss: 177.9103 - val_loss: 5349.6870 - val_vae_r_loss: 5173.4458 - val_vae_kl_loss: 176.2392
# Epoch 64/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1275.4663 - vae_r_loss: 1097.9680 - vae_kl_loss: 177.4995WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00064: val_loss improved from 5349.68697 to 5162.30849, saving model to vae_kdh_batch10_timestep1_ckpt.64-5162.308.h5
# 11700/11700 [==============================] - 393s 34ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1275.4452 - vae_r_loss: 1097.9464 - vae_kl_loss: 177.5000 - val_loss: 5162.3085 - val_vae_r_loss: 4987.3691 - val_vae_kl_loss: 174.9433
# Epoch 65/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1264.2111 - vae_r_loss: 1087.0925 - vae_kl_loss: 177.1201WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00065: val_loss did not improve from 5162.30849
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1264.2111 - vae_r_loss: 1087.0925 - vae_kl_loss: 177.1201 - val_loss: 5346.6464 - val_vae_r_loss: 5172.0771 - val_vae_kl_loss: 174.5651
# Epoch 66/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1191.1827 - vae_r_loss: 1014.8594 - vae_kl_loss: 176.3226WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00066: val_loss did not improve from 5162.30849
# 11700/11700 [==============================] - 385s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1191.1592 - vae_r_loss: 1014.8358 - vae_kl_loss: 176.3226 - val_loss: 5234.3673 - val_vae_r_loss: 5059.2466 - val_vae_kl_loss: 175.1133
# Epoch 67/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 1251.4751 - vae_r_loss: 1074.8280 - vae_kl_loss: 176.6487WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00067: val_loss did not improve from 5162.30849
# 11700/11700 [==============================] - 388s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1251.4569 - vae_r_loss: 1074.8094 - vae_kl_loss: 176.6489 - val_loss: 5187.0559 - val_vae_r_loss: 5012.7227 - val_vae_kl_loss: 174.3407
# Epoch 68/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1218.6604 - vae_r_loss: 1041.8119 - vae_kl_loss: 176.8512WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00068: val_loss did not improve from 5162.30849
# 11700/11700 [==============================] - 384s 33ms/step - batch: 5849.5000 - size: 10.0000 - loss: 1218.6604 - vae_r_loss: 1041.8119 - vae_kl_loss: 176.8512 - val_loss: 5231.0937 - val_vae_r_loss: 5056.5283 - val_vae_kl_loss: 174.5623
# Epoch 69/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 1238.4445 - vae_r_loss: 1061.9999 - vae_kl_loss: 176.4436WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# ...
# Epoch 1582/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 525.5188 - vae_r_loss: 377.4524 - vae_kl_loss: 148.0674WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01582: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 525.5188 - vae_r_loss: 377.4524 - vae_kl_loss: 148.0674 - val_loss: 2467.6177 - val_vae_r_loss: 2320.4194 - val_vae_kl_loss: 147.1989
# Epoch 1583/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 520.1340 - vae_r_loss: 372.9117 - vae_kl_loss: 147.2232WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01583: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 408s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 520.1340 - vae_r_loss: 372.9117 - vae_kl_loss: 147.2232 - val_loss: 2436.9442 - val_vae_r_loss: 2289.8948 - val_vae_kl_loss: 147.0482
# Epoch 1584/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 523.5614 - vae_r_loss: 375.9266 - vae_kl_loss: 147.6344WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01584: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 523.5614 - vae_r_loss: 375.9266 - vae_kl_loss: 147.6344 - val_loss: 2445.8122 - val_vae_r_loss: 2298.7158 - val_vae_kl_loss: 147.0977
# Epoch 1585/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 527.2181 - vae_r_loss: 379.4977 - vae_kl_loss: 147.7214WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01585: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 411s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 527.2215 - vae_r_loss: 379.4998 - vae_kl_loss: 147.7227 - val_loss: 2431.1764 - val_vae_r_loss: 2283.9270 - val_vae_kl_loss: 147.2485
# Epoch 1586/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 528.3473 - vae_r_loss: 380.3100 - vae_kl_loss: 148.0370WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01586: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 412s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 528.3470 - vae_r_loss: 380.3096 - vae_kl_loss: 148.0371 - val_loss: 2426.8267 - val_vae_r_loss: 2279.7065 - val_vae_kl_loss: 147.1180
# Epoch 1587/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 522.5294 - vae_r_loss: 375.0736 - vae_kl_loss: 147.4551WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01587: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 413s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 522.5294 - vae_r_loss: 375.0736 - vae_kl_loss: 147.4551 - val_loss: 2431.5221 - val_vae_r_loss: 2284.6443 - val_vae_kl_loss: 146.8812
# Epoch 1588/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 522.2811 - vae_r_loss: 374.9904 - vae_kl_loss: 147.2906WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01588: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 522.2871 - vae_r_loss: 374.9961 - vae_kl_loss: 147.2908 - val_loss: 2459.4353 - val_vae_r_loss: 2312.8030 - val_vae_kl_loss: 146.6312
# Epoch 1589/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 523.1491 - vae_r_loss: 375.8549 - vae_kl_loss: 147.2942WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01589: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 417s 36ms/step - batch: 5849.5000 - size: 10.0000 - loss: 523.1459 - vae_r_loss: 375.8523 - vae_kl_loss: 147.2936 - val_loss: 2454.6929 - val_vae_r_loss: 2307.6384 - val_vae_kl_loss: 147.0533
# Epoch 1590/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 520.3569 - vae_r_loss: 373.3029 - vae_kl_loss: 147.0547WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01590: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 412s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 520.3569 - vae_r_loss: 373.3029 - vae_kl_loss: 147.0547 - val_loss: 2436.5043 - val_vae_r_loss: 2289.6824 - val_vae_kl_loss: 146.8235
# Epoch 1591/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 523.7730 - vae_r_loss: 376.2429 - vae_kl_loss: 147.5315WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01591: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 413s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 523.7730 - vae_r_loss: 376.2429 - vae_kl_loss: 147.5315 - val_loss: 2416.5971 - val_vae_r_loss: 2269.6494 - val_vae_kl_loss: 146.9461
# Epoch 1592/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 523.3519 - vae_r_loss: 376.1945 - vae_kl_loss: 147.1582WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01592: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 413s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 523.3519 - vae_r_loss: 376.1945 - vae_kl_loss: 147.1582 - val_loss: 2419.9372 - val_vae_r_loss: 2273.1143 - val_vae_kl_loss: 146.8221
# Epoch 1593/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 526.5252 - vae_r_loss: 378.8496 - vae_kl_loss: 147.6758WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01593: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 526.5252 - vae_r_loss: 378.8496 - vae_kl_loss: 147.6758 - val_loss: 2387.9768 - val_vae_r_loss: 2240.8679 - val_vae_kl_loss: 147.1114
# Epoch 1594/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 523.9534 - vae_r_loss: 376.7263 - vae_kl_loss: 147.2267WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01594: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 523.9534 - vae_r_loss: 376.7263 - vae_kl_loss: 147.2267 - val_loss: 2366.6072 - val_vae_r_loss: 2219.6392 - val_vae_kl_loss: 146.9722
# Epoch 1595/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 526.9716 - vae_r_loss: 378.4716 - vae_kl_loss: 148.4993WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01595: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 412s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 526.9716 - vae_r_loss: 378.4716 - vae_kl_loss: 148.4993 - val_loss: 2362.3912 - val_vae_r_loss: 2215.5171 - val_vae_kl_loss: 146.8698
# Epoch 1596/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 529.3038 - vae_r_loss: 380.9102 - vae_kl_loss: 148.3936WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01596: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 409s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 529.3062 - vae_r_loss: 380.9129 - vae_kl_loss: 148.3933 - val_loss: 2376.3858 - val_vae_r_loss: 2229.5007 - val_vae_kl_loss: 146.8844
# Epoch 1597/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 524.2568 - vae_r_loss: 377.0826 - vae_kl_loss: 147.1744WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01597: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 416s 36ms/step - batch: 5849.5000 - size: 10.0000 - loss: 524.2628 - vae_r_loss: 377.0870 - vae_kl_loss: 147.1761 - val_loss: 2403.2719 - val_vae_r_loss: 2256.2917 - val_vae_kl_loss: 146.9794
# Epoch 1598/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 524.3402 - vae_r_loss: 376.9593 - vae_kl_loss: 147.3816WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01598: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 524.3402 - vae_r_loss: 376.9593 - vae_kl_loss: 147.3816 - val_loss: 2401.1216 - val_vae_r_loss: 2254.4248 - val_vae_kl_loss: 146.6944
# Epoch 1599/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 526.4056 - vae_r_loss: 378.9939 - vae_kl_loss: 147.4121WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01599: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 526.4056 - vae_r_loss: 378.9939 - vae_kl_loss: 147.4121 - val_loss: 2407.5378 - val_vae_r_loss: 2260.7585 - val_vae_kl_loss: 146.7800
# Epoch 1600/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 527.8689 - vae_r_loss: 379.9491 - vae_kl_loss: 147.9199WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01600: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 527.8689 - vae_r_loss: 379.9491 - vae_kl_loss: 147.9199 - val_loss: 2417.2345 - val_vae_r_loss: 2270.6492 - val_vae_kl_loss: 146.5845
# Epoch 1601/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 527.1559 - vae_r_loss: 379.3788 - vae_kl_loss: 147.7776WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01601: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 407s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 527.1559 - vae_r_loss: 379.3788 - vae_kl_loss: 147.7776 - val_loss: 2401.7330 - val_vae_r_loss: 2255.3699 - val_vae_kl_loss: 146.3642
# Epoch 1602/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 519.8308 - vae_r_loss: 372.9474 - vae_kl_loss: 146.8833WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01602: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 519.8325 - vae_r_loss: 372.9489 - vae_kl_loss: 146.8836 - val_loss: 2402.9307 - val_vae_r_loss: 2256.1836 - val_vae_kl_loss: 146.7439
# Epoch 1603/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 524.4076 - vae_r_loss: 376.6788 - vae_kl_loss: 147.7285WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01603: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 524.4076 - vae_r_loss: 376.6788 - vae_kl_loss: 147.7285 - val_loss: 2381.9671 - val_vae_r_loss: 2235.3281 - val_vae_kl_loss: 146.6381
# Epoch 1604/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 525.9928 - vae_r_loss: 378.3221 - vae_kl_loss: 147.6699WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01604: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 410s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 525.9928 - vae_r_loss: 378.3221 - vae_kl_loss: 147.6699 - val_loss: 2387.0141 - val_vae_r_loss: 2240.3962 - val_vae_kl_loss: 146.6188
# Epoch 1605/100000
# 11700/11700 [==============================] - ETA: 0s - batch: 5849.5000 - size: 10.0000 - loss: 524.9456 - vae_r_loss: 376.8448 - vae_kl_loss: 148.1017- ETA: 1s - batch: 5815.5000 - size: 10.0000 - loss: 524.9292 - vae_r_loss: 3WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 01605: val_loss did not improve from 2349.76405
# 11700/11700 [==============================] - 414s 35ms/step - batch: 5849.5000 - size: 10.0000 - loss: 524.9456 - vae_r_loss: 376.8448 - vae_kl_loss: 148.1017 - val_loss: 2381.5071 - val_vae_r_loss: 2234.4631 - val_vae_kl_loss: 147.0423
# Epoch 1606/100000
# 11699/11700 [============================>.] - ETA: 0s - batch: 5849.0000 - size: 10.0000 - loss: 527.2727 - vae_r_loss: 379.6168 - vae_kl_loss: 147.6549- ETA: 0s - batch: 5841.5000 - size: 10.0000 - loss: 527.2643 - vae_r_loss: 379.6084 - vae_kl_loss: 14WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def plot_latent_space(trained_decoder, pimage, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    image = np.array(image).astype("float32")/255.0
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.5])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_tstr = np.array([0.3])
    X_tvel = np.expand_dims(X_tstr, axis=0)
    X_ttime = np.array([0.1])
    X_tvel = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    X_train = [image, X_tstr, X_tvel, X_ttime]

    x_encoded = VarAE.predict(X_train)*255.0
    # print(x_encoded)
    x_encoded_out = np.squeeze(x_encoded,axis=0)
    # pred_image = np.zeros([160,160,3], np.uint8)
    pred_image = array_to_img(x_encoded_out)
    pred_image = np.array(pred_image)
    pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # pred_img = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # print(type(pred_img))
    # print(pred_image.shape)
    plt.imshow(pred_image)
    # plt.imshow(cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB))
    plt.show()

    origin_image_name = '/home2/kdh/vae/vae_test/2022-12-08-14-30-12-332957.jpg'
    cv2.imwrite('/')
    # plt.xticks(pixel_range, sample_range_x)
    # plt.yticks(pixel_range, sample_range_y)
    # plt.xlabel("z[0]")
    # plt.ylabel("z[1]")

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-30-12-332957.jpg')
# plot_latent_space(decoder, test_img)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space(trained_decoder, valid_data, n=50, figsize=15):
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in valid_data:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))

        cv2.imwrite('/home2/kdh/vae/vae_test/'+image_name, image)
        image = np.array(image).astype("float32")/255.0
        # image = image_process.process(image)
        steering_angle, throttle, brake = measurement
        
        image = np.expand_dims(image, axis=0)
        X_tvel = np.array([velocity])
        X_tvel = np.expand_dims(X_tvel, axis=0)
        X_tstr = np.array([steering_angle])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_ttime = np.array([tar_time])
        X_ttime = np.expand_dims(X_ttime, axis=0)
        
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image)
        # plt.imshow(pred_image)
        # plt.show()

        # image_name = '/home2/kdh/vae/vae_test/'+image_name
        pred_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'.jpg'
        gt_tar_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'_gt.jpg'
        cv2.imwrite(pred_image_name, pred_image)
        cv2.imwrite(gt_tar_image_name, tar_image)

        # print(pred_image_name,' done')
        # cv2.imwrite('/')


# save_latent_space(decoder, valid_data[3423:4422])

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space_diff_steer(trained_decoder, pimage, save_image_name, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    cv2.imwrite('/home2/kdh/vae/vae_diff_steer_test/'+save_image_name+'.jpg', image)
    image = np.array(image).astype("float32")/255.0
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.85])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_ttime = np.array([0.8])
    X_ttime = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    for s in np.arange(0, 0.8, 0.0125):
        X_tstr = np.array([s-0.4])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
        s_str = "{:.3f}".format(s)
        pred_image_name = ('/home2/kdh/vae/vae_diff_steer_test/'
                            +save_image_name
                            +'_'+str(s_str)
                            +'.jpg'
        )
        cv2.imwrite(pred_image_name, pred_image)
    
        

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-35-43-708754.jpg')
# save_latent_space_diff_steer(decoder, test_img, '2022-12-08-14-35-43-708754')
