# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
# from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Activation, LeakyReLU, Dropout, BatchNormalization, MaxPooling2D, Lambda
from keras.models import Model
from sklearn.metrics import mean_squared_error as mse
from progressbar import ProgressBar
from image_process import ImageProcess
import const, cv2
from drive_data import DriveData
from config import Config

import matplotlib.pyplot as plt
import sys
sys.setrecursionlimit(10**7)
tf.compat.v1.disable_eager_execution()
# Out:
# =======================================================
#                Configuration Settings
# =======================================================
# Neural Net:     	fusion_kdh_jaerock3
# Data Collection:	fusion_kdh_jaerock3
# Run Neural:     	fusion_kdh_jaerock3

# %%
"""
## Dataset
"""
image_process = ImageProcess()
config = Config.neural_net
# data_path = "/mnt/exData/internal_simulation/test/2022-03-08-17-18-14/"
data_path = "/home2/kdh/av/latent/dataset/2022-12-08-14-25-28/"
if data_path[-1] == '/':
    data_path = data_path[:-1]

    loc_slash = data_path.rfind('/')
    if loc_slash != -1: # there is '/' in the data path
        model_name = data_path[loc_slash + 1:] # get folder name
        #model_name = model_name.strip('/')
    else:
        model_name = data_path
csv_path = data_path + '/' + model_name + const.DATA_EXT 
# data = DriveData(csv_path)
print(csv_path)
# data_path = data_path
# data.read()

csv_header = ['image_fname', 
                  'steering_angle', 'throttle', 'brake', 'linux_time', 
                  'vel', 'vel_x', 'vel_y', 'vel_z', 
                  'pos_x', 'pos_y', 'pos_z', 
                  'tar_image_fname', 'tar_steering_angle', 'tar_vel', 'tar_time']

df = pd.read_csv(csv_path, names=csv_header, index_col=False)
num_data = len(df)

bar = ProgressBar()
df_image_names = []
df_measurements = []
df_time_stamps= []
df_velocities= []
df_velocities_xyz= []
df_positions_xyz= []
df_tar_image_names= []
df_tar_steering_angle= []
df_tar_vel= []
df_tar_time= []
for i in bar(range(num_data)): # we don't have a title
    df_image_names.append(df.loc[i]['image_fname'])
    # if Config.data_collection['brake'] is True:
    df_measurements.append((float(df.loc[i]['steering_angle']),
                            float(df.loc[i]['throttle']), 
                            float(df.loc[i]['brake'])))
    df_time_stamps.append(float(df.loc[i]['linux_time']))
    df_velocities.append(float(df.loc[i]['vel']))
    df_velocities_xyz.append((float(df.loc[i]['vel_x']), 
                                float(df.loc[i]['vel_y']), 
                                float(df.loc[i]['vel_z'])))
    df_positions_xyz.append((float(df.loc[i]['pos_x']), 
                                float(df.loc[i]['pos_y']), 
                                float(df.loc[i]['pos_z'])))
    df_tar_image_names.append(df.loc[i]['tar_image_fname'])
    df_tar_steering_angle.append(float(df.loc[i]['tar_steering_angle']))
    df_tar_vel.append(float(df.loc[i]['tar_vel']))
    df_tar_time.append(float(df.loc[i]['tar_time']))
# Out:
# /home2/kdh/av/latent/dataset/2022-12-08-14-25-28/2022-12-08-14-25-28.csv
# 100% |########################################################################|

# %%
samples = list(zip( df_image_names, df_velocities, df_measurements, 
                    df_tar_image_names, df_tar_steering_angle, df_tar_vel, df_tar_time))

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
gpu_config = tf.compat.v1.ConfigProto()
gpu_config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=gpu_config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

sys.setrecursionlimit(10**7)
tf.compat.v1.disable_eager_execution()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2529432141190499619
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 19459014656
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3629612926758377456
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:18:00.0, compute capability: 8.6"
# ]

# %%
def prepare_vae_batch_samples(batch_samples):
    images = []
    steering_angles = []
    vels = []
    tar_images = []
    tar_steering_angles = []
    tar_vels = []
    tar_times = []
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in batch_samples:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        if Config.data_collection['crop'] is not True:
            image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
            tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        image = image_process.process(image)
        tar_image = image_process.process(tar_image)

        vels.append(velocity)
        tar_vels.append(tar_vel)
        tar_times.append(tar_time)
        tar_steering_angles.append(tar_steering_angle)
        # if no brake data in collected data, brake values are dummy
        steering_angle, throttle, brake = measurement
        steering_angles.append(steering_angle)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/image/'+image_name, image)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/tar_image/'+tar_image_name, tar_image)
        # if data == 'train':
        #     cv2.imwrite('/mnt/Data/oscar/train_data/'+image_name, image)
        # print(image.shape)
        images.append(image)
        tar_images.append(tar_image)
        # segimgs.append(segimg)


    return images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times

# %%
"""
## Encoder
"""

"""
## Create a sampling layer
"""
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon


encoder_inputs_img = tf.keras.Input(shape=(160, 160, 3))
encoder_inputs_str = tf.keras.Input(shape=(1))
encoder_inputs_vel = tf.keras.Input(shape=(1))
encoder_inputs_time = tf.keras.Input(shape=(1))
x = layers.Conv2D(24, (5, 5), padding='same', name='conv2d_1')(encoder_inputs_img)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1')(x)

x = layers.Conv2D(36, (5, 5), padding='same', name='conv2d_2')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_2')(x)

x = layers.Conv2D(48, (5, 5), padding='same', name='conv2d_3')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2d_4')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)

x = layers.Conv2D(64, (3, 3), padding='same', name='conv2d_5')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('elu')(x)
latent = layers.Flatten()(x)

fc_s1  = layers.Dense(100)(encoder_inputs_str)
fc_s1  = layers.Activation('elu')(fc_s1)
fc_s2  = layers.Dense(50)(fc_s1)
fc_s2  = layers.Activation('elu')(fc_s2)

fc_v1  = layers.Dense(100)(encoder_inputs_vel)
fc_v1  = layers.Activation('elu')(fc_v1)
fc_v2  = layers.Dense(50)(fc_v1)
fc_v2  = layers.Activation('elu')(fc_v2)

fc_t1  = layers.Dense(100)(encoder_inputs_time)
fc_t1  = layers.Activation('elu')(fc_t1)
fc_t2  = layers.Dense(50)(fc_t1)
fc_t2  = layers.Activation('elu')(fc_t2)

conc_i_v_t = layers.concatenate([latent, fc_v2, fc_t2])
fc_1_ivt   = layers.Dense(100)(conc_i_v_t)
fc_1_ivt   = layers.Activation('elu')(fc_1_ivt)

conc_i_s  = layers.concatenate([latent, fc_s2])
fc_1_is   = layers.Dense(100)(conc_i_s)
fc_1_is   = layers.Activation('elu')(fc_1_is)

z_mean_ivt = layers.Dense(50, name="z_mean_ivt")(fc_1_ivt)
z_log_var_ivt = layers.Dense(50, name="z_log_var_ivt")(fc_1_ivt)
z_mean_is = layers.Dense(50, name="z_mean_is")(fc_1_is)
z_log_var_is = layers.Dense(50, name="z_log_var_is")(fc_1_is)

encoder_output_ivt = Sampling()([z_mean_ivt, z_log_var_ivt])
encoder_output_is = Sampling()([z_mean_is, z_log_var_is])
encoder = tf.keras.Model([ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time], 
                        [ z_mean_ivt, z_log_var_ivt, z_mean_is, z_log_var_is, 
                        encoder_output_ivt, encoder_output_is], 
                        name="encoder")
encoder.summary()
# Out:
# WARNING:tensorflow:From /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 24) 1824        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160, 160, 24) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 160, 160, 24) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# pool2d_1 (MaxPooling2D)         (None, 80, 80, 24)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 80, 80, 36)   21636       pool2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 80, 36)   144         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 80, 80, 36)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# pool2d_2 (MaxPooling2D)         (None, 40, 40, 36)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 40, 40, 48)   43248       pool2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40, 40, 48)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 40, 40, 48)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 64)   27712       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 40, 40, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 40, 40, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          200         input_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          200         input_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          200         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 40, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 50)           5050        activation_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           5050        activation_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           5050        activation_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 102400)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 102500)       0           flatten[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 102450)       0           flatten[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          10250100    concatenate[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100)          10245100    concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# z_mean_ivt (Dense)              (None, 50)           5050        activation_11[0][0]
# __________________________________________________________________________________________________
# z_log_var_ivt (Dense)           (None, 50)           5050        activation_11[0][0]
# __________________________________________________________________________________________________
# z_mean_is (Dense)               (None, 50)           5050        activation_12[0][0]
# __________________________________________________________________________________________________
# z_log_var_is (Dense)            (None, 50)           5050        activation_12[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 50)           0           z_mean_ivt[0][0]
#                                                                  z_log_var_ivt[0][0]
# __________________________________________________________________________________________________
# sampling_1 (Sampling)           (None, 50)           0           z_mean_is[0][0]
#                                                                  z_log_var_is[0][0]
# ==================================================================================================
# Total params: 20,663,442
# Trainable params: 20,662,970
# Non-trainable params: 472
# __________________________________________________________________________________________________

# %%
"""
## Decoder
"""

ivt_latent_inputs = tf.keras.Input(shape=(50,))
is_latent_inputs = tf.keras.Input(shape=(50,))
x1 = layers.Dense(200, activation="elu")(ivt_latent_inputs)
x2 = layers.Dense(200, activation="elu")(is_latent_inputs)
conc_x = layers.concatenate([x1, x2])
x = layers.Dense(40 * 40 * 64, activation="elu")(conc_x)
x = layers.Reshape((40, 40, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="elu",  padding="same")(x)
x = layers.Conv2DTranspose(36, 3, activation="elu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(24, 3, activation="elu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = tf.keras.Model(inputs=[ivt_latent_inputs, is_latent_inputs], outputs=decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 200)          10200       input_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 200)          10200       input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 400)          0           dense_8[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 102400)       41062400    concatenate_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 40, 40, 64)   0           dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 40, 40, 64)   36928       reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 80, 80, 36)   20772       conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 160, 160, 24) 7800        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 3)  651         conv2d_transpose_2[0][0]
# ==================================================================================================
# Total params: 41,148,951
# Trainable params: 41,148,951
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
"""
## VAE
"""
# [ encoder_inputs_img, encoder_inputs_str,
# encoder_inputs_vel, encoder_inputs_time], 
# [ z_mean_ivt, z_log_var_ivt, z_mean_is, z_log_var_is, 
# encoder_output_ivt, encoder_output_is]
model_input = [ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time]
model_output = decoder([encoder_output_ivt, encoder_output_is])

VarAE=Model(model_input, model_output)
# VarAE.run_eagerly = True

# %%
"""
Data generator
"""
from sklearn.model_selection import train_test_split

def _generator(samples, batch_size=config['batch_size']):
    num_samples = len(samples)
    while True: # Loop forever so the generator never terminates
        for offset in range(0, (num_samples//batch_size)*batch_size, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times = prepare_vae_batch_samples(batch_samples)

            X_img = np.array(images).astype("float32")/255.0
            X_tvel = np.array(tar_vels).astype("float32")
            X_tstr = np.array(tar_steering_angles).astype("float32")
            X_ttime = np.array(tar_times).astype("float32")

            y_train = np.array(tar_images).astype("float32")/255.0
            # if config['num_outputs'] == 1:
            # y_train = np.array(segimg)
            # print(y_train.max())
            # y_train = np.repeat(y_train[..., np.newaxis], 1, -1)/y_train.max()
            X_train = [X_img, X_tstr, X_tvel, X_ttime]
            # print(X_tstr, X_tvel, X_ttime)
            # print(y_train)
            # print(y_train.shape)
            yield X_train, y_train

train_data, valid_data = train_test_split(samples, test_size=config['validation_rate'])

train_generator = _generator(train_data, config['batch_size'])
valid_generator = _generator(valid_data, config['batch_size'])

# %%
"""
VAE loss
"""
optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.0000001)
# optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.00000001)
#                                  learning_rate=0.000005,decay=0.0000000001
r_loss_factor=160*160*100   # This is a Hyperparameter

def vae_r_loss(y_true, y_pred):    ## MSE
    r_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_pred), axis=[1,2,3])
    return r_loss_factor * r_loss

def vae_kl_loss(y_true, y_pred):   ## KL-Divergence
    kl_loss_ivt=( -0.5 * tf.keras.backend.sum(1+z_log_var_ivt 
                - tf.keras.backend.square(z_mean_ivt) 
                - tf.keras.backend.exp(z_log_var_ivt), axis=1)
    )
    kl_loss_is=( -0.5 * tf.keras.backend.sum(1+z_log_var_is 
                - tf.keras.backend.square(z_mean_is) 
                - tf.keras.backend.exp(z_log_var_is), axis=1)
    )
    return (kl_loss_ivt+kl_loss_is)*0.5

def vae_loss(y_true, y_pred): 
    r_loss=vae_r_loss(y_true, y_pred) #Loss of Decoder
    kl_loss = vae_kl_loss(y_true, y_pred) #Loss of Encoder
    return r_loss + kl_loss #Sum of these two


VarAE.compile(optimizer=optimizer,
                loss= vae_loss, 
                metrics=[vae_r_loss, vae_kl_loss])
# VarAE.summary()
#  vae_r_loss: 12.6586 - vae_kl_loss: 2251744.5000 
#  val_loss: 50649853.6174 
#  val_vae_r_loss: 28.6742 - val_vae_kl_loss: 50649896.0000

# %%
"""
## Train the VAE
"""
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.python.framework.ops import disable_eager_execution

        # checkpoint
callbacks = []
#weight_filename = self.data_path + '_' + Config.config_yaml_name \
#    + '_N' + str(config['network_type']) + '_ckpt'
model_ckpt_name = "vae_kdh_z2"
checkpoint = ModelCheckpoint(model_ckpt_name +'_ckpt.{epoch:02d}-{val_loss:.3f}.h5',
                                monitor='val_loss', 
                                verbose=1, save_best_only=True, mode='min')
callbacks.append(checkpoint)

# early stopping
patience = 1000
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, 
                            verbose=1, mode='min')
# callbacks.append(earlystop)

# validation_steps = len(valid_data)//config['batch_size']
# print(validation_steps)
train_hist = VarAE.fit( train_generator,  
                        steps_per_epoch=len(train_data)//config['batch_size'], 
                        epochs=100000, 
                        validation_data=valid_generator,
                        validation_steps=len(valid_data)//config['batch_size'],
                        # shuffle=True,
                        verbose=1, 
                        callbacks=callbacks, 
                        use_multiprocessing=True,
                        workers=48
                        )
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 13784161.4033 - vae_r_loss: 14659.4248 - vae_kl_loss: 13769264.0000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_loss improved from inf to 20175.29042, saving model to vae_kdh_z2_ckpt.01-20175.290.h5
# 3127/3127 [==============================] - 374s 117ms/step - batch: 1563.0000 - size: 32.0000 - loss: 13784161.4033 - vae_r_loss: 14659.4248 - vae_kl_loss: 13769264.0000 - val_loss: 20175.2904 - val_vae_r_loss: 19732.9258 - val_vae_kl_loss: 442.3662
# Epoch 2/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 174657404318.1189 - vae_r_loss: 9597.4453 - vae_kl_loss: 174657388544.0000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00002: val_loss did not improve from 20175.29042
# 3127/3127 [==============================] - 352s 113ms/step - batch: 1563.0000 - size: 32.0000 - loss: 174601549698.5977 - vae_r_loss: 9597.1279 - vae_kl_loss: 174601535488.0000 - val_loss: 22899.3046 - val_vae_r_loss: 20597.6367 - val_vae_kl_loss: 2301.6792
# Epoch 3/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 9523.4194 - vae_r_loss: 8466.7119 - vae_kl_loss: 1056.7147WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00003: val_loss did not improve from 20175.29042
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 9523.4194 - vae_r_loss: 8466.7119 - vae_kl_loss: 1056.7147 - val_loss: 20415.0837 - val_vae_r_loss: 19585.4746 - val_vae_kl_loss: 829.5920
# Epoch 4/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7973.5545 - vae_r_loss: 7332.4658 - vae_kl_loss: 641.0919WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00004: val_loss improved from 20175.29042 to 19987.06534, saving model to vae_kdh_z2_ckpt.04-19987.065.h5
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7973.5545 - vae_r_loss: 7332.4658 - vae_kl_loss: 641.0919 - val_loss: 19987.0653 - val_vae_r_loss: 19421.1602 - val_vae_kl_loss: 565.9008
# Epoch 5/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 7418.7781 - vae_r_loss: 6981.2905 - vae_kl_loss: 437.4882WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00005: val_loss improved from 19987.06534 to 19277.28173, saving model to vae_kdh_z2_ckpt.05-19277.282.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 7418.7781 - vae_r_loss: 6981.2905 - vae_kl_loss: 437.4882 - val_loss: 19277.2817 - val_vae_r_loss: 18890.9902 - val_vae_kl_loss: 386.2871
# Epoch 6/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6922.5997 - vae_r_loss: 6569.3296 - vae_kl_loss: 353.2642WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00006: val_loss improved from 19277.28173 to 18748.64413, saving model to vae_kdh_z2_ckpt.06-18748.644.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6922.5997 - vae_r_loss: 6569.3296 - vae_kl_loss: 353.2642 - val_loss: 18748.6441 - val_vae_r_loss: 18387.9707 - val_vae_kl_loss: 360.6680
# Epoch 7/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6749.7860 - vae_r_loss: 6410.6240 - vae_kl_loss: 339.1527WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00007: val_loss improved from 18748.64413 to 18289.77195, saving model to vae_kdh_z2_ckpt.07-18289.772.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6749.7860 - vae_r_loss: 6410.6240 - vae_kl_loss: 339.1527 - val_loss: 18289.7720 - val_vae_r_loss: 17939.2383 - val_vae_kl_loss: 350.5289
# Epoch 8/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6589.8072 - vae_r_loss: 6258.6694 - vae_kl_loss: 331.1499WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00008: val_loss improved from 18289.77195 to 18216.60032, saving model to vae_kdh_z2_ckpt.08-18216.600.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6589.8072 - vae_r_loss: 6258.6694 - vae_kl_loss: 331.1499 - val_loss: 18216.6003 - val_vae_r_loss: 17894.3086 - val_vae_kl_loss: 322.2885
# Epoch 9/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6376.3016 - vae_r_loss: 6064.0005 - vae_kl_loss: 312.2988WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00009: val_loss improved from 18216.60032 to 18136.38897, saving model to vae_kdh_z2_ckpt.09-18136.389.h5
# 3127/3127 [==============================] - 377s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6376.3016 - vae_r_loss: 6064.0005 - vae_kl_loss: 312.2988 - val_loss: 18136.3890 - val_vae_r_loss: 17831.5098 - val_vae_kl_loss: 304.8799
# Epoch 10/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6352.3012 - vae_r_loss: 6043.6899 - vae_kl_loss: 308.6131WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00010: val_loss did not improve from 18136.38897
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6352.3012 - vae_r_loss: 6043.6899 - vae_kl_loss: 308.6131 - val_loss: 18446.0462 - val_vae_r_loss: 18147.5293 - val_vae_kl_loss: 298.5146
# Epoch 11/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6310.3068 - vae_r_loss: 6010.2793 - vae_kl_loss: 300.0255WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00011: val_loss did not improve from 18136.38897
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6310.3068 - vae_r_loss: 6010.2793 - vae_kl_loss: 300.0255 - val_loss: 18662.2149 - val_vae_r_loss: 18376.9746 - val_vae_kl_loss: 285.2457
# Epoch 12/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6211.8876 - vae_r_loss: 5915.2925 - vae_kl_loss: 296.5961WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00012: val_loss did not improve from 18136.38897
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6211.8876 - vae_r_loss: 5915.2925 - vae_kl_loss: 296.5961 - val_loss: 18396.5943 - val_vae_r_loss: 18088.4570 - val_vae_kl_loss: 308.1371
# Epoch 13/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 6234.7705 - vae_r_loss: 5935.3564 - vae_kl_loss: 299.4136WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00013: val_loss improved from 18136.38897 to 17993.24850, saving model to vae_kdh_z2_ckpt.13-17993.249.h5
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 6234.7705 - vae_r_loss: 5935.3564 - vae_kl_loss: 299.4136 - val_loss: 17993.2485 - val_vae_r_loss: 17710.4316 - val_vae_kl_loss: 282.8159
# Epoch 14/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 5915.3972 - vae_r_loss: 5623.5093 - vae_kl_loss: 291.8888WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00014: val_loss did not improve from 17993.24850
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5915.4988 - vae_r_loss: 5623.6133 - vae_kl_loss: 291.8864 - val_loss: 18044.7288 - val_vae_r_loss: 17763.8086 - val_vae_kl_loss: 280.9289
# Epoch 15/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5912.4723 - vae_r_loss: 5620.2759 - vae_kl_loss: 292.2010WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00015: val_loss improved from 17993.24850 to 17632.01722, saving model to vae_kdh_z2_ckpt.15-17632.017.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5912.4723 - vae_r_loss: 5620.2759 - vae_kl_loss: 292.2010 - val_loss: 17632.0172 - val_vae_r_loss: 17359.2793 - val_vae_kl_loss: 272.7248
# Epoch 16/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 5649.7960 - vae_r_loss: 5366.3096 - vae_kl_loss: 283.4985WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00016: val_loss improved from 17632.01722 to 17572.09696, saving model to vae_kdh_z2_ckpt.16-17572.097.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5649.4551 - vae_r_loss: 5365.9751 - vae_kl_loss: 283.4920 - val_loss: 17572.0970 - val_vae_r_loss: 17299.1133 - val_vae_kl_loss: 272.9767
# Epoch 17/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5394.4923 - vae_r_loss: 5124.3457 - vae_kl_loss: 270.1497WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00017: val_loss improved from 17572.09696 to 16992.02964, saving model to vae_kdh_z2_ckpt.17-16992.030.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5394.4923 - vae_r_loss: 5124.3457 - vae_kl_loss: 270.1497 - val_loss: 16992.0296 - val_vae_r_loss: 16741.0332 - val_vae_kl_loss: 250.9865
# Epoch 18/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 14237060.7697 - vae_r_loss: 6084.1709 - vae_kl_loss: 14230662.0000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00018: val_loss did not improve from 16992.02964
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 14237060.7697 - vae_r_loss: 6084.1709 - vae_kl_loss: 14230662.0000 - val_loss: 18113.3466 - val_vae_r_loss: 17785.1680 - val_vae_kl_loss: 328.1683
# Epoch 19/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5726.9988 - vae_r_loss: 5409.6943 - vae_kl_loss: 317.3058WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00019: val_loss did not improve from 16992.02964
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5726.9988 - vae_r_loss: 5409.6943 - vae_kl_loss: 317.3058 - val_loss: 17196.6686 - val_vae_r_loss: 16914.1680 - val_vae_kl_loss: 282.5113
# Epoch 20/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5493.7095 - vae_r_loss: 5189.7109 - vae_kl_loss: 304.0019WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00020: val_loss improved from 16992.02964 to 16812.64148, saving model to vae_kdh_z2_ckpt.20-16812.641.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5493.7095 - vae_r_loss: 5189.7109 - vae_kl_loss: 304.0019 - val_loss: 16812.6415 - val_vae_r_loss: 16529.5156 - val_vae_kl_loss: 283.1231
# Epoch 21/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5230.6273 - vae_r_loss: 4942.4165 - vae_kl_loss: 288.2076WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00021: val_loss improved from 16812.64148 to 16317.15115, saving model to vae_kdh_z2_ckpt.21-16317.151.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5230.6273 - vae_r_loss: 4942.4165 - vae_kl_loss: 288.2076 - val_loss: 16317.1511 - val_vae_r_loss: 16040.0254 - val_vae_kl_loss: 277.1298
# Epoch 22/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 5086.8651 - vae_r_loss: 4804.0713 - vae_kl_loss: 282.7932WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00022: val_loss improved from 16317.15115 to 16075.01111, saving model to vae_kdh_z2_ckpt.22-16075.011.h5
# 3127/3127 [==============================] - 377s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5086.8651 - vae_r_loss: 4804.0713 - vae_kl_loss: 282.7932 - val_loss: 16075.0111 - val_vae_r_loss: 15805.4014 - val_vae_kl_loss: 269.6041
# Epoch 23/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 5091.0856 - vae_r_loss: 4818.3252 - vae_kl_loss: 272.7648WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00023: val_loss did not improve from 16075.01111
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 5090.7419 - vae_r_loss: 4817.9810 - vae_kl_loss: 272.7653 - val_loss: 16268.9882 - val_vae_r_loss: 16006.0928 - val_vae_kl_loss: 262.9012
# Epoch 24/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4829.7713 - vae_r_loss: 4556.5239 - vae_kl_loss: 273.2473WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00024: val_loss improved from 16075.01111 to 15342.09921, saving model to vae_kdh_z2_ckpt.24-15342.099.h5
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4829.7713 - vae_r_loss: 4556.5239 - vae_kl_loss: 273.2473 - val_loss: 15342.0992 - val_vae_r_loss: 15075.2197 - val_vae_kl_loss: 266.8889
# Epoch 25/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4751.4704 - vae_r_loss: 4484.7637 - vae_kl_loss: 266.7094WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00025: val_loss did not improve from 15342.09921
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4751.4704 - vae_r_loss: 4484.7637 - vae_kl_loss: 266.7094 - val_loss: 15581.3127 - val_vae_r_loss: 15312.7715 - val_vae_kl_loss: 268.5552
# Epoch 26/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4496.5392 - vae_r_loss: 4229.1035 - vae_kl_loss: 267.4369WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00026: val_loss did not improve from 15342.09921
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4496.5392 - vae_r_loss: 4229.1035 - vae_kl_loss: 267.4369 - val_loss: 15603.7703 - val_vae_r_loss: 15334.7627 - val_vae_kl_loss: 269.0074
# Epoch 27/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4412.9686 - vae_r_loss: 4147.1152 - vae_kl_loss: 265.8627WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00027: val_loss did not improve from 15342.09921
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4412.9686 - vae_r_loss: 4147.1152 - vae_kl_loss: 265.8627 - val_loss: 15584.0340 - val_vae_r_loss: 15325.5146 - val_vae_kl_loss: 258.5310
# Epoch 28/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4843.5828 - vae_r_loss: 4049.4561 - vae_kl_loss: 794.1299WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00028: val_loss did not improve from 15342.09921
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4843.5828 - vae_r_loss: 4049.4561 - vae_kl_loss: 794.1299 - val_loss: 16169.2524 - val_vae_r_loss: 15928.9014 - val_vae_kl_loss: 240.3598
# Epoch 29/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4402.4430 - vae_r_loss: 4156.4258 - vae_kl_loss: 246.0189WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00029: val_loss did not improve from 15342.09921
# 3127/3127 [==============================] - 381s 122ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4402.4430 - vae_r_loss: 4156.4258 - vae_kl_loss: 246.0189 - val_loss: 15453.7003 - val_vae_r_loss: 15208.9434 - val_vae_kl_loss: 244.7490
# Epoch 30/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4218.9410 - vae_r_loss: 3977.8386 - vae_kl_loss: 241.1032WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00030: val_loss improved from 15342.09921 to 15315.70260, saving model to vae_kdh_z2_ckpt.30-15315.703.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4218.9410 - vae_r_loss: 3977.8386 - vae_kl_loss: 241.1032 - val_loss: 15315.7026 - val_vae_r_loss: 15075.3896 - val_vae_kl_loss: 240.3096
# Epoch 31/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4038.1952 - vae_r_loss: 3797.5493 - vae_kl_loss: 240.6486WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00031: val_loss improved from 15315.70260 to 14645.95081, saving model to vae_kdh_z2_ckpt.31-14645.951.h5
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4038.1952 - vae_r_loss: 3797.5493 - vae_kl_loss: 240.6486 - val_loss: 14645.9508 - val_vae_r_loss: 14413.4316 - val_vae_kl_loss: 232.5303
# Epoch 32/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3873.1684 - vae_r_loss: 3633.9202 - vae_kl_loss: 239.2453WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00032: val_loss did not improve from 14645.95081
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3873.1684 - vae_r_loss: 3633.9202 - vae_kl_loss: 239.2453 - val_loss: 14669.4348 - val_vae_r_loss: 14441.0146 - val_vae_kl_loss: 228.4267
# Epoch 33/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3844.2800 - vae_r_loss: 3466.8132 - vae_kl_loss: 377.4636WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00033: val_loss did not improve from 14645.95081
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3844.2800 - vae_r_loss: 3466.8132 - vae_kl_loss: 377.4636 - val_loss: 16047.8996 - val_vae_r_loss: 15814.7178 - val_vae_kl_loss: 233.1812
# Epoch 34/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3849.1644 - vae_r_loss: 3612.1230 - vae_kl_loss: 237.0364WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00034: val_loss did not improve from 14645.95081
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3849.1644 - vae_r_loss: 3612.1230 - vae_kl_loss: 237.0364 - val_loss: 14745.7688 - val_vae_r_loss: 14517.2266 - val_vae_kl_loss: 228.5386
# Epoch 35/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3561.0455 - vae_r_loss: 3333.7883 - vae_kl_loss: 227.2580WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00035: val_loss improved from 14645.95081 to 14090.07060, saving model to vae_kdh_z2_ckpt.35-14090.071.h5
# 3127/3127 [==============================] - 377s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3561.0455 - vae_r_loss: 3333.7883 - vae_kl_loss: 227.2580 - val_loss: 14090.0706 - val_vae_r_loss: 13846.6611 - val_vae_kl_loss: 243.4044
# Epoch 36/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3445.7402 - vae_r_loss: 3219.8455 - vae_kl_loss: 225.8979WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00036: val_loss improved from 14090.07060 to 14022.76630, saving model to vae_kdh_z2_ckpt.36-14022.766.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3445.7402 - vae_r_loss: 3219.8455 - vae_kl_loss: 225.8979 - val_loss: 14022.7663 - val_vae_r_loss: 13798.8301 - val_vae_kl_loss: 223.9308
# Epoch 37/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3506.4846 - vae_r_loss: 3282.6677 - vae_kl_loss: 223.8170WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00037: val_loss improved from 14022.76630 to 13695.90172, saving model to vae_kdh_z2_ckpt.37-13695.902.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3506.0105 - vae_r_loss: 3282.1931 - vae_kl_loss: 223.8172 - val_loss: 13695.9017 - val_vae_r_loss: 13483.0791 - val_vae_kl_loss: 212.8322
# Epoch 38/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3209.4415 - vae_r_loss: 2992.4932 - vae_kl_loss: 216.9480WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00038: val_loss did not improve from 13695.90172
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3209.4415 - vae_r_loss: 2992.4932 - vae_kl_loss: 216.9480 - val_loss: 13741.5585 - val_vae_r_loss: 13529.9229 - val_vae_kl_loss: 211.6353
# Epoch 39/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3221.7661 - vae_r_loss: 3003.2466 - vae_kl_loss: 218.5190WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00039: val_loss did not improve from 13695.90172
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3221.7661 - vae_r_loss: 3003.2466 - vae_kl_loss: 218.5190 - val_loss: 13901.9655 - val_vae_r_loss: 13692.7100 - val_vae_kl_loss: 209.2541
# Epoch 40/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3225.4119 - vae_r_loss: 3012.7935 - vae_kl_loss: 212.6227WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00040: val_loss improved from 13695.90172 to 13301.06873, saving model to vae_kdh_z2_ckpt.40-13301.069.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3225.4119 - vae_r_loss: 3012.7935 - vae_kl_loss: 212.6227 - val_loss: 13301.0687 - val_vae_r_loss: 13094.5303 - val_vae_kl_loss: 206.5319
# Epoch 41/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3187.4610 - vae_r_loss: 2975.4600 - vae_kl_loss: 212.0007WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00041: val_loss did not improve from 13301.06873
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3187.4610 - vae_r_loss: 2975.4600 - vae_kl_loss: 212.0007 - val_loss: 13633.6614 - val_vae_r_loss: 13423.8818 - val_vae_kl_loss: 209.7860
# Epoch 42/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3037.3319 - vae_r_loss: 2825.4602 - vae_kl_loss: 211.8730WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00042: val_loss improved from 13301.06873 to 13298.11709, saving model to vae_kdh_z2_ckpt.42-13298.117.h5
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3037.3319 - vae_r_loss: 2825.4602 - vae_kl_loss: 211.8730 - val_loss: 13298.1171 - val_vae_r_loss: 13094.4004 - val_vae_kl_loss: 203.7093
# Epoch 43/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2880.4215 - vae_r_loss: 2672.8271 - vae_kl_loss: 207.5959WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00043: val_loss did not improve from 13298.11709
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2880.4215 - vae_r_loss: 2672.8271 - vae_kl_loss: 207.5959 - val_loss: 13301.3020 - val_vae_r_loss: 13094.6104 - val_vae_kl_loss: 206.6789
# Epoch 44/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3065.0532 - vae_r_loss: 2854.6265 - vae_kl_loss: 210.4298WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00044: val_loss improved from 13298.11709 to 13280.87116, saving model to vae_kdh_z2_ckpt.44-13280.871.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3065.0532 - vae_r_loss: 2854.6265 - vae_kl_loss: 210.4298 - val_loss: 13280.8712 - val_vae_r_loss: 13074.6943 - val_vae_kl_loss: 206.1876
# Epoch 45/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2933.5668 - vae_r_loss: 2725.0452 - vae_kl_loss: 208.5207WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00045: val_loss improved from 13280.87116 to 13237.58221, saving model to vae_kdh_z2_ckpt.45-13237.582.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2933.5668 - vae_r_loss: 2725.0452 - vae_kl_loss: 208.5207 - val_loss: 13237.5822 - val_vae_r_loss: 13033.0732 - val_vae_kl_loss: 204.5140
# Epoch 46/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2807.0022 - vae_r_loss: 2600.5747 - vae_kl_loss: 206.4294WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00046: val_loss improved from 13237.58221 to 13110.84260, saving model to vae_kdh_z2_ckpt.46-13110.843.h5
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2807.0022 - vae_r_loss: 2600.5747 - vae_kl_loss: 206.4294 - val_loss: 13110.8426 - val_vae_r_loss: 12906.5713 - val_vae_kl_loss: 204.2758
# Epoch 47/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2862.3471 - vae_r_loss: 2656.7427 - vae_kl_loss: 205.6018WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00047: val_loss improved from 13110.84260 to 12730.69544, saving model to vae_kdh_z2_ckpt.47-12730.695.h5
# 3127/3127 [==============================] - 380s 122ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2862.3471 - vae_r_loss: 2656.7427 - vae_kl_loss: 205.6018 - val_loss: 12730.6954 - val_vae_r_loss: 12529.8535 - val_vae_kl_loss: 200.8453
# Epoch 48/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 4966421.3899 - vae_r_loss: 2942.9905 - vae_kl_loss: 4963358.0000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00048: val_loss did not improve from 12730.69544
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 4966421.3899 - vae_r_loss: 2942.9905 - vae_kl_loss: 4963358.0000 - val_loss: 13351.9068 - val_vae_r_loss: 13119.1309 - val_vae_kl_loss: 232.7728
# Epoch 49/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3224.0396 - vae_r_loss: 2994.9294 - vae_kl_loss: 229.1146WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00049: val_loss did not improve from 12730.69544
# 3127/3127 [==============================] - 380s 122ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3224.0396 - vae_r_loss: 2994.9294 - vae_kl_loss: 229.1146 - val_loss: 13206.6317 - val_vae_r_loss: 12983.4658 - val_vae_kl_loss: 223.1747
# Epoch 50/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 3044.5584 - vae_r_loss: 2821.8997 - vae_kl_loss: 222.6628WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00050: val_loss improved from 12730.69544 to 12653.03936, saving model to vae_kdh_z2_ckpt.50-12653.039.h5
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3045.2944 - vae_r_loss: 2822.6396 - vae_kl_loss: 222.6588 - val_loss: 12653.0394 - val_vae_r_loss: 12434.5898 - val_vae_kl_loss: 218.4547
# Epoch 51/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2945.1887 - vae_r_loss: 2725.9185 - vae_kl_loss: 219.2703WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00051: val_loss improved from 12653.03936 to 12481.19487, saving model to vae_kdh_z2_ckpt.51-12481.195.h5
# 3127/3127 [==============================] - 381s 122ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2945.1887 - vae_r_loss: 2725.9185 - vae_kl_loss: 219.2703 - val_loss: 12481.1949 - val_vae_r_loss: 12263.0293 - val_vae_kl_loss: 218.1655
# Epoch 52/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2907.6698 - vae_r_loss: 2688.1877 - vae_kl_loss: 219.4844- ETA: 2s - batch: 1545.0000 - size: 32.0000 - loss: 2911.4826 - vae_r_loss: 269WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00052: val_loss improved from 12481.19487 to 12480.25270, saving model to vae_kdh_z2_ckpt.52-12480.253.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2907.6698 - vae_r_loss: 2688.1877 - vae_kl_loss: 219.4844 - val_loss: 12480.2527 - val_vae_r_loss: 12263.4678 - val_vae_kl_loss: 216.7816
# Epoch 53/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 3050.3773 - vae_r_loss: 2831.4785 - vae_kl_loss: 218.8955WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00053: val_loss improved from 12480.25270 to 12117.01132, saving model to vae_kdh_z2_ckpt.53-12117.011.h5
# 3127/3127 [==============================] - 380s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 3050.3773 - vae_r_loss: 2831.4785 - vae_kl_loss: 218.8955 - val_loss: 12117.0113 - val_vae_r_loss: 11902.1309 - val_vae_kl_loss: 214.8718
# Epoch 54/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2906.8349 - vae_r_loss: 2687.8167 - vae_kl_loss: 219.0199WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00054: val_loss did not improve from 12117.01132
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2906.8349 - vae_r_loss: 2687.8167 - vae_kl_loss: 219.0199 - val_loss: 12170.6934 - val_vae_r_loss: 11954.2012 - val_vae_kl_loss: 216.4924
# Epoch 55/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2732.1312 - vae_r_loss: 2516.5637 - vae_kl_loss: 215.5657WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00055: val_loss improved from 12117.01132 to 11798.05159, saving model to vae_kdh_z2_ckpt.55-11798.052.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2732.1312 - vae_r_loss: 2516.5637 - vae_kl_loss: 215.5657 - val_loss: 11798.0516 - val_vae_r_loss: 11583.0361 - val_vae_kl_loss: 215.0159
# Epoch 56/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2602.7492 - vae_r_loss: 2388.7500 - vae_kl_loss: 213.9983WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00056: val_loss improved from 11798.05159 to 11603.06255, saving model to vae_kdh_z2_ckpt.56-11603.063.h5
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2602.7492 - vae_r_loss: 2388.7500 - vae_kl_loss: 213.9983 - val_loss: 11603.0625 - val_vae_r_loss: 11388.4668 - val_vae_kl_loss: 214.5966
# Epoch 57/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2542.3825 - vae_r_loss: 2329.6348 - vae_kl_loss: 212.7475WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00057: val_loss improved from 11603.06255 to 11542.63822, saving model to vae_kdh_z2_ckpt.57-11542.638.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2542.3825 - vae_r_loss: 2329.6348 - vae_kl_loss: 212.7475 - val_loss: 11542.6382 - val_vae_r_loss: 11329.6699 - val_vae_kl_loss: 212.9624
# Epoch 58/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2481.1957 - vae_r_loss: 2271.5488 - vae_kl_loss: 209.6481WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00058: val_loss did not improve from 11542.63822
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2481.1957 - vae_r_loss: 2271.5488 - vae_kl_loss: 209.6481 - val_loss: 11651.0681 - val_vae_r_loss: 11442.2070 - val_vae_kl_loss: 208.8689
# Epoch 59/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2494.4096 - vae_r_loss: 2285.0964 - vae_kl_loss: 209.3124WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00059: val_loss improved from 11542.63822 to 11472.35016, saving model to vae_kdh_z2_ckpt.59-11472.350.h5
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2494.4096 - vae_r_loss: 2285.0964 - vae_kl_loss: 209.3124 - val_loss: 11472.3502 - val_vae_r_loss: 11264.8154 - val_vae_kl_loss: 207.5398
# Epoch 60/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 2470.1115 - vae_r_loss: 2264.1714 - vae_kl_loss: 205.9399WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00060: val_loss improved from 11472.35016 to 11078.15877, saving model to vae_kdh_z2_ckpt.60-11078.159.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2470.0082 - vae_r_loss: 2264.0657 - vae_kl_loss: 205.9423 - val_loss: 11078.1588 - val_vae_r_loss: 10872.5303 - val_vae_kl_loss: 205.6294
# Epoch 61/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2459.1602 - vae_r_loss: 2251.3118 - vae_kl_loss: 207.8479WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00061: val_loss improved from 11078.15877 to 11012.12440, saving model to vae_kdh_z2_ckpt.61-11012.124.h5
# 3127/3127 [==============================] - 380s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2459.1602 - vae_r_loss: 2251.3118 - vae_kl_loss: 207.8479 - val_loss: 11012.1244 - val_vae_r_loss: 10811.3096 - val_vae_kl_loss: 200.8182
# Epoch 62/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2410.9594 - vae_r_loss: 2205.7644 - vae_kl_loss: 205.1944WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00062: val_loss did not improve from 11012.12440
# 3127/3127 [==============================] - 381s 122ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2410.9594 - vae_r_loss: 2205.7644 - vae_kl_loss: 205.1944 - val_loss: 11116.4190 - val_vae_r_loss: 10912.2773 - val_vae_kl_loss: 204.1541
# Epoch 63/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2505.6436 - vae_r_loss: 2301.8625 - vae_kl_loss: 203.7843WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00063: val_loss improved from 11012.12440 to 10891.29459, saving model to vae_kdh_z2_ckpt.63-10891.295.h5
# 3127/3127 [==============================] - 381s 122ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2505.6436 - vae_r_loss: 2301.8625 - vae_kl_loss: 203.7843 - val_loss: 10891.2946 - val_vae_r_loss: 10689.0244 - val_vae_kl_loss: 202.2703
# Epoch 64/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2365.4443 - vae_r_loss: 2161.6831 - vae_kl_loss: 203.7628WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00064: val_loss did not improve from 10891.29459
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2365.4443 - vae_r_loss: 2161.6831 - vae_kl_loss: 203.7628 - val_loss: 11032.2619 - val_vae_r_loss: 10830.4248 - val_vae_kl_loss: 201.8312
# Epoch 65/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2442.3049 - vae_r_loss: 2235.7754 - vae_kl_loss: 206.5292WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00065: val_loss improved from 10891.29459 to 10828.72748, saving model to vae_kdh_z2_ckpt.65-10828.727.h5
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2442.3049 - vae_r_loss: 2235.7754 - vae_kl_loss: 206.5292 - val_loss: 10828.7275 - val_vae_r_loss: 10623.5918 - val_vae_kl_loss: 205.1369
# Epoch 66/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2354.8057 - vae_r_loss: 2150.8066 - vae_kl_loss: 203.9974WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00066: val_loss did not improve from 10828.72748
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2354.8057 - vae_r_loss: 2150.8066 - vae_kl_loss: 203.9974 - val_loss: 10830.9553 - val_vae_r_loss: 10628.8936 - val_vae_kl_loss: 202.0591
# Epoch 67/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2369.8913 - vae_r_loss: 2167.2031 - vae_kl_loss: 202.6861WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00067: val_loss improved from 10828.72748 to 10661.93290, saving model to vae_kdh_z2_ckpt.67-10661.933.h5
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2369.8913 - vae_r_loss: 2167.2031 - vae_kl_loss: 202.6861 - val_loss: 10661.9329 - val_vae_r_loss: 10462.5703 - val_vae_kl_loss: 199.3674
# Epoch 68/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2235.9961 - vae_r_loss: 2035.8101 - vae_kl_loss: 200.1882WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00068: val_loss improved from 10661.93290 to 10340.80365, saving model to vae_kdh_z2_ckpt.68-10340.804.h5
# 3127/3127 [==============================] - 377s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2235.9961 - vae_r_loss: 2035.8101 - vae_kl_loss: 200.1882 - val_loss: 10340.8037 - val_vae_r_loss: 10146.0781 - val_vae_kl_loss: 194.7271
# Epoch 69/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2311.1375 - vae_r_loss: 2111.2563 - vae_kl_loss: 199.8812- ETA: 5s - batch: 1529.0000 - size: 32.0000 WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00069: val_loss did not improve from 10340.80365
# 3127/3127 [==============================] - 377s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2311.1375 - vae_r_loss: 2111.2563 - vae_kl_loss: 199.8812 - val_loss: 10458.0793 - val_vae_r_loss: 10261.1982 - val_vae_kl_loss: 196.8725
# Epoch 70/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2198.9010 - vae_r_loss: 1997.5599 - vae_kl_loss: 201.3387WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00070: val_loss did not improve from 10340.80365
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 2198.9010 - vae_r_loss: 1997.5599 - vae_kl_loss: 201.3387 - val_loss: 10430.7329 - val_vae_r_loss: 10230.2861 - val_vae_kl_loss: 200.4465
# Epoch 71/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 2299.1064 - vae_r_loss: 2099.1973 - vae_kl_loss: 199.9098WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# ...
#
# Epoch 00717: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 737.6077 - vae_r_loss: 605.2175 - vae_kl_loss: 132.3905 - val_loss: 4759.5814 - val_vae_r_loss: 4627.5342 - val_vae_kl_loss: 132.0480
# Epoch 718/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 734.8011 - vae_r_loss: 602.4764 - vae_kl_loss: 132.3241WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00718: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 734.8011 - vae_r_loss: 602.4764 - vae_kl_loss: 132.3241 - val_loss: 4702.7126 - val_vae_r_loss: 4570.8359 - val_vae_kl_loss: 131.8754
# Epoch 719/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 725.9201 - vae_r_loss: 593.8462 - vae_kl_loss: 132.0738WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00719: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 725.9201 - vae_r_loss: 593.8462 - vae_kl_loss: 132.0738 - val_loss: 4744.0782 - val_vae_r_loss: 4611.7979 - val_vae_kl_loss: 132.2772
# Epoch 720/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 727.9354 - vae_r_loss: 595.8149 - vae_kl_loss: 132.1202WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00720: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 727.9051 - vae_r_loss: 595.7849 - vae_kl_loss: 132.1200 - val_loss: 4723.7942 - val_vae_r_loss: 4592.3926 - val_vae_kl_loss: 131.4029
# Epoch 721/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 727.9780 - vae_r_loss: 596.0991 - vae_kl_loss: 131.8793WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00721: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 727.9836 - vae_r_loss: 596.1055 - vae_kl_loss: 131.8783 - val_loss: 4750.5880 - val_vae_r_loss: 4618.7959 - val_vae_kl_loss: 131.7934
# Epoch 722/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 730.9172 - vae_r_loss: 599.3240 - vae_kl_loss: 131.5927WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00722: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 730.8866 - vae_r_loss: 599.2941 - vae_kl_loss: 131.5921 - val_loss: 4753.7181 - val_vae_r_loss: 4621.4282 - val_vae_kl_loss: 132.2888
# Epoch 723/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 726.2238 - vae_r_loss: 594.7429 - vae_kl_loss: 131.4817WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00723: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 726.2238 - vae_r_loss: 594.7429 - vae_kl_loss: 131.4817 - val_loss: 4745.6062 - val_vae_r_loss: 4613.7012 - val_vae_kl_loss: 131.9066
# Epoch 724/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 734.3832 - vae_r_loss: 602.3527 - vae_kl_loss: 132.0301- ETA: 9s - baWARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00724: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 734.3832 - vae_r_loss: 602.3527 - vae_kl_loss: 132.0301 - val_loss: 4700.8051 - val_vae_r_loss: 4569.3062 - val_vae_kl_loss: 131.4980
# Epoch 725/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 744.5690 - vae_r_loss: 612.2451 - vae_kl_loss: 132.3233WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00725: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 744.5690 - vae_r_loss: 612.2451 - vae_kl_loss: 132.3233 - val_loss: 4688.1208 - val_vae_r_loss: 4555.6338 - val_vae_kl_loss: 132.4873
# Epoch 726/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 745.5448 - vae_r_loss: 613.1063 - vae_kl_loss: 132.4379WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00726: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 372s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 745.5448 - vae_r_loss: 613.1063 - vae_kl_loss: 132.4379 - val_loss: 4796.2989 - val_vae_r_loss: 4664.7339 - val_vae_kl_loss: 131.5631
# Epoch 727/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 736.7551 - vae_r_loss: 605.2056 - vae_kl_loss: 131.5501- ETA: 3s - batch: 1543.5000 - size: 32.0000 - loss: 736.2303 - vae_r_loss:WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00727: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 736.7551 - vae_r_loss: 605.2056 - vae_kl_loss: 131.5501 - val_loss: 4719.9067 - val_vae_r_loss: 4588.2808 - val_vae_kl_loss: 131.6258
# Epoch 728/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 728.1727 - vae_r_loss: 596.5072 - vae_kl_loss: 131.6652WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00728: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 728.1727 - vae_r_loss: 596.5072 - vae_kl_loss: 131.6652 - val_loss: 4685.6332 - val_vae_r_loss: 4553.6226 - val_vae_kl_loss: 132.0105
# Epoch 729/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 724.6091 - vae_r_loss: 593.3055 - vae_kl_loss: 131.3040WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00729: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 724.6091 - vae_r_loss: 593.3055 - vae_kl_loss: 131.3040 - val_loss: 4655.3512 - val_vae_r_loss: 4523.6240 - val_vae_kl_loss: 131.7294
# Epoch 730/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 727.2041 - vae_r_loss: 595.6240 - vae_kl_loss: 131.5803WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00730: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 370s 118ms/step - batch: 1563.0000 - size: 32.0000 - loss: 727.2041 - vae_r_loss: 595.6240 - vae_kl_loss: 131.5803 - val_loss: 4651.9622 - val_vae_r_loss: 4520.2080 - val_vae_kl_loss: 131.7534
# Epoch 731/100000
# 3126/3127 [============================>.] - ETA: 0s - batch: 1562.5000 - size: 32.0000 - loss: 723.1213 - vae_r_loss: 591.7568 - vae_kl_loss: 131.3640WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00731: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 723.1047 - vae_r_loss: 591.7408 - vae_kl_loss: 131.3633 - val_loss: 4752.4591 - val_vae_r_loss: 4621.7007 - val_vae_kl_loss: 130.7609
# Epoch 732/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 736.4729 - vae_r_loss: 604.9972 - vae_kl_loss: 131.4761WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00732: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 736.4729 - vae_r_loss: 604.9972 - vae_kl_loss: 131.4761 - val_loss: 4691.3601 - val_vae_r_loss: 4559.5063 - val_vae_kl_loss: 131.8513
# Epoch 733/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 733.2709 - vae_r_loss: 601.4557 - vae_kl_loss: 131.8150WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00733: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 733.2709 - vae_r_loss: 601.4557 - vae_kl_loss: 131.8150 - val_loss: 4679.3482 - val_vae_r_loss: 4548.1670 - val_vae_kl_loss: 131.1792
# Epoch 734/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 731.3985 - vae_r_loss: 600.0720 - vae_kl_loss: 131.3267WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00734: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 731.3985 - vae_r_loss: 600.0720 - vae_kl_loss: 131.3267 - val_loss: 4650.1852 - val_vae_r_loss: 4518.9985 - val_vae_kl_loss: 131.1862
# Epoch 735/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 727.5647 - vae_r_loss: 596.2656 - vae_kl_loss: 131.3000WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00735: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 378s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 727.5647 - vae_r_loss: 596.2656 - vae_kl_loss: 131.3000 - val_loss: 4697.6902 - val_vae_r_loss: 4566.2319 - val_vae_kl_loss: 131.4596
# Epoch 736/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 721.5349 - vae_r_loss: 590.4507 - vae_kl_loss: 131.0845WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00736: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 373s 119ms/step - batch: 1563.0000 - size: 32.0000 - loss: 721.5349 - vae_r_loss: 590.4507 - vae_kl_loss: 131.0845 - val_loss: 4677.0844 - val_vae_r_loss: 4546.1045 - val_vae_kl_loss: 130.9785
# Epoch 737/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 727.2152 - vae_r_loss: 596.2740 - vae_kl_loss: 130.9415WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00737: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 727.2152 - vae_r_loss: 596.2740 - vae_kl_loss: 130.9415 - val_loss: 4682.6847 - val_vae_r_loss: 4551.4531 - val_vae_kl_loss: 131.2286
# Epoch 738/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 734.6619 - vae_r_loss: 603.4540 - vae_kl_loss: 131.2079WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00738: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 374s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 734.6619 - vae_r_loss: 603.4540 - vae_kl_loss: 131.2079 - val_loss: 4687.9030 - val_vae_r_loss: 4556.6528 - val_vae_kl_loss: 131.2535
# Epoch 739/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 725.8628 - vae_r_loss: 594.5687 - vae_kl_loss: 131.2938- ETA: 2s - batch: 1548.0000 - size: 32.0000 - loss: 726.0646 - vae_r_loss: 594WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00739: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 375s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 725.8628 - vae_r_loss: 594.5687 - vae_kl_loss: 131.2938 - val_loss: 4726.6498 - val_vae_r_loss: 4595.3516 - val_vae_kl_loss: 131.2962
# Epoch 740/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 713.3876 - vae_r_loss: 582.7624 - vae_kl_loss: 130.6248WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00740: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 376s 120ms/step - batch: 1563.0000 - size: 32.0000 - loss: 713.3876 - vae_r_loss: 582.7624 - vae_kl_loss: 130.6248 - val_loss: 4688.4941 - val_vae_r_loss: 4557.8862 - val_vae_kl_loss: 130.6074
# Epoch 741/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 713.0410 - vae_r_loss: 582.5729 - vae_kl_loss: 130.4686WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00741: val_loss did not improve from 4581.93078
# 3127/3127 [==============================] - 379s 121ms/step - batch: 1563.0000 - size: 32.0000 - loss: 713.0410 - vae_r_loss: 582.5729 - vae_kl_loss: 130.4686 - val_loss: 4722.8020 - val_vae_r_loss: 4592.3022 - val_vae_kl_loss: 130.4985
# Epoch 742/100000
# 3127/3127 [==============================] - ETA: 0s - batch: 1563.0000 - size: 32.0000 - loss: 723.6757 - vae_r_loss: 592.6949 - vae_kl_loss: 130.9806WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def plot_latent_space(trained_decoder, pimage, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    image = np.array(image).astype("float32")/255.0
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.5])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_tstr = np.array([0.3])
    X_tvel = np.expand_dims(X_tstr, axis=0)
    X_ttime = np.array([0.1])
    X_tvel = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    X_train = [image, X_tstr, X_tvel, X_ttime]

    x_encoded = VarAE.predict(X_train)*255.0
    # print(x_encoded)
    x_encoded_out = np.squeeze(x_encoded,axis=0)
    # pred_image = np.zeros([160,160,3], np.uint8)
    pred_image = array_to_img(x_encoded_out)
    pred_image = np.array(pred_image)
    pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # pred_img = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # print(type(pred_img))
    # print(pred_image.shape)
    plt.imshow(pred_image)
    # plt.imshow(cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB))
    plt.show()

    origin_image_name = '/home2/kdh/vae/vae_test/2022-12-08-14-30-12-332957.jpg'
    cv2.imwrite('/')
    # plt.xticks(pixel_range, sample_range_x)
    # plt.yticks(pixel_range, sample_range_y)
    # plt.xlabel("z[0]")
    # plt.ylabel("z[1]")

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-30-12-332957.jpg')
# plot_latent_space(decoder, test_img)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space(trained_decoder, valid_data, n=50, figsize=15):
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in valid_data:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))

        cv2.imwrite('/home2/kdh/vae/vae_test/'+image_name, image)
        image = np.array(image).astype("float32")/255.0
        # image = image_process.process(image)
        steering_angle, throttle, brake = measurement
        
        image = np.expand_dims(image, axis=0)
        X_tvel = np.array([velocity])
        X_tvel = np.expand_dims(X_tvel, axis=0)
        X_tstr = np.array([steering_angle])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_ttime = np.array([tar_time])
        X_ttime = np.expand_dims(X_ttime, axis=0)
        
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image)
        # plt.imshow(pred_image)
        # plt.show()

        # image_name = '/home2/kdh/vae/vae_test/'+image_name
        pred_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'.jpg'
        gt_tar_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'_gt.jpg'
        cv2.imwrite(pred_image_name, pred_image)
        cv2.imwrite(gt_tar_image_name, tar_image)

        # print(pred_image_name,' done')
        # cv2.imwrite('/')


# save_latent_space(decoder, valid_data[3423:4422])

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space_diff_steer(trained_decoder, pimage, save_image_name, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    cv2.imwrite('/home2/kdh/vae/vae_diff_steer_test/'+save_image_name+'.jpg', image)
    image = np.array(image).astype("float32")/255.0
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.85])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_ttime = np.array([0.8])
    X_ttime = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    for s in np.arange(0, 0.8, 0.0125):
        X_tstr = np.array([s-0.4])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
        s_str = "{:.3f}".format(s)
        pred_image_name = ('/home2/kdh/vae/vae_diff_steer_test/'
                            +save_image_name
                            +'_'+str(s_str)
                            +'.jpg'
        )
        cv2.imwrite(pred_image_name, pred_image)
    
        

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-35-43-708754.jpg')
# save_latent_space_diff_steer(decoder, test_img, '2022-12-08-14-35-43-708754')
