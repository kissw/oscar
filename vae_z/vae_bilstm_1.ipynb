# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
# from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Activation, LeakyReLU, Dropout, BatchNormalization, MaxPooling2D, Lambda
from keras.models import Model
from sklearn.metrics import mean_squared_error as mse
from progressbar import ProgressBar
from image_process import ImageProcess
import const, cv2
from drive_data import DriveData
from config import Config

import matplotlib.pyplot as plt
import sys
config = Config.neural_net
sys.setrecursionlimit(10**7)
tf.compat.v1.experimental.output_all_intermediates(True)
tf.compat.v1.disable_eager_execution()
# Out:
# =======================================================
#                Configuration Settings
# =======================================================
# Neural Net:     	fusion_kdh_jaerock3
# Data Collection:	fusion_kdh_jaerock3
# Run Neural:     	fusion_kdh_jaerock3

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
gpu_config = tf.compat.v1.ConfigProto()
gpu_config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=gpu_config)
tf.compat.v1.keras.backend.set_session(sess)

# %%
"""
## Encoder
"""

"""
## Create a sampling layer
"""
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

encoder_inputs_img = tf.keras.Input(batch_shape=(32, 1, 160, 160, 3))
encoder_inputs_str = tf.keras.Input(batch_shape=(32, 1, 1))
encoder_inputs_vel = tf.keras.Input(batch_shape=(32, 1, 1))
encoder_inputs_time = tf.keras.Input(batch_shape=(32, 1, 1))
x = layers.TimeDistributed(layers.Conv2D(24, (5, 5), padding='same', name='conv2d_1'))(encoder_inputs_img)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1'))(x)
# x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_1'))(x)
x = layers.TimeDistributed(layers.Conv2D(36, (5, 5), padding='same', name='conv2d_2'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2, 2), name='pool2d_2'))(x)
x = layers.TimeDistributed(layers.Conv2D(48, (5, 5), padding='same', name='conv2d_3'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.Conv2D(64, (3, 3), padding='same', name='conv2d_4'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
x = layers.TimeDistributed(layers.Conv2D(64, (3, 3), padding='same', name='conv2d_5'))(x)
x = layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed(layers.Activation('elu'))(x)
latent = layers.TimeDistributed(layers.Flatten())(x)
latent = layers.TimeDistributed(layers.Dense(500))(latent)
latent = layers.TimeDistributed(layers.LayerNormalization())(latent)
latent = layers.TimeDistributed(layers.Activation('tanh'))(latent)
fc_s1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_str)
fc_s1  = layers.TimeDistributed(layers.Activation('elu'))(fc_s1)
fc_s2  = layers.TimeDistributed(layers.Dense(50))(fc_s1)
fc_s2  = layers.TimeDistributed(layers.Activation('elu'))(fc_s2)
fc_v1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_vel)
fc_v1  = layers.TimeDistributed(layers.Activation('elu'))(fc_v1)
fc_v2  = layers.TimeDistributed(layers.Dense(50))(fc_v1)
fc_v2  = layers.TimeDistributed(layers.Activation('elu'))(fc_v2)
fc_t1  = layers.TimeDistributed(layers.Dense(100))(encoder_inputs_time)
fc_t1  = layers.TimeDistributed(layers.Activation('elu'))(fc_t1)
fc_t2  = layers.TimeDistributed(layers.Dense(50))(fc_t1)
fc_t2  = layers.TimeDistributed(layers.Activation('elu'))(fc_t2)
conc_1 = layers.concatenate([latent, fc_s2, fc_v2, fc_t2])
bilstm = layers.Bidirectional(layers.LSTM(500, input_shape=(1000, 1), batch_size=32, stateful=True))(conc_1)
fc_1   = layers.Dense(500)(bilstm)
fc_1   = layers.Activation('elu')(fc_1)
fc_2   = layers.Dense(100)(fc_1)
x   = layers.Activation('elu')(fc_2)
z_mean = layers.Dense(50, name="z_mean")(x)
z_log_var = layers.Dense(50, name="z_log_var")(x)
encoder_output = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model([ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time], 
                        [z_mean, z_log_var, encoder_output], 
                        name="encoder")

"""
## Decoder
"""
latent_inputs = tf.keras.Input(shape=(50,))
x = layers.Dense(40 * 40 * 64, activation="elu")(latent_inputs)
x = layers.Reshape((40, 40, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="elu",  padding="same")(x)
x = layers.Conv2DTranspose(36, 3, activation="elu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(24, 3, activation="elu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = tf.keras.Model(latent_inputs, decoder_outputs, name="decoder")

"""
## VAE
"""
model_input = [ encoder_inputs_img, encoder_inputs_str,
                        encoder_inputs_vel, encoder_inputs_time]
model_output = decoder(encoder_output)

VarAE=Model(model_input, model_output)
VarAE.summary()
# Out:
# WARNING:tensorflow:From /home2/kdh/anaconda3/envs/vae/lib/python3.6/site-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(32, 1, 160, 160, 3 0
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (32, 1, 160, 160, 24 1824        input_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (32, 1, 160, 160, 24 96          time_distributed[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (32, 1, 160, 160, 24 0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (32, 1, 80, 80, 24)  0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (32, 1, 80, 80, 36)  21636       time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (32, 1, 80, 80, 36)  144         time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (32, 1, 80, 80, 36)  0           time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (32, 1, 40, 40, 36)  0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (32, 1, 40, 40, 48)  43248       time_distributed_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (32, 1, 40, 40, 48)  192         time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (32, 1, 40, 40, 48)  0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (32, 1, 40, 40, 64)  27712       time_distributed_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (32, 1, 40, 40, 64)  256         time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (32, 1, 40, 40, 64)  0           time_distributed_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (32, 1, 40, 40, 64)  36928       time_distributed_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (32, 1, 40, 40, 64)  256         time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (32, 1, 40, 40, 64)  0           time_distributed_15[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(32, 1, 1)]         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(32, 1, 1)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(32, 1, 1)]         0
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (32, 1, 102400)      0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (32, 1, 100)         200         input_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (32, 1, 100)         200         input_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (32, 1, 100)         200         input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (32, 1, 500)         51200500    time_distributed_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (32, 1, 100)         0           time_distributed_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (32, 1, 100)         0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (32, 1, 100)         0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (32, 1, 500)         1000        time_distributed_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (32, 1, 50)          5050        time_distributed_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (32, 1, 50)          5050        time_distributed_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (32, 1, 50)          5050        time_distributed_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (32, 1, 500)         0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (32, 1, 50)          0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (32, 1, 50)          0           time_distributed_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (32, 1, 50)          0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (32, 1, 650)         0           time_distributed_20[0][0]
#                                                                  time_distributed_24[0][0]
#                                                                  time_distributed_28[0][0]
#                                                                  time_distributed_32[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (32, 1000)           4604000     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (32, 500)            500500      bidirectional[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (32, 500)            0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (32, 100)            50100       activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (32, 100)            0           dense_8[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (32, 50)             5050        activation_13[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (32, 50)             5050        activation_13[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (32, 50)             0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 160, 160, 3)  5288551     sampling[0][0]
# ==================================================================================================
# Total params: 61,802,793
# Trainable params: 61,802,321
# Non-trainable params: 472
# __________________________________________________________________________________________________

# %%
"""
## Dataset
"""
image_process = ImageProcess()
config = Config.neural_net
# data_path = "/mnt/exData/internal_simulation/test/2022-03-08-17-18-14/"
data_path = "/home2/kdh/vae/2022-12-08-14-25-28/"
if data_path[-1] == '/':
    data_path = data_path[:-1]

    loc_slash = data_path.rfind('/')
    if loc_slash != -1: # there is '/' in the data path
        model_name = data_path[loc_slash + 1:] # get folder name
        #model_name = model_name.strip('/')
    else:
        model_name = data_path
csv_path = data_path + '/' + model_name + const.DATA_EXT 
# data = DriveData(csv_path)
print(csv_path)
# data_path = data_path
# data.read()

csv_header = ['image_fname', 
                  'steering_angle', 'throttle', 'brake', 'linux_time', 
                  'vel', 'vel_x', 'vel_y', 'vel_z', 
                  'pos_x', 'pos_y', 'pos_z', 
                  'tar_image_fname', 'tar_steering_angle', 'tar_vel', 'tar_time']

df = pd.read_csv(csv_path, names=csv_header, index_col=False)
num_data = len(df)

bar = ProgressBar()
df_image_names = []
df_measurements = []
df_time_stamps= []
df_velocities= []
df_velocities_xyz= []
df_positions_xyz= []
df_tar_image_names= []
df_tar_steering_angle= []
df_tar_vel= []
df_tar_time= []
for i in bar(range(num_data)): # we don't have a title
    df_image_names.append(df.loc[i]['image_fname'])
    # if Config.data_collection['brake'] is True:
    df_measurements.append((float(df.loc[i]['steering_angle']),
                            float(df.loc[i]['throttle']), 
                            float(df.loc[i]['brake'])))
    df_time_stamps.append(float(df.loc[i]['linux_time']))
    df_velocities.append(float(df.loc[i]['vel']))
    df_velocities_xyz.append((float(df.loc[i]['vel_x']), 
                                float(df.loc[i]['vel_y']), 
                                float(df.loc[i]['vel_z'])))
    df_positions_xyz.append((float(df.loc[i]['pos_x']), 
                                float(df.loc[i]['pos_y']), 
                                float(df.loc[i]['pos_z'])))
    df_tar_image_names.append(df.loc[i]['tar_image_fname'])
    df_tar_steering_angle.append(float(df.loc[i]['tar_steering_angle']))
    df_tar_vel.append(float(df.loc[i]['tar_vel']))
    df_tar_time.append(float(df.loc[i]['tar_time']))
# Out:
# /home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-25-28.csv
# 100% |########################################################################|

# %%
samples = list(zip( df_image_names, df_velocities, df_measurements, 
                    df_tar_image_names, df_tar_steering_angle, df_tar_vel, df_tar_time))

# %%
def prepare_vae_batch_samples(batch_samples):
    images = []
    steering_angles = []
    vels = []
    tar_images = []
    tar_steering_angles = []
    tar_vels = []
    tar_times = []


    batch_images = []
    batch_steering_angles = []
    batch_vels = []
    batch_tar_images = []
    batch_tar_steering_angles = []
    batch_tar_vels = []
    batch_tar_times = []
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in batch_samples:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        if Config.data_collection['crop'] is not True:
            image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
            tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                        Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        image = image_process.process(image)
        tar_image = image_process.process(tar_image)

        batch_vels.append(velocity)
        batch_tar_vels.append(tar_vel)
        batch_tar_times.append(tar_time)
        batch_tar_steering_angles.append(tar_steering_angle)
        # if no brake data in collected data, brake values are dummy
        steering_angle, throttle, brake = measurement
        batch_steering_angles.append(steering_angle)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/image/'+image_name, image)
        # cv2.imwrite('/home2/kdh/vae/oscar/test/tar_image/'+tar_image_name, tar_image)
        # if data == 'train':
        #     cv2.imwrite('/mnt/Data/oscar/train_data/'+image_name, image)
        # print(image.shape)
        batch_images.append(image)
        tar_images.append(tar_image)
        # segimgs.append(segimg)


    images.append(batch_images)
    steering_angles.append(batch_steering_angles)
    vels.append(batch_vels)
    # tar_images.append(batch_tar_images)
    tar_steering_angles.append(batch_tar_steering_angles)
    tar_vels.append(batch_tar_vels)
    tar_times.append(batch_tar_times)
    # print(np.array(tar_times).shape)
    return images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times

# %%
"""
Data generator
"""
from sklearn.model_selection import train_test_split

def _generator(samples, batch_size=config['batch_size']):
    num_samples = len(samples)
    while True: # Loop forever so the generator never terminates
        for offset in range(0, (num_samples//batch_size)*batch_size, batch_size):
            batch_samples = samples[offset:offset+batch_size]

            images, vels, steering_angles, tar_images, tar_steering_angles, tar_vels, tar_times = prepare_vae_batch_samples(batch_samples)

            X_img = np.array(images).astype("float32")/255.0
            X_tvel = np.array(tar_vels).astype("float32")
            X_tstr = np.array(tar_steering_angles).astype("float32")
            X_ttime = np.array(tar_times).astype("float32")

            X_img = X_img.swapaxes(0,1)
            
            X_tvel = X_tvel.swapaxes(0,1)
            X_tstr = X_tstr.swapaxes(0,1)
            X_ttime = X_ttime.swapaxes(0,1)
            X_tvel = X_tvel.reshape(-1, 1, 1)
            X_tstr = X_tstr.reshape(-1, 1, 1)
            X_ttime = X_ttime.reshape(-1, 1, 1)
            y_train = np.array(tar_images).astype("float32")/255.0
            # print(X_img.shape)
            # print(X_tvel.shape)
            # print(y_train.shape)
            # if config['num_outputs'] == 1:
            # y_train = np.array(segimg)
            # print(y_train.max())
            # y_train = np.repeat(y_train[..., np.newaxis], 1, -1)/y_train.max()
            X_train = [X_img, X_tstr, X_tvel, X_ttime]
            # print(X_tstr, X_tvel, X_ttime)
            # print(y_train)
            # print(y_train.shape)
            yield X_train, y_train

train_data, valid_data = train_test_split(samples, test_size=config['validation_rate'])

train_generator = _generator(train_data, config['batch_size'])
valid_generator = _generator(valid_data, config['batch_size'])

# %%
"""
VAE loss
"""
optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.0000001)
# optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, decay=0.00000001)
#                                  learning_rate=0.000005,decay=0.0000000001
r_loss_factor=160*160*100   # This is a Hyperparameter

def vae_r_loss(y_true, y_pred):    ## MSE
    r_loss = tf.keras.backend.mean(tf.keras.backend.square(y_true-y_pred), axis=[1,2,3])
    return r_loss_factor * r_loss

def vae_kl_loss(y_true, y_pred):   ## KL-Divergence
    kl_loss=( -0.5 * tf.keras.backend.sum(1+z_log_var 
                - tf.keras.backend.square(z_mean) 
                - tf.keras.backend.exp(z_log_var), axis=1)
    )
    return kl_loss

def vae_loss(y_true, y_pred): 
    r_loss=vae_r_loss(y_true, y_pred) #Loss of Decoder
    kl_loss = vae_kl_loss(y_true, y_pred) #Loss of Encoder
    return r_loss + kl_loss #Sum of these two


VarAE.compile(optimizer=optimizer,
                loss= vae_loss, 
                metrics=[vae_r_loss, vae_kl_loss])
# VarAE.summary()
#  vae_r_loss: 12.6586 - vae_kl_loss: 2251744.5000 
#  val_loss: 50649853.6174 
#  val_vae_r_loss: 28.6742 - val_vae_kl_loss: 50649896.0000

# %%
"""
## Train the VAE
"""
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.python.framework.ops import disable_eager_execution

        # checkpoint
callbacks = []
#weight_filename = self.data_path + '_' + Config.config_yaml_name \
#    + '_N' + str(config['network_type']) + '_ckpt'
model_ckpt_name = "vae_kdh"
checkpoint = ModelCheckpoint(model_ckpt_name +'_ckpt.{epoch:02d}-{val_loss:.3f}.h5',
                                monitor='val_loss', 
                                verbose=1, save_best_only=True, mode='min')
callbacks.append(checkpoint)

# early stopping
patience = 500
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, 
                            verbose=1, mode='min')
# callbacks.append(earlystop)

# validation_steps = len(valid_data)//config['batch_size']
# print(validation_steps)
train_hist = VarAE.fit( train_generator,  
                        steps_per_epoch=len(train_data)//config['batch_size'], 
                        epochs=100000, 
                        validation_data=valid_generator,
                        validation_steps=len(valid_data)//config['batch_size'],
                        # shuffle=True,
                        verbose=1, 
                        callbacks=callbacks, 
                        use_multiprocessing=True,
                        workers=48
                        )
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# Epoch 1/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 10179.8200 - vae_r_loss: 9972.3193 - vae_kl_loss: 207.4913WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00001: val_loss improved from inf to 18913.37566, saving model to vae_kdh_ckpt.01-18913.376.h5
# 3656/3656 [==============================] - 196s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 10179.8200 - vae_r_loss: 9972.3193 - vae_kl_loss: 207.4913 - val_loss: 18913.3757 - val_vae_r_loss: 18707.5859 - val_vae_kl_loss: 205.7823
# Epoch 2/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 8866.4577 - vae_r_loss: 8664.9189 - vae_kl_loss: 201.5386WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00002: val_loss did not improve from 18913.37566
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 8865.9648 - vae_r_loss: 8664.4297 - vae_kl_loss: 201.5349 - val_loss: 19019.8015 - val_vae_r_loss: 18831.4941 - val_vae_kl_loss: 188.3117
# Epoch 3/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 7554.0630 - vae_r_loss: 7358.9678 - vae_kl_loss: 195.1002WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00003: val_loss improved from 18913.37566 to 17217.72078, saving model to vae_kdh_ckpt.03-17217.721.h5
# 3656/3656 [==============================] - 196s 54ms/step - batch: 1827.5000 - size: 32.0000 - loss: 7553.8210 - vae_r_loss: 7358.7227 - vae_kl_loss: 195.1035 - val_loss: 17217.7208 - val_vae_r_loss: 17027.3516 - val_vae_kl_loss: 190.3708
# Epoch 4/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 6345.3867 - vae_r_loss: 6150.7759 - vae_kl_loss: 194.6060WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00004: val_loss did not improve from 17217.72078
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 6345.3867 - vae_r_loss: 6150.7759 - vae_kl_loss: 194.6060 - val_loss: 18665.6313 - val_vae_r_loss: 18477.0742 - val_vae_kl_loss: 188.5693
# Epoch 5/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 5948.1302 - vae_r_loss: 5753.5005 - vae_kl_loss: 194.6364WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00005: val_loss did not improve from 17217.72078
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 5948.3209 - vae_r_loss: 5753.6938 - vae_kl_loss: 194.6338 - val_loss: 17426.4996 - val_vae_r_loss: 17237.0723 - val_vae_kl_loss: 189.4127
# Epoch 6/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 5557.7508 - vae_r_loss: 5365.7900 - vae_kl_loss: 191.9621WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00006: val_loss improved from 17217.72078 to 17068.79973, saving model to vae_kdh_ckpt.06-17068.800.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 5557.7508 - vae_r_loss: 5365.7900 - vae_kl_loss: 191.9621 - val_loss: 17068.7997 - val_vae_r_loss: 16881.0176 - val_vae_kl_loss: 187.7758
# Epoch 7/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 5273.8782 - vae_r_loss: 5083.1626 - vae_kl_loss: 190.7221WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00007: val_loss improved from 17068.79973 to 16724.17263, saving model to vae_kdh_ckpt.07-16724.173.h5
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 5273.5211 - vae_r_loss: 5082.8076 - vae_kl_loss: 190.7202 - val_loss: 16724.1726 - val_vae_r_loss: 16539.5020 - val_vae_kl_loss: 184.6489
# Epoch 8/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 5117.4251 - vae_r_loss: 4926.9116 - vae_kl_loss: 190.5139WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00008: val_loss improved from 16724.17263 to 16142.09774, saving model to vae_kdh_ckpt.08-16142.098.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 5117.1486 - vae_r_loss: 4926.6333 - vae_kl_loss: 190.5156 - val_loss: 16142.0977 - val_vae_r_loss: 15955.2852 - val_vae_kl_loss: 186.8111
# Epoch 9/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 4886.1605 - vae_r_loss: 4693.4326 - vae_kl_loss: 192.7276WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00009: val_loss did not improve from 16142.09774
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 4886.4166 - vae_r_loss: 4693.6895 - vae_kl_loss: 192.7267 - val_loss: 16373.8473 - val_vae_r_loss: 16186.4570 - val_vae_kl_loss: 187.3781
# Epoch 10/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 4508.4089 - vae_r_loss: 4315.3530 - vae_kl_loss: 193.0550WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00010: val_loss improved from 16142.09774 to 15400.61792, saving model to vae_kdh_ckpt.10-15400.618.h5
# 3656/3656 [==============================] - 192s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 4508.3757 - vae_r_loss: 4315.3203 - vae_kl_loss: 193.0545 - val_loss: 15400.6179 - val_vae_r_loss: 15211.7578 - val_vae_kl_loss: 188.8498
# Epoch 11/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 4156.0543 - vae_r_loss: 3962.7891 - vae_kl_loss: 193.2674WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00011: val_loss improved from 15400.61792 to 15171.17791, saving model to vae_kdh_ckpt.11-15171.178.h5
# 3656/3656 [==============================] - 191s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 4155.6489 - vae_r_loss: 3962.3816 - vae_kl_loss: 193.2695 - val_loss: 15171.1779 - val_vae_r_loss: 14977.8545 - val_vae_kl_loss: 193.3203
# Epoch 12/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 3845.9553 - vae_r_loss: 3651.6360 - vae_kl_loss: 194.3136WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00012: val_loss improved from 15171.17791 to 14359.54859, saving model to vae_kdh_ckpt.12-14359.549.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3845.9553 - vae_r_loss: 3651.6360 - vae_kl_loss: 194.3136 - val_loss: 14359.5486 - val_vae_r_loss: 14166.9199 - val_vae_kl_loss: 192.6266
# Epoch 13/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 3829.2017 - vae_r_loss: 3634.6641 - vae_kl_loss: 194.5415WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00013: val_loss improved from 14359.54859 to 13548.86859, saving model to vae_kdh_ckpt.13-13548.869.h5
# 3656/3656 [==============================] - 191s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3829.2017 - vae_r_loss: 3634.6641 - vae_kl_loss: 194.5415 - val_loss: 13548.8686 - val_vae_r_loss: 13355.7637 - val_vae_kl_loss: 193.1004
# Epoch 14/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 3621.7121 - vae_r_loss: 3425.5049 - vae_kl_loss: 196.2089WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00014: val_loss improved from 13548.86859 to 12960.53704, saving model to vae_kdh_ckpt.14-12960.537.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3621.6612 - vae_r_loss: 3425.4551 - vae_kl_loss: 196.2075 - val_loss: 12960.5370 - val_vae_r_loss: 12768.7305 - val_vae_kl_loss: 191.8025
# Epoch 15/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 3606.0271 - vae_r_loss: 3410.6294 - vae_kl_loss: 195.4005WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00015: val_loss improved from 12960.53704 to 12460.18525, saving model to vae_kdh_ckpt.15-12460.185.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3605.5844 - vae_r_loss: 3410.1877 - vae_kl_loss: 195.3993 - val_loss: 12460.1852 - val_vae_r_loss: 12267.7969 - val_vae_kl_loss: 192.3894
# Epoch 16/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 3482.9486 - vae_r_loss: 3286.1677 - vae_kl_loss: 196.7776WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00016: val_loss improved from 12460.18525 to 12016.10507, saving model to vae_kdh_ckpt.16-12016.105.h5
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3482.9486 - vae_r_loss: 3286.1677 - vae_kl_loss: 196.7776 - val_loss: 12016.1051 - val_vae_r_loss: 11823.6299 - val_vae_kl_loss: 192.4836
# Epoch 17/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 3202.1100 - vae_r_loss: 3006.3018 - vae_kl_loss: 195.8092WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00017: val_loss improved from 12016.10507 to 11415.62544, saving model to vae_kdh_ckpt.17-11415.625.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3202.4215 - vae_r_loss: 3006.6113 - vae_kl_loss: 195.8112 - val_loss: 11415.6254 - val_vae_r_loss: 11223.9346 - val_vae_kl_loss: 191.6793
# Epoch 18/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 3067.0312 - vae_r_loss: 2871.9788 - vae_kl_loss: 195.0567WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00018: val_loss improved from 11415.62544 to 10930.49730, saving model to vae_kdh_ckpt.18-10930.497.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3067.0004 - vae_r_loss: 2871.9478 - vae_kl_loss: 195.0567 - val_loss: 10930.4973 - val_vae_r_loss: 10738.3457 - val_vae_kl_loss: 192.1548
# Epoch 19/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 3112.8912 - vae_r_loss: 2917.2114 - vae_kl_loss: 195.6805WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00019: val_loss improved from 10930.49730 to 10693.73985, saving model to vae_kdh_ckpt.19-10693.740.h5
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 3112.8912 - vae_r_loss: 2917.2114 - vae_kl_loss: 195.6805 - val_loss: 10693.7399 - val_vae_r_loss: 10498.7578 - val_vae_kl_loss: 194.9786
# Epoch 20/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2962.9888 - vae_r_loss: 2767.1870 - vae_kl_loss: 195.8028WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00020: val_loss improved from 10693.73985 to 10623.32806, saving model to vae_kdh_ckpt.20-10623.328.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2962.9888 - vae_r_loss: 2767.1870 - vae_kl_loss: 195.8028 - val_loss: 10623.3281 - val_vae_r_loss: 10428.8291 - val_vae_kl_loss: 194.4984
# Epoch 21/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 2890.0613 - vae_r_loss: 2693.1118 - vae_kl_loss: 196.9460WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00021: val_loss improved from 10623.32806 to 9916.79932, saving model to vae_kdh_ckpt.21-9916.799.h5
# 3656/3656 [==============================] - 196s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2889.8688 - vae_r_loss: 2692.9177 - vae_kl_loss: 196.9478 - val_loss: 9916.7993 - val_vae_r_loss: 9722.4736 - val_vae_kl_loss: 194.3193
# Epoch 22/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2851.5686 - vae_r_loss: 2655.4802 - vae_kl_loss: 196.0922WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00022: val_loss did not improve from 9916.79932
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2851.5686 - vae_r_loss: 2655.4802 - vae_kl_loss: 196.0922 - val_loss: 10000.9675 - val_vae_r_loss: 9809.7021 - val_vae_kl_loss: 191.2630
# Epoch 23/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 2829.6016 - vae_r_loss: 2633.1992 - vae_kl_loss: 196.4046WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00023: val_loss did not improve from 9916.79932
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2829.9901 - vae_r_loss: 2633.5872 - vae_kl_loss: 196.4050 - val_loss: 9979.4253 - val_vae_r_loss: 9784.1670 - val_vae_kl_loss: 195.2642
# Epoch 24/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2674.1416 - vae_r_loss: 2478.6292 - vae_kl_loss: 195.5096WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00024: val_loss improved from 9916.79932 to 9636.72775, saving model to vae_kdh_ckpt.24-9636.728.h5
# 3656/3656 [==============================] - 197s 54ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2674.1416 - vae_r_loss: 2478.6292 - vae_kl_loss: 195.5096 - val_loss: 9636.7278 - val_vae_r_loss: 9444.2773 - val_vae_kl_loss: 192.4551
# Epoch 25/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2640.9945 - vae_r_loss: 2445.1445 - vae_kl_loss: 195.8528WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00025: val_loss improved from 9636.72775 to 9191.50200, saving model to vae_kdh_ckpt.25-9191.502.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2640.9945 - vae_r_loss: 2445.1445 - vae_kl_loss: 195.8528 - val_loss: 9191.5020 - val_vae_r_loss: 8997.6562 - val_vae_kl_loss: 193.8482
# Epoch 26/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2542.6961 - vae_r_loss: 2346.3142 - vae_kl_loss: 196.3821WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00026: val_loss improved from 9191.50200 to 9174.83776, saving model to vae_kdh_ckpt.26-9174.838.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2542.6961 - vae_r_loss: 2346.3142 - vae_kl_loss: 196.3821 - val_loss: 9174.8378 - val_vae_r_loss: 8981.1367 - val_vae_kl_loss: 193.7038
# Epoch 27/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2537.7598 - vae_r_loss: 2340.2781 - vae_kl_loss: 197.4820WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00027: val_loss improved from 9174.83776 to 8999.65120, saving model to vae_kdh_ckpt.27-8999.651.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2537.7598 - vae_r_loss: 2340.2781 - vae_kl_loss: 197.4820 - val_loss: 8999.6512 - val_vae_r_loss: 8804.7285 - val_vae_kl_loss: 194.9226
# Epoch 28/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2490.9472 - vae_r_loss: 2294.2805 - vae_kl_loss: 196.6658WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00028: val_loss improved from 8999.65120 to 8712.66336, saving model to vae_kdh_ckpt.28-8712.663.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2490.9472 - vae_r_loss: 2294.2805 - vae_kl_loss: 196.6658 - val_loss: 8712.6634 - val_vae_r_loss: 8515.6260 - val_vae_kl_loss: 197.0291
# Epoch 29/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2434.0751 - vae_r_loss: 2238.2056 - vae_kl_loss: 195.8689WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00029: val_loss improved from 8712.66336 to 8319.65973, saving model to vae_kdh_ckpt.29-8319.660.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2434.0751 - vae_r_loss: 2238.2056 - vae_kl_loss: 195.8689 - val_loss: 8319.6597 - val_vae_r_loss: 8123.5308 - val_vae_kl_loss: 196.1220
# Epoch 30/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2511.7982 - vae_r_loss: 2315.8054 - vae_kl_loss: 195.9903WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00030: val_loss improved from 8319.65973 to 8311.99906, saving model to vae_kdh_ckpt.30-8311.999.h5
# 3656/3656 [==============================] - 191s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2511.7982 - vae_r_loss: 2315.8054 - vae_kl_loss: 195.9903 - val_loss: 8311.9991 - val_vae_r_loss: 8117.5303 - val_vae_kl_loss: 194.4726
# Epoch 31/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2332.9703 - vae_r_loss: 2136.6663 - vae_kl_loss: 196.2990WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00031: val_loss improved from 8311.99906 to 8052.71223, saving model to vae_kdh_ckpt.31-8052.712.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2332.9703 - vae_r_loss: 2136.6663 - vae_kl_loss: 196.2990 - val_loss: 8052.7122 - val_vae_r_loss: 7857.6484 - val_vae_kl_loss: 195.0603
# Epoch 32/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 2309.1021 - vae_r_loss: 2112.6731 - vae_kl_loss: 196.4304WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00032: val_loss did not improve from 8052.71223
# 3656/3656 [==============================] - 192s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2308.8759 - vae_r_loss: 2112.4475 - vae_kl_loss: 196.4299 - val_loss: 8095.7504 - val_vae_r_loss: 7900.2124 - val_vae_kl_loss: 195.5404
# Epoch 33/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2316.3624 - vae_r_loss: 2119.6467 - vae_kl_loss: 196.7126WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00033: val_loss improved from 8052.71223 to 7696.85949, saving model to vae_kdh_ckpt.33-7696.859.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2316.3624 - vae_r_loss: 2119.6467 - vae_kl_loss: 196.7126 - val_loss: 7696.8595 - val_vae_r_loss: 7501.8105 - val_vae_kl_loss: 195.0478
# Epoch 34/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 2224.8389 - vae_r_loss: 2029.4767 - vae_kl_loss: 195.3617WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00034: val_loss improved from 7696.85949 to 7667.98278, saving model to vae_kdh_ckpt.34-7667.983.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2224.6756 - vae_r_loss: 2029.3148 - vae_kl_loss: 195.3604 - val_loss: 7667.9828 - val_vae_r_loss: 7474.2974 - val_vae_kl_loss: 193.6806
# Epoch 35/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2166.6014 - vae_r_loss: 1971.5265 - vae_kl_loss: 195.0744WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00035: val_loss improved from 7667.98278 to 7535.94173, saving model to vae_kdh_ckpt.35-7535.942.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2166.6014 - vae_r_loss: 1971.5265 - vae_kl_loss: 195.0744 - val_loss: 7535.9417 - val_vae_r_loss: 7341.5449 - val_vae_kl_loss: 194.3896
# Epoch 36/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2170.8931 - vae_r_loss: 1975.6954 - vae_kl_loss: 195.1940WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00036: val_loss improved from 7535.94173 to 7335.26571, saving model to vae_kdh_ckpt.36-7335.266.h5
# 3656/3656 [==============================] - 196s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2170.8931 - vae_r_loss: 1975.6954 - vae_kl_loss: 195.1940 - val_loss: 7335.2657 - val_vae_r_loss: 7141.7832 - val_vae_kl_loss: 193.4885
# Epoch 37/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2181.6852 - vae_r_loss: 1986.0443 - vae_kl_loss: 195.6434WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00037: val_loss improved from 7335.26571 to 7148.21709, saving model to vae_kdh_ckpt.37-7148.217.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2181.6852 - vae_r_loss: 1986.0443 - vae_kl_loss: 195.6434 - val_loss: 7148.2171 - val_vae_r_loss: 6954.8340 - val_vae_kl_loss: 193.3906
# Epoch 38/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 2126.6091 - vae_r_loss: 1930.9233 - vae_kl_loss: 195.6861WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00038: val_loss improved from 7148.21709 to 7071.84080, saving model to vae_kdh_ckpt.38-7071.841.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2126.4591 - vae_r_loss: 1930.7742 - vae_kl_loss: 195.6853 - val_loss: 7071.8408 - val_vae_r_loss: 6879.1646 - val_vae_kl_loss: 192.6741
# Epoch 39/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 2023.6377 - vae_r_loss: 1829.4259 - vae_kl_loss: 194.2151WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00039: val_loss improved from 7071.84080 to 6963.52129, saving model to vae_kdh_ckpt.39-6963.521.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2023.7048 - vae_r_loss: 1829.4928 - vae_kl_loss: 194.2154 - val_loss: 6963.5213 - val_vae_r_loss: 6768.8857 - val_vae_kl_loss: 194.6333
# Epoch 40/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2071.0643 - vae_r_loss: 1874.8992 - vae_kl_loss: 196.1652WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00040: val_loss improved from 6963.52129 to 6853.67659, saving model to vae_kdh_ckpt.40-6853.677.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2071.0643 - vae_r_loss: 1874.8992 - vae_kl_loss: 196.1652 - val_loss: 6853.6766 - val_vae_r_loss: 6661.4556 - val_vae_kl_loss: 192.2204
# Epoch 41/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1962.2600 - vae_r_loss: 1768.3521 - vae_kl_loss: 193.9065WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00041: val_loss improved from 6853.67659 to 6816.16708, saving model to vae_kdh_ckpt.41-6816.167.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1962.2600 - vae_r_loss: 1768.3521 - vae_kl_loss: 193.9065 - val_loss: 6816.1671 - val_vae_r_loss: 6622.2729 - val_vae_kl_loss: 193.8925
# Epoch 42/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 2002.9199 - vae_r_loss: 1808.4802 - vae_kl_loss: 194.4397WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00042: val_loss improved from 6816.16708 to 6788.73259, saving model to vae_kdh_ckpt.42-6788.733.h5
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 2002.9199 - vae_r_loss: 1808.4802 - vae_kl_loss: 194.4397 - val_loss: 6788.7326 - val_vae_r_loss: 6595.0225 - val_vae_kl_loss: 193.7088
# Epoch 43/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1952.6975 - vae_r_loss: 1757.9454 - vae_kl_loss: 194.7528WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00043: val_loss improved from 6788.73259 to 6533.34626, saving model to vae_kdh_ckpt.43-6533.346.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1952.6505 - vae_r_loss: 1757.8988 - vae_kl_loss: 194.7524 - val_loss: 6533.3463 - val_vae_r_loss: 6340.1680 - val_vae_kl_loss: 193.1772
# Epoch 44/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1918.2793 - vae_r_loss: 1724.0151 - vae_kl_loss: 194.2648- ETA: 0s - batch: 1823.5000 - size: 32.0000 - loss: 1917.5841 - vae_r_loss: 1723.3180 - vae_kl_loss: 194.WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00044: val_loss improved from 6533.34626 to 6449.18627, saving model to vae_kdh_ckpt.44-6449.186.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1918.2793 - vae_r_loss: 1724.0151 - vae_kl_loss: 194.2648 - val_loss: 6449.1863 - val_vae_r_loss: 6257.4443 - val_vae_kl_loss: 191.7408
# Epoch 45/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1951.8470 - vae_r_loss: 1756.6599 - vae_kl_loss: 195.1879WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00045: val_loss improved from 6449.18627 to 6083.30358, saving model to vae_kdh_ckpt.45-6083.304.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1951.8336 - vae_r_loss: 1756.6453 - vae_kl_loss: 195.1892 - val_loss: 6083.3036 - val_vae_r_loss: 5890.5112 - val_vae_kl_loss: 192.7873
# Epoch 46/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1888.0875 - vae_r_loss: 1694.1765 - vae_kl_loss: 193.9075WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00046: val_loss did not improve from 6083.30358
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1888.0875 - vae_r_loss: 1694.1765 - vae_kl_loss: 193.9075 - val_loss: 6156.2995 - val_vae_r_loss: 5964.2744 - val_vae_kl_loss: 192.0252
# Epoch 47/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1870.0662 - vae_r_loss: 1676.4171 - vae_kl_loss: 193.6477WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00047: val_loss improved from 6083.30358 to 5905.17014, saving model to vae_kdh_ckpt.47-5905.170.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1869.8814 - vae_r_loss: 1676.2321 - vae_kl_loss: 193.6478 - val_loss: 5905.1701 - val_vae_r_loss: 5712.4727 - val_vae_kl_loss: 192.6962
# Epoch 48/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1825.2920 - vae_r_loss: 1631.5791 - vae_kl_loss: 193.7132WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00048: val_loss did not improve from 5905.17014
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1825.2920 - vae_r_loss: 1631.5791 - vae_kl_loss: 193.7132 - val_loss: 6029.4242 - val_vae_r_loss: 5835.4346 - val_vae_kl_loss: 193.9897
# Epoch 49/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1816.4149 - vae_r_loss: 1622.5707 - vae_kl_loss: 193.8431WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00049: val_loss did not improve from 5905.17014
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1816.4149 - vae_r_loss: 1622.5707 - vae_kl_loss: 193.8431 - val_loss: 6063.7317 - val_vae_r_loss: 5870.6689 - val_vae_kl_loss: 193.0650
# Epoch 50/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1876.2168 - vae_r_loss: 1681.6503 - vae_kl_loss: 194.5706WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00050: val_loss did not improve from 5905.17014
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1876.2168 - vae_r_loss: 1681.6503 - vae_kl_loss: 194.5706 - val_loss: 5965.7415 - val_vae_r_loss: 5772.7319 - val_vae_kl_loss: 193.0114
# Epoch 51/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1819.9792 - vae_r_loss: 1625.8040 - vae_kl_loss: 194.1764WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00051: val_loss improved from 5905.17014 to 5777.64533, saving model to vae_kdh_ckpt.51-5777.645.h5
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1820.4775 - vae_r_loss: 1626.3046 - vae_kl_loss: 194.1742 - val_loss: 5777.6453 - val_vae_r_loss: 5585.7222 - val_vae_kl_loss: 191.9229
# Epoch 52/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1750.3260 - vae_r_loss: 1557.6565 - vae_kl_loss: 192.6684WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00052: val_loss did not improve from 5777.64533
# 3656/3656 [==============================] - 189s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1750.2619 - vae_r_loss: 1557.5925 - vae_kl_loss: 192.6683 - val_loss: 5857.4674 - val_vae_r_loss: 5664.4219 - val_vae_kl_loss: 193.0498
# Epoch 53/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1791.6803 - vae_r_loss: 1597.2349 - vae_kl_loss: 194.4436WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00053: val_loss improved from 5777.64533 to 5737.64846, saving model to vae_kdh_ckpt.53-5737.648.h5
# 3656/3656 [==============================] - 192s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1791.6803 - vae_r_loss: 1597.2349 - vae_kl_loss: 194.4436 - val_loss: 5737.6485 - val_vae_r_loss: 5545.9351 - val_vae_kl_loss: 191.7181
# Epoch 54/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1705.5929 - vae_r_loss: 1512.2257 - vae_kl_loss: 193.3688WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00054: val_loss did not improve from 5737.64846
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1705.5929 - vae_r_loss: 1512.2257 - vae_kl_loss: 193.3688 - val_loss: 5804.8714 - val_vae_r_loss: 5612.8779 - val_vae_kl_loss: 191.9934
# Epoch 55/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1730.3894 - vae_r_loss: 1537.5641 - vae_kl_loss: 192.8263WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00055: val_loss did not improve from 5737.64846
# 3656/3656 [==============================] - 192s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1730.3894 - vae_r_loss: 1537.5641 - vae_kl_loss: 192.8263 - val_loss: 5750.1780 - val_vae_r_loss: 5560.0420 - val_vae_kl_loss: 190.1388
# Epoch 56/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1723.6145 - vae_r_loss: 1530.5354 - vae_kl_loss: 193.0805WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00056: val_loss improved from 5737.64846 to 5543.84204, saving model to vae_kdh_ckpt.56-5543.842.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1723.4854 - vae_r_loss: 1530.4049 - vae_kl_loss: 193.0819 - val_loss: 5543.8420 - val_vae_r_loss: 5353.0962 - val_vae_kl_loss: 190.7505
# Epoch 57/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1701.7487 - vae_r_loss: 1508.7098 - vae_kl_loss: 193.0390WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00057: val_loss improved from 5543.84204 to 5525.52747, saving model to vae_kdh_ckpt.57-5525.527.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1701.7487 - vae_r_loss: 1508.7098 - vae_kl_loss: 193.0390 - val_loss: 5525.5275 - val_vae_r_loss: 5333.7793 - val_vae_kl_loss: 191.7473
# Epoch 58/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1670.8030 - vae_r_loss: 1478.2675 - vae_kl_loss: 192.5357WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00058: val_loss improved from 5525.52747 to 5498.23018, saving model to vae_kdh_ckpt.58-5498.230.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1670.6847 - vae_r_loss: 1478.1498 - vae_kl_loss: 192.5351 - val_loss: 5498.2302 - val_vae_r_loss: 5307.4663 - val_vae_kl_loss: 190.7652
# Epoch 59/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1622.7532 - vae_r_loss: 1430.5973 - vae_kl_loss: 192.1556WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00059: val_loss improved from 5498.23018 to 5365.93626, saving model to vae_kdh_ckpt.59-5365.936.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1622.6454 - vae_r_loss: 1430.4919 - vae_kl_loss: 192.1531 - val_loss: 5365.9363 - val_vae_r_loss: 5175.2266 - val_vae_kl_loss: 190.7107
# Epoch 60/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1561.9933 - vae_r_loss: 1370.5068 - vae_kl_loss: 191.4869WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00060: val_loss improved from 5365.93626 to 5330.92089, saving model to vae_kdh_ckpt.60-5330.921.h5
# 3656/3656 [==============================] - 190s 52ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1561.9933 - vae_r_loss: 1370.5068 - vae_kl_loss: 191.4869 - val_loss: 5330.9209 - val_vae_r_loss: 5139.2388 - val_vae_kl_loss: 191.6868
# Epoch 61/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1632.1027 - vae_r_loss: 1440.3188 - vae_kl_loss: 191.7851WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00061: val_loss did not improve from 5330.92089
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1632.0730 - vae_r_loss: 1440.2897 - vae_kl_loss: 191.7846 - val_loss: 5333.6562 - val_vae_r_loss: 5142.6460 - val_vae_kl_loss: 191.0077
# Epoch 62/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1584.6198 - vae_r_loss: 1392.6976 - vae_kl_loss: 191.9227WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00062: val_loss improved from 5330.92089 to 5180.66521, saving model to vae_kdh_ckpt.62-5180.665.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1584.5104 - vae_r_loss: 1392.5883 - vae_kl_loss: 191.9227 - val_loss: 5180.6652 - val_vae_r_loss: 4990.7417 - val_vae_kl_loss: 189.9271
# Epoch 63/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1608.5445 - vae_r_loss: 1416.3794 - vae_kl_loss: 192.1645- ETA: 7s - bWARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00063: val_loss did not improve from 5180.66521
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1608.5445 - vae_r_loss: 1416.3794 - vae_kl_loss: 192.1645 - val_loss: 5352.7134 - val_vae_r_loss: 5163.4316 - val_vae_kl_loss: 189.2784
# Epoch 64/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1636.5965 - vae_r_loss: 1444.2084 - vae_kl_loss: 192.3898WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00064: val_loss did not improve from 5180.66521
# 3656/3656 [==============================] - 192s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1636.6999 - vae_r_loss: 1444.3105 - vae_kl_loss: 192.3910 - val_loss: 5230.0525 - val_vae_r_loss: 5039.6978 - val_vae_kl_loss: 190.3546
# Epoch 65/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1547.1991 - vae_r_loss: 1356.2548 - vae_kl_loss: 190.9454WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00065: val_loss improved from 5180.66521 to 5126.50337, saving model to vae_kdh_ckpt.65-5126.503.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1547.0992 - vae_r_loss: 1356.1542 - vae_kl_loss: 190.9460 - val_loss: 5126.5034 - val_vae_r_loss: 4937.0645 - val_vae_kl_loss: 189.4339
# Epoch 66/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1527.2645 - vae_r_loss: 1336.9532 - vae_kl_loss: 190.3124WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00066: val_loss improved from 5126.50337 to 5079.33983, saving model to vae_kdh_ckpt.66-5079.340.h5
# 3656/3656 [==============================] - 194s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1527.1822 - vae_r_loss: 1336.8687 - vae_kl_loss: 190.3146 - val_loss: 5079.3398 - val_vae_r_loss: 4890.2759 - val_vae_kl_loss: 189.0589
# Epoch 67/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1569.1631 - vae_r_loss: 1378.4359 - vae_kl_loss: 190.7265WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00067: val_loss improved from 5079.33983 to 4937.40689, saving model to vae_kdh_ckpt.67-4937.407.h5
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1569.1631 - vae_r_loss: 1378.4359 - vae_kl_loss: 190.7265 - val_loss: 4937.4069 - val_vae_r_loss: 4748.4082 - val_vae_kl_loss: 188.9968
# Epoch 68/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1533.7019 - vae_r_loss: 1343.1720 - vae_kl_loss: 190.5305WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00068: val_loss did not improve from 4937.40689
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1534.0029 - vae_r_loss: 1343.4725 - vae_kl_loss: 190.5309 - val_loss: 5024.0550 - val_vae_r_loss: 4835.9028 - val_vae_kl_loss: 188.1522
# Epoch 69/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 1519.6959 - vae_r_loss: 1328.3917 - vae_kl_loss: 191.3037WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00069: val_loss improved from 4937.40689 to 4761.29716, saving model to vae_kdh_ckpt.69-4761.297.h5
# 3656/3656 [==============================] - 195s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1519.6959 - vae_r_loss: 1328.3917 - vae_kl_loss: 191.3037 - val_loss: 4761.2972 - val_vae_r_loss: 4572.8252 - val_vae_kl_loss: 188.4680
# Epoch 70/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1503.0109 - vae_r_loss: 1312.3367 - vae_kl_loss: 190.6721WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00070: val_loss did not improve from 4761.29716
# 3656/3656 [==============================] - 193s 53ms/step - batch: 1827.5000 - size: 32.0000 - loss: 1502.9029 - vae_r_loss: 1312.2295 - vae_kl_loss: 190.6712 - val_loss: 4885.8981 - val_vae_r_loss: 4696.9863 - val_vae_kl_loss: 188.9136
# Epoch 71/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 1524.5870 - vae_r_loss: 1333.6770 - vae_kl_loss: 190.9097WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 00071: val_loss did not improve from 4761.29716
# ...
# Epoch 4330/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 494.6221 - vae_r_loss: 350.1668 - vae_kl_loss: 144.4549WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04330: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.6221 - vae_r_loss: 350.1668 - vae_kl_loss: 144.4549 - val_loss: 2018.9458 - val_vae_r_loss: 1876.0223 - val_vae_kl_loss: 142.9243
# Epoch 4331/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.3775 - vae_r_loss: 350.8773 - vae_kl_loss: 144.4999WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04331: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 199s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.3793 - vae_r_loss: 350.8806 - vae_kl_loss: 144.4984 - val_loss: 2017.9356 - val_vae_r_loss: 1874.7712 - val_vae_kl_loss: 143.1644
# Epoch 4332/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 496.3467 - vae_r_loss: 351.9585 - vae_kl_loss: 144.3884WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04332: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 201s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 496.3573 - vae_r_loss: 351.9662 - vae_kl_loss: 144.3913 - val_loss: 2019.6008 - val_vae_r_loss: 1876.3741 - val_vae_kl_loss: 143.2262
# Epoch 4333/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 496.4580 - vae_r_loss: 351.9502 - vae_kl_loss: 144.5074WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04333: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 203s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 496.4580 - vae_r_loss: 351.9502 - vae_kl_loss: 144.5074 - val_loss: 2006.1569 - val_vae_r_loss: 1862.8673 - val_vae_kl_loss: 143.2880
# Epoch 4334/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.2087 - vae_r_loss: 351.3704 - vae_kl_loss: 143.8380WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04334: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 201s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.2053 - vae_r_loss: 351.3665 - vae_kl_loss: 143.8385 - val_loss: 2014.5090 - val_vae_r_loss: 1871.3157 - val_vae_kl_loss: 143.1929
# Epoch 4335/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 494.7697 - vae_r_loss: 351.0397 - vae_kl_loss: 143.7299WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04335: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 201s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.7697 - vae_r_loss: 351.0397 - vae_kl_loss: 143.7299 - val_loss: 2007.9709 - val_vae_r_loss: 1864.7614 - val_vae_kl_loss: 143.2092
# Epoch 4336/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 495.5905 - vae_r_loss: 351.6534 - vae_kl_loss: 143.9375WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04336: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 201s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.5905 - vae_r_loss: 351.6534 - vae_kl_loss: 143.9375 - val_loss: 2010.3942 - val_vae_r_loss: 1867.3229 - val_vae_kl_loss: 143.0708
# Epoch 4337/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 495.2933 - vae_r_loss: 351.1801 - vae_kl_loss: 144.1135WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04337: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.2933 - vae_r_loss: 351.1801 - vae_kl_loss: 144.1135 - val_loss: 2013.4279 - val_vae_r_loss: 1870.1322 - val_vae_kl_loss: 143.2949
# Epoch 4338/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.3812 - vae_r_loss: 351.2598 - vae_kl_loss: 144.1215WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04338: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.3890 - vae_r_loss: 351.2655 - vae_kl_loss: 144.1236 - val_loss: 2016.4733 - val_vae_r_loss: 1873.4108 - val_vae_kl_loss: 143.0645
# Epoch 4339/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.5397 - vae_r_loss: 350.8989 - vae_kl_loss: 144.6407WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04339: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.5393 - vae_r_loss: 350.8968 - vae_kl_loss: 144.6425 - val_loss: 2025.1203 - val_vae_r_loss: 1881.8323 - val_vae_kl_loss: 143.2887
# Epoch 4340/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 494.0945 - vae_r_loss: 349.5914 - vae_kl_loss: 144.5032WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04340: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.0945 - vae_r_loss: 349.5914 - vae_kl_loss: 144.5032 - val_loss: 2020.6010 - val_vae_r_loss: 1877.3505 - val_vae_kl_loss: 143.2509
# Epoch 4341/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 494.0834 - vae_r_loss: 349.7832 - vae_kl_loss: 144.3002WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04341: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.0834 - vae_r_loss: 349.7832 - vae_kl_loss: 144.3002 - val_loss: 2019.3109 - val_vae_r_loss: 1875.9060 - val_vae_kl_loss: 143.4041
# Epoch 4342/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 493.1988 - vae_r_loss: 348.9287 - vae_kl_loss: 144.2698WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04342: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 493.1988 - vae_r_loss: 348.9287 - vae_kl_loss: 144.2698 - val_loss: 2014.8027 - val_vae_r_loss: 1871.3441 - val_vae_kl_loss: 143.4583
# Epoch 4343/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 493.7852 - vae_r_loss: 349.4678 - vae_kl_loss: 144.3172WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04343: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 493.7852 - vae_r_loss: 349.4678 - vae_kl_loss: 144.3172 - val_loss: 2014.4045 - val_vae_r_loss: 1870.9980 - val_vae_kl_loss: 143.4062
# Epoch 4344/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 492.8921 - vae_r_loss: 348.6690 - vae_kl_loss: 144.2230WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04344: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 202s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 492.8921 - vae_r_loss: 348.6690 - vae_kl_loss: 144.2230 - val_loss: 2018.0589 - val_vae_r_loss: 1874.6483 - val_vae_kl_loss: 143.4099
# Epoch 4345/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 493.5059 - vae_r_loss: 349.3282 - vae_kl_loss: 144.1777WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04345: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 201s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 493.5059 - vae_r_loss: 349.3282 - vae_kl_loss: 144.1777 - val_loss: 2017.9641 - val_vae_r_loss: 1874.7479 - val_vae_kl_loss: 143.2148
# Epoch 4346/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 494.6914 - vae_r_loss: 350.4532 - vae_kl_loss: 144.2387WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04346: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.6914 - vae_r_loss: 350.4532 - vae_kl_loss: 144.2387 - val_loss: 2015.3615 - val_vae_r_loss: 1872.0841 - val_vae_kl_loss: 143.2765
# Epoch 4347/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 494.2224 - vae_r_loss: 350.0295 - vae_kl_loss: 144.1931WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04347: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 199s 54ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.2215 - vae_r_loss: 350.0298 - vae_kl_loss: 144.1919 - val_loss: 2019.0691 - val_vae_r_loss: 1876.0093 - val_vae_kl_loss: 143.0586
# Epoch 4348/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.3546 - vae_r_loss: 351.3216 - vae_kl_loss: 144.0328WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04348: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.3595 - vae_r_loss: 351.3270 - vae_kl_loss: 144.0323 - val_loss: 2021.3953 - val_vae_r_loss: 1878.2772 - val_vae_kl_loss: 143.1172
# Epoch 4349/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.5712 - vae_r_loss: 351.4289 - vae_kl_loss: 144.1427WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04349: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 199s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.5675 - vae_r_loss: 351.4249 - vae_kl_loss: 144.1430 - val_loss: 2016.3697 - val_vae_r_loss: 1872.9916 - val_vae_kl_loss: 143.3794
# Epoch 4350/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.9160 - vae_r_loss: 351.2393 - vae_kl_loss: 144.6766WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04350: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 199s 54ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.9231 - vae_r_loss: 351.2460 - vae_kl_loss: 144.6770 - val_loss: 2024.1132 - val_vae_r_loss: 1881.0107 - val_vae_kl_loss: 143.1015
# Epoch 4351/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 494.5720 - vae_r_loss: 350.5797 - vae_kl_loss: 143.9921WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04351: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 200s 55ms/step - batch: 1827.5000 - size: 32.0000 - loss: 494.5659 - vae_r_loss: 350.5747 - vae_kl_loss: 143.9910 - val_loss: 2029.0458 - val_vae_r_loss: 1885.5957 - val_vae_kl_loss: 143.4481
# Epoch 4352/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 495.8149 - vae_r_loss: 351.3156 - vae_kl_loss: 144.4986WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04352: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 204s 56ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.8149 - vae_r_loss: 351.3156 - vae_kl_loss: 144.4986 - val_loss: 2018.2547 - val_vae_r_loss: 1874.9777 - val_vae_kl_loss: 143.2755
# Epoch 4353/100000
# 3655/3656 [============================>.] - ETA: 0s - batch: 1827.0000 - size: 32.0000 - loss: 495.8932 - vae_r_loss: 351.1731 - vae_kl_loss: 144.7198WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04353: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 205s 56ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.8966 - vae_r_loss: 351.1771 - vae_kl_loss: 144.7192 - val_loss: 2017.3624 - val_vae_r_loss: 1874.1106 - val_vae_kl_loss: 143.2506
# Epoch 4354/100000
# 3656/3656 [==============================] - ETA: 0s - batch: 1827.5000 - size: 32.0000 - loss: 495.7382 - vae_r_loss: 351.5062 - vae_kl_loss: 144.2318WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
#
# Epoch 04354: val_loss did not improve from 1981.93430
# 3656/3656 [==============================] - 204s 56ms/step - batch: 1827.5000 - size: 32.0000 - loss: 495.7382 - vae_r_loss: 351.5062 - vae_kl_loss: 144.2318 - val_loss: 2013.8378 - val_vae_r_loss: 1870.3446 - val_vae_kl_loss: 143.4904
# Epoch 4355/100000
#  464/3656 [==>...........................] - ETA: 2:09 - batch: 231.5000 - size: 32.0000 - loss: 496.5392 - vae_r_loss: 351.9980 - vae_kl_loss: 144.5411

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def plot_latent_space(trained_decoder, pimage, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    image = np.array(image).astype("float32")/255.0
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.5])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_tstr = np.array([0.3])
    X_tvel = np.expand_dims(X_tstr, axis=0)
    X_ttime = np.array([0.1])
    X_tvel = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    X_train = [image, X_tstr, X_tvel, X_ttime]

    x_encoded = VarAE.predict(X_train)*255.0
    # print(x_encoded)
    x_encoded_out = np.squeeze(x_encoded,axis=0)
    # pred_image = np.zeros([160,160,3], np.uint8)
    pred_image = array_to_img(x_encoded_out)
    pred_image = np.array(pred_image)
    pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # pred_img = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
    # print(type(pred_img))
    # print(pred_image.shape)
    plt.imshow(pred_image)
    # plt.imshow(cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB))
    plt.show()

    origin_image_name = '/home2/kdh/vae/vae_test/2022-12-08-14-30-12-332957.jpg'
    cv2.imwrite('/')
    # plt.xticks(pixel_range, sample_range_x)
    # plt.yticks(pixel_range, sample_range_y)
    # plt.xlabel("z[0]")
    # plt.ylabel("z[1]")

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-30-12-332957.jpg')
# plot_latent_space(decoder, test_img)

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space(trained_decoder, valid_data, n=50, figsize=15):
        
    for image_name, velocity, measurement, tar_image_name, tar_steering_angle, tar_vel, tar_time in valid_data:
        # self.data.image_names, self.data.velocities, self.data.measurements, 
        # self.data.tar_image_names, self.data.tar_steering_angle, self.data.tar_vel, self.data.tar_time
        
        image_path = data_path + '/' + image_name
        # print(data_path, tar_image_name)
        tar_image_path = data_path + '/' + tar_image_name
        image = cv2.imread(image_path)
        tar_image = cv2.imread(tar_image_path)

        # if collected data is not cropped then crop here
        # otherwise do not crop.
        image = image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        image = cv2.resize(image, 
                            (config['input_image_width'],
                            config['input_image_height']))
        tar_image = tar_image[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                    Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
        tar_image = cv2.resize(tar_image, 
                            (config['input_image_width'],
                            config['input_image_height']))

        cv2.imwrite('/home2/kdh/vae/vae_test/'+image_name, image)
        image = np.array(image).astype("float32")/255.0
        # image = image_process.process(image)
        steering_angle, throttle, brake = measurement
        
        image = np.expand_dims(image, axis=0)
        X_tvel = np.array([velocity])
        X_tvel = np.expand_dims(X_tvel, axis=0)
        X_tstr = np.array([steering_angle])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_ttime = np.array([tar_time])
        X_ttime = np.expand_dims(X_ttime, axis=0)
        
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image)
        # plt.imshow(pred_image)
        # plt.show()

        # image_name = '/home2/kdh/vae/vae_test/'+image_name
        pred_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'.jpg'
        gt_tar_image_name = '/home2/kdh/vae/vae_test/'+image_name[:-4]+'_'+str(int(steering_angle*1000))+'_'+str(int(velocity))+'_'+str(tar_time)[:4]+'_gt.jpg'
        cv2.imwrite(pred_image_name, pred_image)
        cv2.imwrite(gt_tar_image_name, tar_image)

        # print(pred_image_name,' done')
        # cv2.imwrite('/')


# save_latent_space(decoder, valid_data[3423:4422])

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import array_to_img
def save_latent_space_diff_steer(trained_decoder, pimage, save_image_name, n=50, figsize=15):


    image = pimage[Config.data_collection['image_crop_y1']:Config.data_collection['image_crop_y2'],
                Config.data_collection['image_crop_x1']:Config.data_collection['image_crop_x2']]
    image = cv2.resize(image, 
                        (config['input_image_width'],
                        config['input_image_height']))
    cv2.imwrite('/home2/kdh/vae/vae_diff_steer_test/'+save_image_name+'.jpg', image)
    image = np.array(image).astype("float32")/255.0
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.show()
    image = np.expand_dims(image, axis=0)
    # vel = np.array()


    X_tvel = np.array([14.85])
    X_tvel = np.expand_dims(X_tvel, axis=0)
    X_ttime = np.array([0.8])
    X_ttime = np.expand_dims(X_ttime, axis=0)
    # print(X_tvel.shape)
    for s in np.arange(0, 0.8, 0.0125):
        X_tstr = np.array([s-0.4])
        X_tstr = np.expand_dims(X_tstr, axis=0)
        X_train = [image, X_tstr, X_tvel, X_ttime]

        x_encoded = VarAE.predict(X_train)*255.0
        x_encoded_out = np.squeeze(x_encoded,axis=0)
        pred_image = array_to_img(x_encoded_out)
        pred_image = np.array(pred_image)
        # pred_image = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)
        s_str = "{:.3f}".format(s)
        pred_image_name = ('/home2/kdh/vae/vae_diff_steer_test/'
                            +save_image_name
                            +'_'+str(s_str)
                            +'.jpg'
        )
        cv2.imwrite(pred_image_name, pred_image)
    
        

# test_img = cv2.imread('/home2/kdh/vae/2022-12-08-14-25-28/2022-12-08-14-35-43-708754.jpg')
# save_latent_space_diff_steer(decoder, test_img, '2022-12-08-14-35-43-708754')
